# %%
# import libraries

import pandas as pd
#import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
#import matplotlib.patches as mpatches

# %%
path = f"C:/Users/pablo/OneDrive/Documentos/GitHub/MDS-Notebooks/02-VdI/prodagosto2022.xlsx"
frame = pd.read_excel(path)

# %%
frame.columns
# Out:
# Index(['Maq1', 'Orden Fab.', 'CW1', 'Cantidad OF', 'Saldo', 'Cant. Piso',
#        'Registrado', 'Turn', 'Etiq', 'Hora', 'Material', 'Cant. Leida',
#        'Descrip. Material', 'Embalaje', 'Secuencia', 'Cant. Sugerida', 'CQF',
#        'Veloc1', 'Mód', 'S', 'Veloc2', 'Veloc3', 'Creado', 'Nº pers.',
#        'Usuario', 'Almacén Notificación'],
#       dtype='object')

# %%
frame
# Out:
#         Maq1  Orden Fab.  CW1  Cantidad OF    Saldo  Cant. Piso Registrado  \
# 0     BB12-1   110132446  160      80000.0  11623.2     68360.0 2022-08-05
# 1     BB12-1   110132446  160      80000.0  11623.2     68360.0 2022-08-05
# 2     BB12-1   110132446  160      80000.0  11623.2     68360.0 2022-08-19
# 3     BB12-1   110132446  160      80000.0  11623.2     68360.0 2022-08-19
# 4     BB12-1   110132446  160      80000.0  11623.2     68360.0 2022-08-30
# ...      ...         ...  ...          ...      ...         ...        ...
# 6140  J-B123   110138881  165      92000.0  25568.0     66422.0 2022-08-31
# 6141  J-B123   110138881  165      92000.0  25568.0     66422.0 2022-08-31
# 6142  J-B123   110138881  165      92000.0  25568.0     66422.0 2022-08-31
# 6143  J-B123   110138881  165      92000.0  25568.0     66422.0 2022-08-31
# 6144  J-B123   110138881  165      92000.0  25568.0     66422.0 2022-08-31
#
#       Turn  Etiq      Hora  ... CQF  Veloc1  Mód  S  Veloc2  Veloc3  \
# 0        1   156  14:16:54  ...   C  475.74  ICP  L       0       0
# 1        3   157  08:53:34  ...   C  475.74  ICP  L       0       0
# 2        1   166  09:03:30  ...   C  475.74  ICP  L       0       0
# 3        1   167  09:03:00  ...   C  475.74  ICP  L       0       0
# 4        2   168  20:45:27  ...   C  475.74  ICP  L       0       0
# ...    ...   ...       ...  ...  ..     ...  ... ..     ...     ...
# 6140     3     2  02:27:12  ...   C  855.59  ICP  L    5000       0
# 6141     3     3  02:27:04  ...   C  855.59  ICP  L    5000       0
# 6142     3     4  03:26:44  ...   C  855.59  ICP  L    5000       0
# 6143     3     5  05:15:01  ...   C  855.59  ICP  L    5000       0
# 6144     3     6  05:15:28  ...   C  855.59  ICP  L    5000       0
#
#          Creado  Nº pers.   Usuario Almacén Notificación
# 0    2022-08-05         0  AREATREF               1110.0
# 1    2022-08-06         0  AREATREF               1110.0
# 2    2022-08-19         0  AREATREF               1110.0
# 3    2022-08-19         0  AREATREF               1110.0
# 4    2022-08-30         0  AREATREF               1110.0
# ...         ...       ...       ...                  ...
# 6140 2022-09-01         0  AREATREF               1110.0
# 6141 2022-09-01         0  AREATREF               1110.0
# 6142 2022-09-01         0  AREATREF               1110.0
# 6143 2022-09-01         0  AREATREF               1110.0
# 6144 2022-09-01         0  AREATREF               1110.0
#
# [6145 rows x 26 columns]

# %%
p1 = frame[['Maq1', 'Orden Fab.', 'Cantidad OF', 'Saldo', 'Cant. Piso',
       'Registrado', 'Turn', 'Material', 'Cant. Leida',
       'Veloc1']]
p1
# Out:
#         Maq1  Orden Fab.  Cantidad OF    Saldo  Cant. Piso Registrado  Turn  \
# 0     BB12-1   110132446      80000.0  11623.2     68360.0 2022-08-05     1
# 1     BB12-1   110132446      80000.0  11623.2     68360.0 2022-08-05     3
# 2     BB12-1   110132446      80000.0  11623.2     68360.0 2022-08-19     1
# 3     BB12-1   110132446      80000.0  11623.2     68360.0 2022-08-19     1
# 4     BB12-1   110132446      80000.0  11623.2     68360.0 2022-08-30     2
# ...      ...         ...          ...      ...         ...        ...   ...
# 6140  J-B123   110138881      92000.0  25568.0     66422.0 2022-08-31     3
# 6141  J-B123   110138881      92000.0  25568.0     66422.0 2022-08-31     3
# 6142  J-B123   110138881      92000.0  25568.0     66422.0 2022-08-31     3
# 6143  J-B123   110138881      92000.0  25568.0     66422.0 2022-08-31     3
# 6144  J-B123   110138881      92000.0  25568.0     66422.0 2022-08-31     3
#
#           Material  Cant. Leida  Veloc1
# 0     T00133060000          590  475.74
# 1     T00133060000          664  475.74
# 2     T00133060000          717  475.74
# 3     T00133060000          633  475.74
# 4     T00133060000          692  475.74
# ...            ...          ...     ...
# 6140  T00190500001          782  855.59
# 6141  T00190500001          785  855.59
# 6142  T00190500001          784  855.59
# 6143  T00190500001          787  855.59
# 6144  T00190500001          787  855.59
#
# [6145 rows x 10 columns]

# %%
p1['Maq1'].unique()
# Out:
# array(['BB12-1', 'BZ 8', 'BB11-1', 'MONOS', 'FRIG B91', 'BB 82', 'BB10-1',
#        'BZ4-2', 'BB 71', 'JUP7', 'JUP9-1', 'JUP9-2', 'BB 62', 'BB10-2',
#        'BB 81', 'J-B122', 'J-B5-1', 'BZ 5', 'J-B4-1', 'M 4', 'BB 52',
#        'BB 31', 'BAZ 10', 'J-B111', 'J-B123', 'J-B121', 'JUP9-4',
#        'JUP9-3', 'J-C92', 'C 91', 'J-C93', 'J-B101', 'C 92', 'NDB 5',
#        'J-C91', 'H 8', 'C 82', 'NDB 2', 'NDB 1', 'NDB 3', 'B 92',
#        'D 12-2', 'C 81', 'BCU'], dtype=object)

# %%
p2 = p1.groupby(by=['Orden Fab.','Maq1'])['Cantidad OF'].mean().reset_index()
p2['Cant. Leida'] = p1.groupby(by=['Orden Fab.','Maq1'])['Cant. Leida'].sum().reset_index()['Cant. Leida']
p2 = p2.sort_values(by=['Orden Fab.']).reset_index()
p2.head(15)
# Out:
#     index  Orden Fab.      Maq1  Cantidad OF  Cant. Leida
# 0       0   110132446    BB12-1      80000.0         6992
# 1       1   110134256      BZ 8    1120000.0       112097
# 2       2   110134327    BB12-1     220000.0        18309
# 3       3   110134504    BB11-1     385000.0        24691
# 4       4   110134504    BB12-1     385000.0         2068
# 5       5   110135325     MONOS     120000.0         4287
# 6       6   110135340  FRIG B91    1000000.0       107944
# 7       7   110135351     BB 82     220000.0        42657
# 8       8   110135725    BB10-1     330000.0        54432
# 9       9   110135759     BB 71     800000.0         3210
# 10     10   110135759     BZ4-2     800000.0        91873
# 11     11   110135759      JUP7     800000.0         4022
# 12     13   110135797    JUP9-1    1710000.0         7259
# 13     14   110135797    JUP9-2    1710000.0          910
# 14     12   110135797      JUP7    1710000.0       244457

# %% [markdown]
# # from raw value to percentage
# total = frame.groupby('Orden Fab.')['Cantidad OF'].mean().reset_index()
# total

# %% [markdown]
# piso = frame.groupby('Orden Fab.')['Cant. Piso'].mean().reset_index()
# piso['Cant. Piso'] = [i / j * 100 for i,j in zip(piso['Cant. Piso'], total['Cantidad OF'])]
# total['Cantidad OF'] = [i / j * 100 for i,j in zip(total['Cantidad OF'], total['Cantidad OF'])]

# %% [markdown]
# # set the figure size
# plt.figure(figsize=(150, 30))
#
# # bar chart 1 -> top bars (group of "Cantidad OF")
# bar1 = sns.barplot(x="Orden Fab.",  y="Cantidad OF", data=total, color='darkblue')
# #bar1 = sns.barplot(y="Orden Fab.",  x="Cantidad OF", data=total, color='darkblue')
# # bar chart 2 -> bottom bars (group of 'Cant. Piso'
# bar2 = sns.barplot(x="Orden Fab.", y='Cant. Piso', data=piso, color='lightblue')
# #bar2 = sns.barplot(y="Orden Fab.", x='Cant. Piso', data=piso, color='lightblue')
#
# # add legend
# top_bar = mpatches.Patch(color='darkblue', label='Saldo')
# bottom_bar = mpatches.Patch(color='lightblue', label='Cant. Piso')
# plt.legend(handles=[top_bar, bottom_bar])
#
#
# # show the graph
# plt.show()
# pass

# %%
a = frame.groupby('Orden Fab.')['Cantidad OF','Cant. Piso'].mean().reset_index()
# Out:
# C:\Users\pablo\AppData\Local\Temp\ipykernel_30492\4266636242.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   a = frame.groupby('Orden Fab.')['Cantidad OF','Cant. Piso'].mean().reset_index()

# %%
def porcentaje (cantof, cantpiso):
    porcentaje = cantpiso/cantof*100
    return porcentaje
a['cumplimiento']=a[['Cantidad OF','Cant. Piso']].apply(lambda x : porcentaje(*x), axis=1)
a
# Out:
#      Orden Fab.  Cantidad OF  Cant. Piso  cumplimiento
# 0     110132446      80000.0     68360.0     85.450000
# 1     110134256    1120000.0    850862.0     75.969821
# 2     110134327     220000.0    191163.0     86.892273
# 3     110134504     385000.0    305689.0     79.399740
# 4     110135325     120000.0    103310.0     86.091667
# ..          ...          ...         ...           ...
# 826   119001045       1800.0      1767.0     98.166667
# 827   119001046        900.0       727.0     80.777778
# 828   119001055        691.0       756.0    109.406657
# 829   119001056        522.0       444.0     85.057471
# 830   119001060       8000.0      7236.0     90.450000
#
# [831 rows x 4 columns]

# %%
porcentaje_ordenado=a.sort_values(by='cumplimiento') #ver qué tan critica es la OF (tiempo paa cumplirla)
porcentaje_ordenado
# Out:
#      Orden Fab.  Cantidad OF  Cant. Piso  cumplimiento
# 348   110138287       2400.0       298.0     12.416667
# 82    110137953       4500.0       657.0     14.600000
# 493   110138441      12000.0      2086.0     17.383333
# 379   110138327       5500.0       974.0     17.709091
# 821   119001020      52000.0     11986.0     23.050000
# ..          ...          ...         ...           ...
# 46    110137513      80000.0     95265.0    119.081250
# 188   110138095      52000.0     61955.0    119.144231
# 16    110136183      52000.0     61969.0    119.171154
# 498   110138446      20000.0     23940.0    119.700000
# 668   110138619      40000.0     47978.0    119.945000
#
# [831 rows x 4 columns]

# %%
top10=porcentaje_ordenado.iloc[0:10]
top10=pd.DataFrame(top10)
top10
# Out:
#      Orden Fab.  Cantidad OF  Cant. Piso  cumplimiento
# 348   110138287       2400.0       298.0     12.416667
# 82    110137953       4500.0       657.0     14.600000
# 493   110138441      12000.0      2086.0     17.383333
# 379   110138327       5500.0       974.0     17.709091
# 821   119001020      52000.0     11986.0     23.050000
# 512   110138462      16200.0      3854.0     23.790123
# 702   110138665      50000.0     11953.0     23.906000
# 678   110138635       3200.0       943.0     29.468750
# 492   110138440       6400.0      2217.0     34.640625
# 510   110138460      80000.0     28584.0     35.730000

# %% [markdown]
# plt.figure(figsize=(10,10))
# bar1 = sns.barplot(y="Orden Fab.",  x="Porcentaje de cumplimiento", data=top10, orient="h", order=top10['Orden Fab.'], color="#36a7e9")
# plt.xlim(0,100)
# plt.ylabel('Número de OF', fontsize=20)
# plt.xlabel('Cumplimiento %', fontsize=20)
# plt.grid(True, color = "#a1cdf2", linewidth = "2", linestyle = "-.", axis='x')
# plt.show()

# %%
top10.set_index('Orden Fab.', inplace=True)

# %%
df_sorted = top10['cumplimiento'].sort_values(ascending=False)
df_sorted =pd.DataFrame(df_sorted)
df_sorted['pendiente'] = 100-df_sorted
# Out:
#             cumplimiento  pendiente
# Orden Fab.
# 110138460      35.730000  64.270000
# 110138440      34.640625  65.359375
# 110138635      29.468750  70.531250
# 110138665      23.906000  76.094000
# 110138462      23.790123  76.209877
# 119001020      23.050000  76.950000
# 110138327      17.709091  82.290909
# 110138441      17.383333  82.616667
# 110137953      14.600000  85.400000
# 110138287      12.416667  87.583333

# %%
#Función que permite eliminar los bordes del gráfico
def hide_border(ax):
    ax.spines['bottom'].set_visible(False) #Linea inferior
    ax.spines['left'].set_visible(False) #Linea izquierda
    ax.spines['right'].set_visible(False) #Linea derecha
    ax.spines['top'].set_visible(False) #Linea superior

# %%
fontsize=12
colors = ["#36a7e9", '#d3d3d3']

ax = df_sorted.plot.barh(stacked=True, figsize=(10, 5), legend=False, width=0.9, alpha=0.9, xlim=(0, 100),
                        color=colors)

hide_border(ax)   #Ocultar bordes
ax.tick_params(axis=u'both', which=u'both', length=0)
ax.set_ylabel('')
ax.set_title("Top 10 de #OF con menor % de cumplimiento", pad=24, fontweight=700)
ax.title.set_position([.5, 1])
percents = df_sorted.columns
ax.text(0, df_sorted.shape[0]-0.3, #ubicacion horizontal, posicion vertica,
        percents[0], color=colors[0], fontsize=fontsize)  #nombre de la variable, color del texto, tamaño texto 
ax.text(85, df_sorted.shape[0]-0.3, percents[1], color=colors[1], fontsize=fontsize)

for p in ax.patches:
    if p.xy[0] == 0:
        xpos = 2
    else:
        xpos = 93
    ax.annotate(str(int(round(p.get_width()))) + "%", (xpos, p.xy[1] + 0.3), color='black', fontsize=fontsize)

plt.show()

# %%
df_sorted.index
# Out:
# Int64Index([110138460, 110138440, 110138635, 110138665, 110138462, 119001020,
#             110138327, 110138441, 110137953, 110138287],
#            dtype='int64', name='Orden Fab.')

# %%
p3 = pd.DataFrame()
for i in df_sorted.index:
    p3 = p3.append(p2[p2['Orden Fab.']==i])
p3
# Out:
# C:\Users\pablo\AppData\Local\Temp\ipykernel_30492\3125413433.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   p3 = p3.append(p2[p2['Orden Fab.']==i])
# C:\Users\pablo\AppData\Local\Temp\ipykernel_30492\3125413433.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   p3 = p3.append(p2[p2['Orden Fab.']==i])
# C:\Users\pablo\AppData\Local\Temp\ipykernel_30492\3125413433.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   p3 = p3.append(p2[p2['Orden Fab.']==i])
# C:\Users\pablo\AppData\Local\Temp\ipykernel_30492\3125413433.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   p3 = p3.append(p2[p2['Orden Fab.']==i])
# C:\Users\pablo\AppData\Local\Temp\ipykernel_30492\3125413433.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   p3 = p3.append(p2[p2['Orden Fab.']==i])
# C:\Users\pablo\AppData\Local\Temp\ipykernel_30492\3125413433.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   p3 = p3.append(p2[p2['Orden Fab.']==i])
# C:\Users\pablo\AppData\Local\Temp\ipykernel_30492\3125413433.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   p3 = p3.append(p2[p2['Orden Fab.']==i])
# C:\Users\pablo\AppData\Local\Temp\ipykernel_30492\3125413433.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   p3 = p3.append(p2[p2['Orden Fab.']==i])
# C:\Users\pablo\AppData\Local\Temp\ipykernel_30492\3125413433.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   p3 = p3.append(p2[p2['Orden Fab.']==i])
# C:\Users\pablo\AppData\Local\Temp\ipykernel_30492\3125413433.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   p3 = p3.append(p2[p2['Orden Fab.']==i])
#      index  Orden Fab.      Maq1  Cantidad OF  Cant. Leida
# 590    590   110138460    J-B101      80000.0        22286
# 591    591   110138460    J-B121      80000.0         6298
# 572    572   110138440    BB12-1       6400.0          762
# 802    802   110138635    J-B5-1       3200.0          943
# 827    827   110138665  FRIG B91      50000.0        11953
# 593    593   110138462       BCU      16200.0         3854
# 955    955   119001020     BB 31      52000.0         8240
# 439    439   110138327     BB 52       5500.0          974
# 573    573   110138441    BB12-1      12000.0         2086
# 103    103   110137953      BZ 5       4500.0          335
# 406    406   110138287    JUP9-1       2400.0          298
