# %% [markdown]
# ## APIs

# %% [markdown]
# ### Ejercicio 1

# %%
import requests
import json

## https://pokedevs.gitbook.io/pokedex/resources/pokemon

r = requests.get('https://pokeapi.glitch.me/v1/pokemon/pikachu')

# %%
data = r.json()
data
# Out:
# [{'number': '25',
#   'name': 'Pikachu',
#   'species': 'Mouse',
#   'types': ['Electric'],
#   'abilities': {'normal': ['Static'], 'hidden': ['Lightning Rod']},
#   'eggGroups': ['Field', 'Fairy'],
#   'gender': [50, 50],
#   'height': '1\'04"',
#   'weight': '13.2 lbs.',
#   'family': {'id': 10,
#    'evolutionStage': 2,
#    'evolutionLine': ['Pichu', 'Pikachu', 'Raichu']},
#   'starter': False,
#   'legendary': False,
#   'mythical': False,
#   'ultraBeast': False,
#   'mega': False,
#   'gen': 1,
#   'sprite': 'https://cdn.traction.one/pokedex/pokemon/25.png',
#   'description': 'When it is angered, it immediately discharges the energy stored in the pouches in its cheeks.'}]

# %%
from IPython.display import Image
from IPython.core.display import HTML 
Image(url= data[0]['sprite'])
# Out:
# <img src="https://cdn.traction.one/pokedex/pokemon/25.png"/>

# %% [markdown]
# Obtener la lista de feriados de la API de https://www.feriadosapp.com/api/holidays.json

# %%
r = requests.get('https://www.feriadosapp.com/api/holidays.json')
feriados = json.loads(r.text)

# %%
feriados
# Out:
# {'status': 'success',
#  'data': [{'date': '2022-01-01',
#    'title': 'Año Nuevo',
#    'type': 'Civil',
#    'inalienable': True,
#    'extra': 'Civil e Irrenunciable'},
#   {'date': '2022-04-15',
#    'title': 'Viernes Santo',
#    'type': 'Religioso',
#    'inalienable': False,
#    'extra': 'Religioso'},
#   {'date': '2022-04-16',
#    'title': 'Sabado Santo',
#    'type': 'Religioso',
#    'inalienable': False,
#    'extra': 'Religioso'},
#   {'date': '2022-05-01',
#    'title': 'Día Nacional del Trabajo',
#    'type': 'Civil',
#    'inalienable': True,
#    'extra': 'Civil e Irrenunciable'},
#   {'date': '2022-05-21',
#    'title': 'Día de las Glorias Navales',
#    'type': 'Civil',
#    'inalienable': False,
#    'extra': 'Civil'},
#   {'date': '2022-06-21',
#    'title': 'Día Nacional de los Pueblos Indígenas',
#    'type': 'Civil',
#    'inalienable': False,
#    'extra': 'Civil'},
#   {'date': '2022-06-27',
#    'title': 'San Pedro y San Pablo',
#    'type': 'Religioso',
#    'inalienable': False,
#    'extra': 'Religioso'},
#   {'date': '2022-07-16',
#    'title': 'Día de la Virgen del Carmen',
#    'type': 'Religioso',
#    'inalienable': False,
#    'extra': 'Religioso'},
#   {'date': '2022-08-15',
#    'title': 'Asunción de la Virgen',
#    'type': 'Religioso',
#    'inalienable': False,
#    'extra': 'Religioso'},
#   {'date': '2022-09-16',
#    'title': '16 de Septiembre',
#    'type': 'Civil',
#    'inalienable': False,
#    'extra': 'Civil'},
#   {'date': '2022-09-18',
#    'title': 'Independencia Nacional',
#    'type': 'Civil',
#    'inalienable': True,
#    'extra': 'Civil e Irrenunciable'},
#   {'date': '2022-09-19',
#    'title': 'Día de las Glorias del Ejercito',
#    'type': 'Civil',
#    'inalienable': True,
#    'extra': 'Civil e Irrenunciable'},
#   {'date': '2022-10-10',
#    'title': 'Encuentro de Dos Mundos',
#    'type': 'Civil',
#    'inalienable': False,
#    'extra': 'Civil'},
#   {'date': '2022-10-31',
#    'title': 'Día de las Iglesias Evangélicas y Protestantes',
#    'type': 'Religioso',
#    'inalienable': False,
#    'extra': 'Religioso'},
#   {'date': '2022-11-01',
#    'title': 'Día de Todos los Santos',
#    'type': 'Religioso',
#    'inalienable': False,
#    'extra': 'Religioso'},
#   {'date': '2022-12-08',
#    'title': 'Inmaculada Concepción',
#    'type': 'Religioso',
#    'inalienable': False,
#    'extra': 'Religioso'},
#   {'date': '2022-12-25',
#    'title': 'Navidad',
#    'type': 'Religioso',
#    'inalienable': True,
#    'extra': 'Religioso e Irrenunciable'}]}

# %%
import pandas as pd

for f in feriados['data']:
    print(f['date'], f['title'], f['extra'])
    
pd.DataFrame(feriados['data'])
# Out:
# 2022-01-01 Año Nuevo Civil e Irrenunciable
# 2022-04-15 Viernes Santo Religioso
# 2022-04-16 Sabado Santo Religioso
# 2022-05-01 Día Nacional del Trabajo Civil e Irrenunciable
# 2022-05-21 Día de las Glorias Navales Civil
# 2022-06-21 Día Nacional de los Pueblos Indígenas Civil
# 2022-06-27 San Pedro y San Pablo Religioso
# 2022-07-16 Día de la Virgen del Carmen Religioso
# 2022-08-15 Asunción de la Virgen Religioso
# 2022-09-16 16 de Septiembre Civil
# 2022-09-18 Independencia Nacional Civil e Irrenunciable
# 2022-09-19 Día de las Glorias del Ejercito Civil e Irrenunciable
# 2022-10-10 Encuentro de Dos Mundos Civil
# 2022-10-31 Día de las Iglesias Evangélicas y Protestantes Religioso
# 2022-11-01 Día de Todos los Santos Religioso
# 2022-12-08 Inmaculada Concepción Religioso
# 2022-12-25 Navidad Religioso e Irrenunciable
#           date                                           title       type  \
# 0   2022-01-01                                       Año Nuevo      Civil
# 1   2022-04-15                                   Viernes Santo  Religioso
# 2   2022-04-16                                    Sabado Santo  Religioso
# 3   2022-05-01                        Día Nacional del Trabajo      Civil
# 4   2022-05-21                      Día de las Glorias Navales      Civil
# 5   2022-06-21           Día Nacional de los Pueblos Indígenas      Civil
# 6   2022-06-27                           San Pedro y San Pablo  Religioso
# 7   2022-07-16                     Día de la Virgen del Carmen  Religioso
# 8   2022-08-15                           Asunción de la Virgen  Religioso
# 9   2022-09-16                                16 de Septiembre      Civil
# 10  2022-09-18                          Independencia Nacional      Civil
# 11  2022-09-19                 Día de las Glorias del Ejercito      Civil
# 12  2022-10-10                         Encuentro de Dos Mundos      Civil
# 13  2022-10-31  Día de las Iglesias Evangélicas y Protestantes  Religioso
# 14  2022-11-01                         Día de Todos los Santos  Religioso
# 15  2022-12-08                           Inmaculada Concepción  Religioso
# 16  2022-12-25                                         Navidad  Religioso
#
#     inalienable                      extra
# 0          True      Civil e Irrenunciable
# 1         False                  Religioso
# 2         False                  Religioso
# 3          True      Civil e Irrenunciable
# 4         False                      Civil
# 5         False                      Civil
# 6         False                  Religioso
# 7         False                  Religioso
# 8         False                  Religioso
# 9         False                      Civil
# 10         True      Civil e Irrenunciable
# 11         True      Civil e Irrenunciable
# 12        False                      Civil
# 13        False                  Religioso
# 14        False                  Religioso
# 15        False                  Religioso
# 16         True  Religioso e Irrenunciable

# %% [markdown]
# ### Ejercicio 2

# %% [markdown]
# Obtener las 10 últimas leyes chilenas de la API https://www.leychile.cl/Consulta/legislacion_abierta_web_service y crear un dataframe con ellas

# %%
import requests
from xml.etree import ElementTree as ET

payload = {
    'opt': 3,
    'cantidad': 10
}

r = requests.get('https://www.leychile.cl/Consulta/obtxml', params=payload)
tree = ET.fromstring(r.text)

# %%
for n in tree:
    print(n)
    for elem in n:
        print(elem.tag)
    break
# Out:
# <Element 'NORMA' at 0x0000027D0F07E4A0>
# TIPOS_NUMEROS
# FECHA_PUBLICACION
# FECHA_PROMULGACION
# TITULO
# ORGANISMOS
# HISTORIASLEY
# TEXTO

# %%
for n in tree:
    for elem in n:
        print(elem.tag, elem.text)
# Out:
# TIPOS_NUMEROS None
# FECHA_PUBLICACION 2022-11-24
# FECHA_PROMULGACION 2022-11-18
# TITULO EXTIENDE TRANSITORIAMENTE EL PERMISO POSTNATAL PARENTAL
# ORGANISMOS None
# HISTORIASLEY None
# TEXTO
# LEY NÚM. 21.510
#
# EXTIENDE TRANSITORIAMENTE EL PERMISO POSTNATAL PARENTAL
#
#      Teniendo presente que el H. Congreso Nacional ha dado su aprobación al siguiente
#
#      Proyecto de ley:
# TIPOS_NUMEROS None
# FECHA_PUBLICACION 2022-11-25
# FECHA_PROMULGACION 2022-11-14
# TITULO QUE AUTORIZA LA TOMA DE EXAMEN PCR DESDE LOS 14 AÑOS, SIN EL CONSENTIMIENTO DE SUS PROGENITORES O DE QUIEN OSTENTE EL CUIDADO PERSONAL Y/O PATRIA POTESTAD, EN EL CONTEXTO DEL PROGRAMA DE BÚSQUEDA DE CASOS ACTIVOS DE COVID-19
# ORGANISMOS None
# HISTORIASLEY None
# TEXTO
# LEY NÚM. 21.509
#
# QUE AUTORIZA LA TOMA DE EXAMEN PCR DESDE LOS 14 AÑOS, SIN EL CONSENTIMIENTO DE SUS PROGENITORES O DE QUIEN OSTENTE EL CUIDADO PERSONAL Y/O PATRIA POTESTAD, EN EL CONTEXTO DEL PROGRAMA DE BÚSQUEDA DE CASOS ACTIVOS DE COVID-19
#
#      Teniendo presente que el H. Congreso Na
# TIPOS_NUMEROS None
# FECHA_PUBLICACION 2022-11-16
# FECHA_PROMULGACION 2022-11-09
# TITULO CONCEDE LA NACIONALIDAD POR GRACIA A LA CIUDADANA NEOZELANDESA SEÑORA MARY THERESE KALIN HURLEY
# ORGANISMOS None
# HISTORIASLEY None
# TEXTO
# LEY NÚM. 21.501
#
# CONCEDE LA NACIONALIDAD POR GRACIA A LA CIUDADANA NEOZELANDESA SEÑORA MARY THERESE KALIN HURLEY
#
#      Teniendo presente que el H. Congreso Nacional ha dado su aprobación al siguiente proyecto de ley iniciado en moción de los Honorables senadores señores Francisco Chahuán Chahuán,
# TIPOS_NUMEROS None
# FECHA_PUBLICACION 2022-11-21
# FECHA_PROMULGACION 2022-11-08
# TITULO PROMUEVE EL ALMACENAMIENTO DE ENERGÍA ELÉCTRICA Y LA ELECTROMOVILIDAD
# ORGANISMOS None
# HISTORIASLEY None
# TEXTO
# LEY NÚM. 21.505
#
# PROMUEVE EL ALMACENAMIENTO DE ENERGÍA ELÉCTRICA Y LA ELECTROMOVILIDAD
#
#      Teniendo presente que el H. Congreso Nacional ha dado su aprobación al siguiente
#
#      Proyecto de ley:
#
# TIPOS_NUMEROS None
# FECHA_PUBLICACION 2022-11-10
# FECHA_PROMULGACION 2022-11-04
# TITULO ESTABLECE PROHIBICIÓN DE INFORMAR DEUDAS CONTRAÍDAS PARA FINANCIAR SERVICIOS Y ACCIONES DE SALUD EN LA LEY Nº 19.628
# ORGANISMOS None
# HISTORIASLEY None
# TEXTO
# LEY NÚM. 21.504
#
# ESTABLECE PROHIBICIÓN DE INFORMAR DEUDAS CONTRAÍDAS PARA FINANCIAR SERVICIOS Y ACCIONES DE SALUD EN LA LEY Nº 19.628
#
#      Teniendo presente que el H. Congreso Nacional ha dado su aprobación al siguiente proyecto de ley iniciado en moción del Honorable senador señor Jaime Quintan
# TIPOS_NUMEROS None
# FECHA_PUBLICACION 2022-11-15
# FECHA_PROMULGACION 2022-11-04
# TITULO SUSPENDE LAS EVALUACIONES DE LOS PROFESIONALES DE LA EDUCACIÓN DURANTE EL AÑO 2022 Y MODIFICA LAS NORMAS QUE INDICA
# ORGANISMOS None
# HISTORIASLEY None
# TEXTO
# LEY NÚM. 21.506
#
# SUSPENDE LAS EVALUACIONES DE LOS PROFESIONALES DE LA EDUCACIÓN DURANTE EL AÑO 2022 Y MODIFICA LAS NORMAS QUE INDICA
#
#      Teniendo presente que el H. Congreso Nacional ha dado su aprobación al siguiente proyecto de ley iniciado en moción de los Honorables senadores seño
# TIPOS_NUMEROS None
# FECHA_PUBLICACION 2022-11-10
# FECHA_PROMULGACION 2022-11-04
# TITULO INTERPRETA Y MODIFICA LA NUEVA LEY DE COPROPIEDAD INMOBILIARIA N° 21.442
# ORGANISMOS None
# HISTORIASLEY None
# TEXTO
# LEY NÚM. 21.508
#
# INTERPRETA Y MODIFICA LA NUEVA LEY DE COPROPIEDAD INMOBILIARIA N° 21.442
#
#      Teniendo presente que el H. Congreso Nacional ha dado su aprobación al siguiente proyecto de ley iniciado en moción de los Honorables senadores señor David Sandoval Plaza, Fidel Espinoza Sandoval
# TIPOS_NUMEROS None
# FECHA_PUBLICACION 2022-11-16
# FECHA_PROMULGACION 2022-11-04
# TITULO SANCIONA PENALMENTE A QUIENES INGRESEN ELEMENTOS PROHIBIDOS A LOS ESTABLECIMIENTOS PENITENCIARIOS
# ORGANISMOS None
# HISTORIASLEY None
# TEXTO
# LEY NÚM. 21.494
#
# SANCIONA PENALMENTE A QUIENES INGRESEN ELEMENTOS PROHIBIDOS A LOS ESTABLECIMIENTOS PENITENCIARIOS
#
#      Teniendo presente que el H. Congreso Nacional ha dado su aprobación al siguiente proyecto de ley iniciado en moción de los Honorables senadores señor Felipe Kast Somm
# TIPOS_NUMEROS None
# FECHA_PUBLICACION 2022-11-15
# FECHA_PROMULGACION 2022-11-04
# TITULO ESTABLECE TRABAJO A DISTANCIA O TELETRABAJO PARA MUJERES EMBARAZADAS EN LOS CASOS QUE INDICA
# ORGANISMOS None
# HISTORIASLEY None
# TEXTO
# LEY NÚM. 21.498
#
# ESTABLECE TRABAJO A DISTANCIA O TELETRABAJO PARA MUJERES EMBARAZADAS EN LOS CASOS QUE INDICA
#
#      Teniendo presente que el H. Congreso Nacional ha dado su aprobación al siguiente proyecto de ley iniciado en moción de las Honorables senadoras señoras Isabel Allende Buss
# TIPOS_NUMEROS None
# FECHA_PUBLICACION 2022-11-05
# FECHA_PROMULGACION 2022-10-26
# TITULO MODIFICA EL PLAZO DE RENDICIÓN DE CUENTAS DE LOS APORTES PARA LOS CUERPOS DE BOMBEROS DE CHILE
# ORGANISMOS None
# HISTORIASLEY None
# TEXTO
# LEY NÚM. 21.503
#
# MODIFICA EL PLAZO DE RENDICIÓN DE CUENTAS DE LOS APORTES PARA LOS CUERPOS DE BOMBEROS DE CHILE
#
#      Teniendo presente que el H. Congreso Nacional ha dado su aprobación al siguiente
#
#      Proyecto de ley:

# %%
# !pip install xmljson
# Out:
# Collecting xmljson
#   Downloading xmljson-0.2.1-py2.py3-none-any.whl (10 kB)
# Installing collected packages: xmljson
# Successfully installed xmljson-0.2.1

# %%
import pandas as pd        
import xmljson 

jsontree = xmljson.parker.data(tree)['NORMA']
pd.DataFrame(jsontree)
# Out:
#                                        TIPOS_NUMEROS FECHA_PUBLICACION  \
# 0  {'TIPO_NUMERO': {'TIPO': 'XX1', 'NUMERO': 2151...        2022-11-24
# 1  {'TIPO_NUMERO': {'TIPO': 'XX1', 'NUMERO': 2150...        2022-11-25
# 2  {'TIPO_NUMERO': {'TIPO': 'XX1', 'NUMERO': 2150...        2022-11-16
# 3  {'TIPO_NUMERO': {'TIPO': 'XX1', 'NUMERO': 2150...        2022-11-21
# 4  {'TIPO_NUMERO': {'TIPO': 'XX1', 'NUMERO': 2150...        2022-11-10
# 5  {'TIPO_NUMERO': {'TIPO': 'XX1', 'NUMERO': 2150...        2022-11-15
# 6  {'TIPO_NUMERO': {'TIPO': 'XX1', 'NUMERO': 2150...        2022-11-10
# 7  {'TIPO_NUMERO': {'TIPO': 'XX1', 'NUMERO': 2149...        2022-11-16
# 8  {'TIPO_NUMERO': {'TIPO': 'XX1', 'NUMERO': 2149...        2022-11-15
# 9  {'TIPO_NUMERO': {'TIPO': 'XX1', 'NUMERO': 2150...        2022-11-05
#
#   FECHA_PROMULGACION                                             TITULO  \
# 0         2022-11-18  EXTIENDE TRANSITORIAMENTE EL PERMISO POSTNATAL...
# 1         2022-11-14  QUE AUTORIZA LA TOMA DE EXAMEN PCR DESDE LOS 1...
# 2         2022-11-09  CONCEDE LA NACIONALIDAD POR GRACIA A LA CIUDAD...
# 3         2022-11-08  PROMUEVE EL ALMACENAMIENTO DE ENERGÍA ELÉCTRIC...
# 4         2022-11-04  ESTABLECE PROHIBICIÓN DE INFORMAR DEUDAS CONTR...
# 5         2022-11-04  SUSPENDE LAS EVALUACIONES DE LOS PROFESIONALES...
# 6         2022-11-04  INTERPRETA Y MODIFICA LA NUEVA LEY DE COPROPIE...
# 7         2022-11-04  SANCIONA PENALMENTE A QUIENES INGRESEN ELEMENT...
# 8         2022-11-04  ESTABLECE TRABAJO A DISTANCIA O TELETRABAJO PA...
# 9         2022-10-26  MODIFICA EL PLAZO DE RENDICIÓN DE CUENTAS DE L...
#
#                                           ORGANISMOS HISTORIASLEY  \
# 0  {'ORGANISMO': 'MINISTERIO DEL TRABAJO Y PREVIS...         None
# 1               {'ORGANISMO': 'MINISTERIO DE SALUD'}         None
# 2  {'ORGANISMO': 'MINISTERIO DEL INTERIOR Y SEGUR...         None
# 3             {'ORGANISMO': 'MINISTERIO DE ENERGÍA'}         None
# 4               {'ORGANISMO': 'MINISTERIO DE SALUD'}         None
# 5           {'ORGANISMO': 'MINISTERIO DE EDUCACIÓN'}         None
# 6  {'ORGANISMO': 'MINISTERIO DE VIVIENDA Y URBANI...         None
# 7  {'ORGANISMO': 'MINISTERIO DE JUSTICIA Y DERECH...         None
# 8  {'ORGANISMO': 'MINISTERIO DEL TRABAJO Y PREVIS...         None
# 9  {'ORGANISMO': 'MINISTERIO DEL INTERIOR Y SEGUR...         None
#
#                                                TEXTO
# 0  \nLEY NÚM. 21.510\n      \nEXTIENDE TRANSITORI...
# 1  \nLEY NÚM. 21.509\n      \nQUE AUTORIZA LA TOM...
# 2  \nLEY NÚM. 21.501\n \nCONCEDE LA NACIONALIDAD ...
# 3  \nLEY NÚM. 21.505\n      \nPROMUEVE EL ALMACEN...
# 4  \nLEY NÚM. 21.504\n \nESTABLECE PROHIBICIÓN DE...
# 5  \nLEY NÚM. 21.506\n      \nSUSPENDE LAS EVALUA...
# 6  \nLEY NÚM. 21.508\n      \nINTERPRETA Y MODIFI...
# 7  \nLEY NÚM. 21.494\n      \nSANCIONA PENALMENTE...
# 8  \nLEY NÚM. 21.498\n      \nESTABLECE TRABAJO A...
# 9  \nLEY NÚM. 21.503\n      \nMODIFICA EL PLAZO D...

# %% [markdown]
# ### Ejercicio 3

# %% [markdown]
# Listar 2 ordenes de compra (incluyendo el monto de la OC) desde Mercado Público del día 9 de Enero del 2020

# %%
import requests
import time 
import pandas as pd

payload = {
    'fecha':'09012022',
    'ticket': '5C5EBE6A-54AC-4725-A0C3-9CA163F13255'
}

r = requests.get('https://api.mercadopublico.cl/servicios/v1/publico/ordenesdecompra.json', params=payload)

data = r.json()

ocs = []

for oc in data['Listado'][:2]:

    print(oc['Codigo'])
    payload = {
        'codigo':oc['Codigo'],
        'ticket':'F8537A18-8766-4DEF-9E59-426B4FEE2844'
    }
    r = requests.get('https://api.mercadopublico.cl/servicios/v1/publico/ordenesdecompra.json', params=payload)

    ocdata = r.json()
    monto = ocdata['Listado'][0]['Total']
    ocs.append({'codigo':oc['Codigo'], 'moto':monto})
    

df = pd.DataFrame(ocs)
# Out:
# 1057441-6330-SE21
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [22], in <cell line: 16>()
#      23     r = requests.get('https://api.mercadopublico.cl/servicios/v1/publico/ordenesdecompra.json', params=payload)
#      25     ocdata = r.json()
# ---> 26     monto = ocdata['Listado'][0]['Total']
#      27     ocs.append({'codigo':oc['Codigo'], 'moto':monto})
#      30 df = pd.DataFrame(ocs)
#
# KeyError: 'Listado'

# %%
data
# Out:
# {'Cantidad': 146,
#  'FechaCreacion': '2022-12-03T13:28:32.1684817Z',
#  'Version': 'v1',
#  'Listado': [{'Codigo': '1057441-6330-SE21',
#    'Nombre': 'ORDEN DE COMPRA DESDE 1057441-81-LE19',
#    'CodigoEstado': 12},
#   {'Codigo': '1057491-82-SE22',
#    'Nombre': 'MPO/RRFF-SSGG/MANTENCION AGUAS DIALISIS/ENERO 2021',
#    'CodigoEstado': 9},
#   {'Codigo': '1202511-16-SE21',
#    'Nombre': 'FEMER 11.851 SERVICIO DE DISTRIBUCIÓN DE AGUA POTABLE MEDIANTE CAMIÓN ALJIBE, PARA APOYAR APR CHAMPULLI EN LA COMUNA DE CARAHUE, PERIODO 06-AGOSTO DE 2021 AL 05 DE SEPTIEMBRE DE 2021), CAMIÓN PATENTE GWSL-25',
#    'CodigoEstado': 6},
#   {'Codigo': '1641-12324-SE21',
#    'Nombre': 'TDP-CNP N° 37737-INSUMOS PERITONEO DIALISIS-1641-2',
#    'CodigoEstado': 12},
#   {'Codigo': '1641-12478-CM21',
#    'Nombre': 'TDP-CP-122021-CANULA CPAP 6 FR',
#    'CodigoEstado': 12},
#   {'Codigo': '1641-98-CM22',
#    'Nombre': 'TDP-CP-012022-EQUIPO INFUSION INTRAVENOSA (SCALP) 23 G X 3/4',
#    'CodigoEstado': 6},
#   {'Codigo': '2272-1-AG22',
#    'Nombre': 'Orden de Compra generada por invitación a compra ágil: 2272-1-COT22',
#    'CodigoEstado': 6},
#   {'Codigo': '2280-12-SE22',
#    'Nombre': '2 SP 76784, DAEM, SERVICIO DE SANITIZACIÓN COVI-19 ESTABLECIMIENTOS EDUCACIONALES URBANOS Y RURALES PP 405-2020 ID 2282-50-LP20',
#    'CodigoEstado': 6},
#   {'Codigo': '2354-8-SE22', 'Nombre': 'APOYO EN GALVANOS', 'CodigoEstado': 6},
#   {'Codigo': '2664-5-SE22',
#    'Nombre': 'MEDICAMENTOS FARMACIA POPULAR S/P. 01-02-22',
#    'CodigoEstado': 6},
#   {'Codigo': '2765-9-SE22',
#    'Nombre': 'Cambio palmetas Casa Cultura, incluye mano de obra',
#    'CodigoEstado': 6},
#   {'Codigo': '3082-10-AG22',
#    'Nombre': 'Termómetros -Compra ágil: 3082-4-COT22',
#    'CodigoEstado': 6},
#   {'Codigo': '3092-258-SE21',
#    'Nombre': 'ORDEN DE COMPRA DESDE 3092-28-LE21',
#    'CodigoEstado': 6},
#   {'Codigo': '3143-4-SE22',
#    'Nombre': 'MANTENCIÓN DE AREAS VERDES ',
#    'CodigoEstado': 6},
#   {'Codigo': '316-3-SE22',
#    'Nombre': 'PEDIDO N°04 MANTENCION COMUNAL Y RECINTOS M.',
#    'CodigoEstado': 6},
#   {'Codigo': '3479-13-AG22',
#    'Nombre': 'Material Eléctrico Parque y Multicancha los Poetas II',
#    'CodigoEstado': 6},
#   {'Codigo': '3604-9-AG22',
#    'Nombre': 'DISPENSADOR DE AGUA Y RECARGA DE GALONES INFRAESTRUCTURA',
#    'CodigoEstado': 6},
#   {'Codigo': '3649-3-AG22',
#    'Nombre': 'ARRIENDO TRACTOR CORTA CESPED',
#    'CodigoEstado': 6},
#   {'Codigo': '3704-10-AG22',
#    'Nombre': 'ADQUISICIÓN DE EMBLEMAS OFICIALES PARA EL LICEO D.M.G.',
#    'CodigoEstado': 6},
#   {'Codigo': '515568-634-AG21',
#    'Nombre': 'SC-41545/INSUMOS PARA TRABAJOS DE SOLDADURAS/DEPTO. MANTENCION/CODEDUC/JFM.',
#    'CodigoEstado': 6},
#   {'Codigo': '5434-14-AG22',
#    'Nombre': 'Materiales Electricos',
#    'CodigoEstado': 12},
#   {'Codigo': '5434-17-AG22', 'Nombre': 'Bus río clarillo', 'CodigoEstado': 4},
#   {'Codigo': '5519-1-AG22',
#    'Nombre': 'Capacitación Administración de Servidores Web.',
#    'CodigoEstado': 6},
#   {'Codigo': '5586-33-AG22',
#    'Nombre': 'Orden de Compra generada por invitación a compra ágil: 5586-2399-COT21',
#    'CodigoEstado': 6},
#   {'Codigo': '5626-591-SE21',
#    'Nombre': 'IMPRESION CNCA Folio 454109 - E.PFEIFFER',
#    'CodigoEstado': 6},
#   {'Codigo': '758-394-AG21',
#    'Nombre': 'SC 12287 REPARACIÓN MESA COE  ONEMI R.M.',
#    'CodigoEstado': 6},
#   {'Codigo': '761-394-CM21', 'Nombre': 'Orden de Compra', 'CodigoEstado': 12},
#   {'Codigo': '813685-201-SE20',
#    'Nombre': 'RENOVACIÓN SERVICIO DE ASEO',
#    'CodigoEstado': 12},
#   {'Codigo': '842082-118-AG21',
#    'Nombre': 'Orden de Compra generada por invitación a compra ágil: 842082-61-COT21',
#    'CodigoEstado': 12},
#   {'Codigo': '842082-120-AG21',
#    'Nombre': 'Orden de Compra generada por invitación a compra ágil: 842082-63-COT21',
#    'CodigoEstado': 12},
#   {'Codigo': '842082-84-AG21',
#    'Nombre': 'Orden de Compra generada por invitación a compra ágil: 842082-39-COT21',
#    'CodigoEstado': 12},
#   {'Codigo': '842082-85-SE21',
#    'Nombre': 'COMPRA DE REPUESTOS',
#    'CodigoEstado': 12},
#   {'Codigo': '842082-89-SE21',
#    'Nombre': 'ORDEN DE COMPRA DESDE 842082-3-L121',
#    'CodigoEstado': 12},
#   {'Codigo': '958479-1-SE22',
#    'Nombre': 'AEROEVACUACION 392 409',
#    'CodigoEstado': 6},
#   {'Codigo': '986278-2-SE21',
#    'Nombre': 'ORDEN DE COMPRA DESDE 986278-11-LE20',
#    'CodigoEstado': 12},
#   {'Codigo': '1057417-9426-SE21',
#    'Nombre': 'IC MCM TD CS 10553 IC PEDIDO DICIEMBRE 2021',
#    'CodigoEstado': 12},
#   {'Codigo': '1057441-6765-SE21',
#    'Nombre': '1057441-32-LQ20',
#    'CodigoEstado': 12},
#   {'Codigo': '1057441-6873-CM21',
#    'Nombre': 'PECHERA PLASTICA MANGA LARGA CON OJAL ',
#    'CodigoEstado': 12},
#   {'Codigo': '1057441-7022-SE21',
#    'Nombre': 'TOLDO RETRACTIL 3X3',
#    'CodigoEstado': 12},
#   {'Codigo': '1057441-7297-SE21',
#    'Nombre': '1057441-32-LQ20\t',
#    'CodigoEstado': 12},
#   {'Codigo': '1057441-7392-SE21',
#    'Nombre': 'MATERIALES DE CONSTRUCCION\t',
#    'CodigoEstado': 12},
#   {'Codigo': '1070620-8491-AG21',
#    'Nombre': 'nzm adq memo N°E-84 unidad de mantención ',
#    'CodigoEstado': 6},
#   {'Codigo': '1132470-112-SE21',
#    'Nombre': 'CJS- LP- P01   ADQ. DE MOBILIARIO SLEP VALPARAÍSO.',
#    'CodigoEstado': 12},
#   {'Codigo': '1132470-97-SE21',
#    'Nombre': 'PVB - SERVICIO IMPRESION OFICINAS SLEP ',
#    'CodigoEstado': 12},
#   {'Codigo': '1641-7054-AG21',
#    'Nombre': 'MJA CP 08/2021 CALCIO CARBONATO-COLECALCIFEROL 1125 MG /1,75 MG. COMPRA AGIL: 1641-721-COT21',
#    'CodigoEstado': 12},
#   {'Codigo': '1658-2717-SE21',
#    'Nombre': 'ORDEN DE COMPRA DESDE 1658-632-LE21',
#    'CodigoEstado': 6},
#   {'Codigo': '1663-1764-AG21',
#    'Nombre': 'CONVENIO HOLTER DE RITMO Y HOLTER PA   1663-668-COT21',
#    'CodigoEstado': 12},
#   {'Codigo': '2111-193-SE22',
#    'Nombre': '2192190374 ANGIOGRAFIA ORDEN DE COMPRA DESDE 2111-94-LQ21  LINEA 11',
#    'CodigoEstado': 6},
#   {'Codigo': '2289-1309-SE21',
#    'Nombre': 'ORDEN DE COMPRA DESDE 2289-46-LE21',
#    'CodigoEstado': 6},
#   {'Codigo': '2294-9-AG22',
#    'Nombre': 'Orden de Compra generada por invitación a compra ágil: 2294-4-COT22',
#    'CodigoEstado': 6},
#   {'Codigo': '2575-44-SE21',
#    'Nombre': 'Extensionista CONAF-Municipalidad  Nacimiento ORDEN DE COMPRA DESDE 2575-5-LE21',
#    'CodigoEstado': 12},
#   {'Codigo': '2704-5-AG22',
#    'Nombre': 'sc 2756 Orden de Compra generada por invitación a compra ágil: 2704-896-COT21',
#    'CodigoEstado': 6},
#   {'Codigo': '2708-9-AG22',
#    'Nombre': 'MANTENCION SISTEMA DE CAMARAS DE VIGILANCIA ESTADIO DIAGUITA DE OVALLE',
#    'CodigoEstado': 6},
#   {'Codigo': '3021-4-SE22',
#    'Nombre': 'E-703 FONDOS SEP MATERIALES TECNOLOGICO ORD 81. DESDE 3021-97-L121',
#    'CodigoEstado': 6},
#   {'Codigo': '3203-4-AG22',
#    'Nombre': 'Orden de Compra generada por invitación a compra ágil: 3203-3-COT22',
#    'CodigoEstado': 6},
#   {'Codigo': '3500-3-AG22',
#    'Nombre': 'IPAD COLEGIO JFM. SEP',
#    'CodigoEstado': 6},
#   {'Codigo': '3921-20-SE22',
#    'Nombre': 'ORDEN DE COMPRA DESDE 3921-108-LE21',
#    'CodigoEstado': 6},
#   {'Codigo': '4158-3-AG22',
#    'Nombre': 'FILTROS Y ACEITE ZUSUKI GRAN NOMADE  GWRZ-74',
#    'CodigoEstado': 6},
#   {'Codigo': '4364-17-CM22',
#    'Nombre': 'Adquisicion de Vestuario ,Esc. Puerto Frutales de Coyanco',
#    'CodigoEstado': 6},
#   {'Codigo': '4414-4-SE22',
#    'Nombre': 'ORDEN DE COMPRA DESDE 4414-127-L121',
#    'CodigoEstado': 6},
#   {'Codigo': '4479-1-AG22',
#    'Nombre': 'Orden de Compra generada por invitación a compra ágil: 4479-1-COT22',
#    'CodigoEstado': 6},
#   {'Codigo': '4704-2-SE22',
#    'Nombre': 'ARRIENDO IMPRESORAS',
#    'CodigoEstado': 6},
#   {'Codigo': '5190-902-SE21',
#    'Nombre': 'FARMACIASUMINISTRO DE PRODUCTOS METABOLICOS',
#    'CodigoEstado': 6},
#   {'Codigo': '5562-63-AG21',
#    'Nombre': 'Orden de Compra generada por invitación a compra ágil: 5562-55-COT21',
#    'CodigoEstado': 12},
#   {'Codigo': '5586-23-SE22',
#    'Nombre': ' B/S Equipamiento e instrumental de apoyo ORDEN DE COMPRA DESDE 5586-335-L121',
#    'CodigoEstado': 6},
#   {'Codigo': '761-377-CM21', 'Nombre': 'Orden de Compra', 'CodigoEstado': 12},
#   {'Codigo': '761-382-CM21', 'Nombre': 'Orden de Compra', 'CodigoEstado': 12},
#   {'Codigo': '761-384-CM21', 'Nombre': 'Orden de Compra', 'CodigoEstado': 12},
#   {'Codigo': '761-386-CM21',
#    'Nombre': 'ORDEN DE COMPRA MANUAL POR REEMISION DE BOLETOS',
#    'CodigoEstado': 12},
#   {'Codigo': '788110-1090-SE21',
#    'Nombre': 'Medicamentos Farmacia Popular enero 2022',
#    'CodigoEstado': 6},
#   {'Codigo': '842082-101-AG21',
#    'Nombre': 'Orden de Compra generada por invitación a compra ágil: 842082-51-COT21',
#    'CodigoEstado': 12},
#   {'Codigo': '842082-94-AG21',
#    'Nombre': 'Orden de Compra generada por invitación a compra ágil: 842082-48-COT21',
#    'CodigoEstado': 12},
#   {'Codigo': '986278-126-CM21',
#    'Nombre': 'Orden de Compra',
#    'CodigoEstado': 12},
#   {'Codigo': '986278-27-SE21',
#    'Nombre': 'ORDEN DE COMPRA DESDE 986278-3-LE21',
#    'CodigoEstado': 12},
#   {'Codigo': '1057501-13788-SE21',
#    'Nombre': 'Servicio Arriendo equipos Oftalmología cuota 4/12, memo 190',
#    'CodigoEstado': 6},
#   {'Codigo': '1070620-7864-SE21',
#    'Nombre': 'FOO TD 1715/2021  ERLOTINIB MEMO 475/2021 FARMACIA Y PRÓTESIS',
#    'CodigoEstado': 6},
#   {'Codigo': '1288-897-AG21',
#    'Nombre': 'INSUMOS - PROGRAMA DEMENCIA II PARTE',
#    'CodigoEstado': 6},
#   {'Codigo': '1641-10139-SE21',
#    'Nombre': 'MGM CP 11/2021BAJADA EPIDU.MICROVOL 1641-268-LP19',
#    'CodigoEstado': 12},
#   {'Codigo': '1641-12038-SE21',
#    'Nombre': 'drm/MEL 2021/LETREROS LED',
#    'CodigoEstado': 12},
#   {'Codigo': '1641-15-CM22',
#    'Nombre': 'moc PROGRAMA INSUMOS ROPERIA 2239-16-LR15 Órtesis, Prótesis, Endoprótesis e Insumos de Salud',
#    'CodigoEstado': 12},
#   {'Codigo': '1641-7723-SE21',
#    'Nombre': 'MGM CNP N°35699 BALON PERIFERICO L1641-140-LR20',
#    'CodigoEstado': 12},
#   {'Codigo': '1658-2795-SE21',
#    'Nombre': 'ORDEN DE COMPRA DESDE 1658-580-LQ21',
#    'CodigoEstado': 6},
#   {'Codigo': '1718-4-AG22',
#    'Nombre': 'Orden de Compra generada por invitación a compra ágil: 1718-362-COT21',
#    'CodigoEstado': 6},
#   {'Codigo': '2065-960-SE21',
#    'Nombre': 'LIC: LENTES ÓPTICOS. ',
#    'CodigoEstado': 6},
#   {'Codigo': '2085-1332-SE21',
#    'Nombre': 'TD COMPRA DE EQUIPOS DE AIRE ACONDICIONADO PARA EL',
#    'CodigoEstado': 9},
#   {'Codigo': '2385-2-SE22',
#    'Nombre': 'COMPRA DE ALIMENTO PARA CANINOS (ORDEN DE COMPRA DESDE 2385-33-LE21)',
#    'CodigoEstado': 6},
#   {'Codigo': '2594-8-AG22',
#    'Nombre': 'UTILES DE ASEO PLAYA AMARILLA Orden de Compra generada por invitación a compra ágil: 2594-7-COT22',
#    'CodigoEstado': 6},
#   {'Codigo': '2667-11-SE22',
#    'Nombre': 'SERVICIO DE ASISTENCIA TECNICA PARA EVENTO',
#    'CodigoEstado': 6},
#   {'Codigo': '2669-808-SE21',
#    'Nombre': 'PTR SVB N°252 DE FECHA 14/10/2021 - (NOVOFARMA SERVICE S A - Axon-Pharma) RESOLUCION Nº 942 DE FECHA 07/12/2021 - MEDICAMENTOS FALTANTES VITABOTICA OCTUBRE 1.29 - OC DESDE LICITACION 2669-328-L121',
#    'CodigoEstado': 6},
#   {'Codigo': '2766-5-SE22', 'Nombre': 'AXON 05-01-2022', 'CodigoEstado': 6},
#   {'Codigo': '3143-5-SE22',
#    'Nombre': 'EXTRACCIÓN DE BASURA DOMICILIARIA  Y MANTENCIÓN DE EX VERTEDERO ',
#    'CodigoEstado': 6},
#   {'Codigo': '3143-7-SE22',
#    'Nombre': 'MANTENCIÓN DE CALLES Y CAMINOS',
#    'CodigoEstado': 6},
#   {'Codigo': '3143-8-SE22',
#    'Nombre': 'MEJORAMIENTO SISTEMAS DE AGUA RURAL',
#    'CodigoEstado': 6},
#   {'Codigo': '3502-870-SE21',
#    'Nombre': 'DAEX 2660 CONSTRUCCION ABASTO DE AGUA POTABLE COMUNIDAD LEFUELUAN ORDEN DE COMPRA DESDE 3502-96-H221',
#    'CodigoEstado': 6},
#   {'Codigo': '3504-27-SE22',
#    'Nombre': 'MATERIALES DE OFICINA PARA DEPARTAMENTO DE FINANZA',
#    'CodigoEstado': 6},
#   {'Codigo': '3512-7-SE22',
#    'Nombre': 'AMPLIFICACIÓN ACT. PROYECTO BORDE RÍO, ILLAPEL',
#    'CodigoEstado': 6},
#   {'Codigo': '425-3-CM22', 'Nombre': 'Orden de Compra', 'CodigoEstado': 6},
#   {'Codigo': '4499-278-AG21',
#    'Nombre': 'Adquisición de Artículos Publicitarios(M-743/Salud)',
#    'CodigoEstado': 9},
#   {'Codigo': '5428-1-SE22',
#    'Nombre': 'Medallas Profesora Titular y Profesor Titular 2019',
#    'CodigoEstado': 12},
#   {'Codigo': '5562-60-SE21',
#    'Nombre': 'ORDEN DE COMPRA DESDE 5562-5-L121',
#    'CodigoEstado': 12},
#   {'Codigo': '5586-55-AG22',
#    'Nombre': 'Orden de Compra generada por invitación a compra ágil: 5586-4-COT22',
#    'CodigoEstado': 6},
#   {'Codigo': '5610-748-AG21',
#    'Nombre': 'ALCOHOL 70º- ALCOHOL DE QUEMAR ',
#    'CodigoEstado': 6},
#   {'Codigo': '5626-592-SE21',
#    'Nombre': 'IMPRESION CNCA‐ Folio 491825 - E.PFEIFFER',
#    'CodigoEstado': 6},
#   {'Codigo': '626529-1-AG22',
#    'Nombre': 'Servicio Producción Evento Campeonato de Cueca Abierto (M-09/DIDECO) OC generada por invitación a compra ágil: 626529-1-COT22',
#    'CodigoEstado': 6},
#   {'Codigo': '761-395-CM21', 'Nombre': 'Orden de Compra', 'CodigoEstado': 12},
#   {'Codigo': '800-30-SE22', 'Nombre': 'CONSUMO ENERO ', 'CodigoEstado': 6},
#   {'Codigo': '842082-100-AG21',
#    'Nombre': 'Orden de Compra generada por invitación a compra ágil: 842082-49-COT21',
#    'CodigoEstado': 12},
#   {'Codigo': '842082-105-AG21',
#    'Nombre': 'Orden de Compra generada por invitación a compra ágil: 842082-52-COT21',
#    'CodigoEstado': 12},
#   {'Codigo': '842082-111-SE21',
#    'Nombre': 'COMPRA FAJAS RACHET Y CYALUME',
#    'CodigoEstado': 12},
#   {'Codigo': '842082-115-SE21',
#    'Nombre': 'COMPRA REPUESTO',
#    'CodigoEstado': 12},
#   {'Codigo': '842082-83-AG21',
#    'Nombre': 'Orden de Compra generada por invitación a compra ágil: 842082-38-COT21',
#    'CodigoEstado': 12},
#   {'Codigo': '842082-93-AG21',
#    'Nombre': 'Orden de Compra generada por invitación a compra ágil: 842082-45-COT21',
#    'CodigoEstado': 12},
#   {'Codigo': '986278-1-SE21',
#    'Nombre': 'Seguro Vehículo Institucional',
#    'CodigoEstado': 12},
#   {'Codigo': '986278-26-SE21',
#    'Nombre': 'ORDEN DE COMPRA DESDE 986278-3-LE21',
#    'CodigoEstado': 12},
#   {'Codigo': '1057441-7024-SE21',
#    'Nombre': 'COLACIONES INDIVIDUALES',
#    'CodigoEstado': 12},
#   {'Codigo': '1057510-91-AG22',
#    'Nombre': 'MANTENCION PREVENTIVA EXTINTORES',
#    'CodigoEstado': 6},
#   {'Codigo': '1058036-630-AG21',
#    'Nombre': 'Medicamento Metilprednisolona',
#    'CodigoEstado': 12},
#   {'Codigo': '1058045-1699-SE21',
#    'Nombre': 'ORDEN DE COMPRA DESDE 1058045-10-LQ21',
#    'CodigoEstado': 12},
#   {'Codigo': '1063535-40-SE22', 'Nombre': 'FARMACOS ENERO', 'CodigoEstado': 6},
#   {'Codigo': '1172239-193-SE21',
#    'Nombre': 'CJS - TD  VALORACIÓN MEDICA MEDICINA FAMILIAR PIE',
#    'CodigoEstado': 12},
#   {'Codigo': '1381-831-SE21',
#    'Nombre': 'ORDEN DE COMPRA DESDE 1175-44-LE21',
#    'CodigoEstado': 6},
#   {'Codigo': '1641-12098-AG21',
#    'Nombre': 'drm/MEL 2021/COMPRA AGIL: 1641-1046-COT21',
#    'CodigoEstado': 12},
#   {'Codigo': '1641-12657-SE21',
#    'Nombre': 'HBH/RES EXENTA XXX/ MONITOR CARDIOFETAL/ GINECOLOGIA/ DICIEMBRE 2021',
#    'CodigoEstado': 12},
#   {'Codigo': '1641-41-SE22',
#    'Nombre': 'TDP-CP-012022-JERINGA INSUFLADORA-1641-101-LQ20',
#    'CodigoEstado': 12},
#   {'Codigo': '1641-5918-SE21',
#    'Nombre': 'TDP-CNP N°33755-STENT CORONARIO CON DROGA-1641-133-LR20',
#    'CodigoEstado': 12},
#   {'Codigo': '2280-5-AG22',
#    'Nombre': '5, SP 20000 - MOVAMONOS 2019 - CEIA LUIS MOLL BRIONES - RENOVACIÓN DE PISOS. Orden de Compra generada por invitación a compra ágil: 2280-1-COT22',
#    'CodigoEstado': 6},
#   {'Codigo': '2282-275-SE21',
#    'Nombre': 'PP.457-2021, CONSERVACION S.C Y J.I. LOS AVELLANOS DESDE 2282-182-LP21',
#    'CodigoEstado': 6},
#   {'Codigo': '2332-8-AG22',
#    'Nombre': 'ARRIENDO 02 VEHCÍCULOS - DISAM PM',
#    'CodigoEstado': 6},
#   {'Codigo': '3203-6-AG22',
#    'Nombre': 'Orden de Compra generada por invitación a compra ágil: 3203-6-COT22',
#    'CodigoEstado': 6},
#   {'Codigo': '3516-884-SE21',
#    'Nombre': 'Arriendo de Camión aljibe para suministro de agua',
#    'CodigoEstado': 6},
#   {'Codigo': '3595-586-SE21',
#    'Nombre': '“Adquisición Equipamiento Computacional”',
#    'CodigoEstado': 12},
#   {'Codigo': '3653-3-AG22',
#    'Nombre': 'Compra Estímulos / Extraescolar DAEM.',
#    'CodigoEstado': 6},
#   {'Codigo': '425-4-CM22', 'Nombre': 'Orden de Compra', 'CodigoEstado': 6},
#   {'Codigo': '4355-1018-AG21',
#    'Nombre': 'Orden de Compra generada por invitación a compra ágil: 4355-374-COT21',
#    'CodigoEstado': 6},
#   {'Codigo': '4364-19-AG22',
#    'Nombre': 'Adquisición de Material eléctricos, Esc. Paso El Roble',
#    'CodigoEstado': 6},
#   {'Codigo': '4548-590-SE21',
#    'Nombre': 'ORDEN DE COMPRA DESDE 4548-79-LE21',
#    'CodigoEstado': 6},
#   {'Codigo': '4595-11-SE22',
#    'Nombre': 'ORDEN DE COMPRA DESDE 4595-21-LE21',
#    'CodigoEstado': 6},
#   {'Codigo': '625-1525-AG21',
#    'Nombre': 'Orden de Compra generada por invitación a compra ágil: 625-326-COT21',
#    'CodigoEstado': 6},
#   {'Codigo': '812030-2259-AG21',
#    'Nombre': 'Orden de Compra generada por invitación a compra ágil: 812030-1634-COT21',
#    'CodigoEstado': 9},
#   {'Codigo': '842082-106-AG21',
#    'Nombre': 'Orden de Compra generada por invitación a compra ágil: 842082-55-COT21',
#    'CodigoEstado': 12},
#   {'Codigo': '842082-119-AG21',
#    'Nombre': 'Orden de Compra generada por invitación a compra ágil: 842082-60-COT21',
#    'CodigoEstado': 12},
#   {'Codigo': '842082-91-SE21',
#    'Nombre': 'ORDEN DE COMPRA DESDE 842082-3-R121',
#    'CodigoEstado': 12},
#   {'Codigo': '842082-92-AG21',
#    'Nombre': 'Orden de Compra generada por invitación a compra ágil: 842082-40-COT21',
#    'CodigoEstado': 12},
#   {'Codigo': '986278-131-CM21',
#    'Nombre': '2239-13-lp14 Convenio Marco Pasajes Aéreos Nacionales e Internacionales',
#    'CodigoEstado': 12},
#   {'Codigo': '986278-132-CM21',
#    'Nombre': 'Orden de Compra',
#    'CodigoEstado': 12},
#   {'Codigo': '986278-45-SE21',
#    'Nombre': 'ORDEN DE COMPRA DESDE 986278-7-LE21',
#    'CodigoEstado': 12}]}

# %% [markdown]
# ### Ejercicio 4

# %% [markdown]
# Obtener las estrellas y issues del repositorio scikit-learn/scikit-learn usando la librería PyGithub

# %%
# !pip install PyGithub
# Out:
# Collecting PyGithub
#   Downloading PyGithub-1.57-py3-none-any.whl (297 kB)
# Requirement already satisfied: pynacl>=1.4.0 in c:\users\pablo\anaconda3\lib\site-packages (from PyGithub) (1.4.0)
# Requirement already satisfied: pyjwt>=2.4.0 in c:\users\pablo\anaconda3\lib\site-packages (from PyGithub) (2.4.0)
# Collecting deprecated
#   Downloading Deprecated-1.2.13-py2.py3-none-any.whl (9.6 kB)
# Requirement already satisfied: requests>=2.14.0 in c:\users\pablo\anaconda3\lib\site-packages (from PyGithub) (2.27.1)
# Requirement already satisfied: six in c:\users\pablo\anaconda3\lib\site-packages (from pynacl>=1.4.0->PyGithub) (1.16.0)
# Requirement already satisfied: cffi>=1.4.1 in c:\users\pablo\anaconda3\lib\site-packages (from pynacl>=1.4.0->PyGithub) (1.15.0)
# Requirement already satisfied: pycparser in c:\users\pablo\anaconda3\lib\site-packages (from cffi>=1.4.1->pynacl>=1.4.0->PyGithub) (2.21)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\pablo\anaconda3\lib\site-packages (from requests>=2.14.0->PyGithub) (2.0.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\pablo\anaconda3\lib\site-packages (from requests>=2.14.0->PyGithub) (1.26.9)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\pablo\anaconda3\lib\site-packages (from requests>=2.14.0->PyGithub) (2021.10.8)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\pablo\anaconda3\lib\site-packages (from requests>=2.14.0->PyGithub) (3.3)
# Requirement already satisfied: wrapt<2,>=1.10 in c:\users\pablo\anaconda3\lib\site-packages (from deprecated->PyGithub) (1.12.1)
# Installing collected packages: deprecated, PyGithub
# Successfully installed PyGithub-1.57 deprecated-1.2.13

# %%
from github import Github
g = Github()
repo = g.get_repo("scikit-learn/scikit-learn")
print('Cantidad de estrellas:', repo.stargazers_count)

open_issues = repo.get_issues(state='open')
for issue in open_issues:
    print(issue)
    break
# Out:
# Cantidad de estrellas: 52229
# Issue(title="MAINT Remove `_arr` suffixes from `_binary_tree`", number=25106)

# %% [markdown]
# ### Ejercicio 5

# %% [markdown]
# Listar los últimos tweets de la cuenta AnidInforma con la librería tweepy

# %%
# !pip install tweepy

# %%
bearer = ""

# %%
import tweepy

# autenticarse
client = tweepy.Client(bearer)

# extraer id de usuario AnidInforma

users = client.get_users(usernames=['AnidInforma'])

user_id = users.data[0].id

# extraer los ultimos tweets de AnidInforma

response = client.get_users_tweets(user_id)

# Por defecto, solo se extrae id y text de los 10 ultimos tweets
for tweet in response.data:
    print(tweet.id)
    print(tweet.text)

# %% [markdown]
# ### Ejercicio 6

# %% [markdown]
# Lista 10 tweets de 10 seguidores de AnidInforma
