# %% [markdown]
# ## APIs

# %% [markdown]
# ### Ejercicio 1

# %%
import requests
import json

## https://pokedevs.gitbook.io/pokedex/resources/pokemon

r = requests.get('https://pokeapi.glitch.me/v1/pokemon/pikachu')

# %%
data = r.json()
data
# Out:
# [{'number': '25',
#   'name': 'Pikachu',
#   'species': 'Mouse',
#   'types': ['Electric'],
#   'abilities': {'normal': ['Static'], 'hidden': ['Lightning Rod']},
#   'eggGroups': ['Field', 'Fairy'],
#   'gender': [50, 50],
#   'height': '1\'04"',
#   'weight': '13.2 lbs.',
#   'family': {'id': 10,
#    'evolutionStage': 2,
#    'evolutionLine': ['Pichu', 'Pikachu', 'Raichu']},
#   'starter': False,
#   'legendary': False,
#   'mythical': False,
#   'ultraBeast': False,
#   'mega': False,
#   'gen': 1,
#   'sprite': 'https://nexus.traction.one/images/pokemon/pokemon/25.png',
#   'description': 'When it is angered, it immediately discharges the energy stored in the pouches in its cheeks.'}]

# %%
from IPython.display import Image
from IPython.core.display import HTML 
Image(url= data[0]['sprite'])
# Out:
# <img src="https://nexus.traction.one/images/pokemon/pokemon/25.png"/>

# %% [markdown]
# Obtener la lista de feriados de la API de https://www.feriadosapp.com/api/holidays.json

# %%
r = requests.get('https://www.feriadosapp.com/api/holidays.json')
feriados = json.loads(r.text)

# %%
feriados
# Out:
# {'status': 'success',
#  'data': [{'date': '2023-01-01',
#    'title': 'Año Nuevo',
#    'type': 'Civil',
#    'inalienable': True,
#    'extra': 'Civil e Irrenunciable'},
#   {'date': '2023-01-02',
#    'title': 'Feriado Adicional',
#    'type': 'Civil',
#    'inalienable': False,
#    'extra': 'Civil'},
#   {'date': '2023-04-07',
#    'title': 'Viernes Santo',
#    'type': 'Religioso',
#    'inalienable': False,
#    'extra': 'Religioso'},
#   {'date': '2023-04-08',
#    'title': 'Sábado Santo',
#    'type': 'Religioso',
#    'inalienable': False,
#    'extra': 'Religioso'},
#   {'date': '2023-05-01',
#    'title': 'Día Nacional del Trabajo',
#    'type': 'Civil',
#    'inalienable': True,
#    'extra': 'Civil e Irrenunciable'},
#   {'date': '2023-05-21',
#    'title': 'Día de las Glorias Navales',
#    'type': 'Civil',
#    'inalienable': False,
#    'extra': 'Civil'},
#   {'date': '2023-06-21',
#    'title': 'Día Nacional de los Pueblos Indígenas',
#    'type': 'Civil',
#    'inalienable': False,
#    'extra': 'Civil'},
#   {'date': '2023-06-26',
#    'title': 'San Pedro y San Pablo',
#    'type': 'Religioso',
#    'inalienable': False,
#    'extra': 'Religioso'},
#   {'date': '2023-07-16',
#    'title': 'Día de la Virgen del Carmen',
#    'type': 'Religioso',
#    'inalienable': False,
#    'extra': 'Religioso'},
#   {'date': '2023-08-15',
#    'title': 'Asunción de la Virgen',
#    'type': 'Religioso',
#    'inalienable': False,
#    'extra': 'Religioso'},
#   {'date': '2023-09-18',
#    'title': 'Independencia Nacional',
#    'type': 'Civil',
#    'inalienable': True,
#    'extra': 'Civil e Irrenunciable'},
#   {'date': '2023-09-19',
#    'title': 'Día de las Glorias del Ejército',
#    'type': 'Civil',
#    'inalienable': True,
#    'extra': 'Civil e Irrenunciable'},
#   {'date': '2023-10-09',
#    'title': 'Encuentro de Dos Mundos',
#    'type': 'Civil',
#    'inalienable': False,
#    'extra': 'Civil'},
#   {'date': '2023-10-27',
#    'title': 'Día de las Iglesias Evangélicas y\nProtestantes',
#    'type': 'Religioso',
#    'inalienable': False,
#    'extra': 'Religioso'},
#   {'date': '2023-11-01',
#    'title': 'Día de Todos los Santos',
#    'type': 'Religioso',
#    'inalienable': False,
#    'extra': 'Religioso'},
#   {'date': '2023-12-08',
#    'title': 'Inmaculada Concepción',
#    'type': 'Religioso',
#    'inalienable': False,
#    'extra': 'Religioso'},
#   {'date': '2023-12-25',
#    'title': 'Navidad',
#    'type': 'Religioso',
#    'inalienable': True,
#    'extra': 'Religioso e Irrenunciable'}]}

# %%
import pandas as pd

for f in feriados['data']:
    print(f['date'], f['title'], f['extra'])
    
pd.DataFrame(feriados['data'])
# Out:
# 2023-01-01 Año Nuevo Civil e Irrenunciable
# 2023-01-02 Feriado Adicional Civil
# 2023-04-07 Viernes Santo Religioso
# 2023-04-08 Sábado Santo Religioso
# 2023-05-01 Día Nacional del Trabajo Civil e Irrenunciable
# 2023-05-21 Día de las Glorias Navales Civil
# 2023-06-21 Día Nacional de los Pueblos Indígenas Civil
# 2023-06-26 San Pedro y San Pablo Religioso
# 2023-07-16 Día de la Virgen del Carmen Religioso
# 2023-08-15 Asunción de la Virgen Religioso
# 2023-09-18 Independencia Nacional Civil e Irrenunciable
# 2023-09-19 Día de las Glorias del Ejército Civil e Irrenunciable
# 2023-10-09 Encuentro de Dos Mundos Civil
# 2023-10-27 Día de las Iglesias Evangélicas y
# Protestantes Religioso
# 2023-11-01 Día de Todos los Santos Religioso
# 2023-12-08 Inmaculada Concepción Religioso
# 2023-12-25 Navidad Religioso e Irrenunciable
#           date                                            title       type  \
# 0   2023-01-01                                        Año Nuevo      Civil
# 1   2023-01-02                                Feriado Adicional      Civil
# 2   2023-04-07                                    Viernes Santo  Religioso
# 3   2023-04-08                                     Sábado Santo  Religioso
# 4   2023-05-01                         Día Nacional del Trabajo      Civil
# 5   2023-05-21                       Día de las Glorias Navales      Civil
# 6   2023-06-21            Día Nacional de los Pueblos Indígenas      Civil
# 7   2023-06-26                            San Pedro y San Pablo  Religioso
# 8   2023-07-16                      Día de la Virgen del Carmen  Religioso
# 9   2023-08-15                            Asunción de la Virgen  Religioso
# 10  2023-09-18                           Independencia Nacional      Civil
# 11  2023-09-19                  Día de las Glorias del Ejército      Civil
# 12  2023-10-09                          Encuentro de Dos Mundos      Civil
# 13  2023-10-27  Día de las Iglesias Evangélicas y\nProtestantes  Religioso
# 14  2023-11-01                          Día de Todos los Santos  Religioso
# 15  2023-12-08                            Inmaculada Concepción  Religioso
# 16  2023-12-25                                          Navidad  Religioso
#
#     inalienable                      extra
# 0          True      Civil e Irrenunciable
# 1         False                      Civil
# 2         False                  Religioso
# 3         False                  Religioso
# 4          True      Civil e Irrenunciable
# 5         False                      Civil
# 6         False                      Civil
# 7         False                  Religioso
# 8         False                  Religioso
# 9         False                  Religioso
# 10         True      Civil e Irrenunciable
# 11         True      Civil e Irrenunciable
# 12        False                      Civil
# 13        False                  Religioso
# 14        False                  Religioso
# 15        False                  Religioso
# 16         True  Religioso e Irrenunciable

# %% [markdown]
# ### Ejercicio 2

# %% [markdown]
# Obtener las 10 últimas leyes chilenas de la API https://www.leychile.cl/Consulta/legislacion_abierta_web_service y crear un dataframe con ellas

# %%
import requests
from xml.etree import ElementTree as ET

payload = {
    'opt': 3,
    'cantidad': 10
}

r = requests.get('https://www.leychile.cl/Consulta/obtxml', params=payload)
tree = ET.fromstring(r.text)

# %%
for n in tree:
    print(n)
    for elem in n:
        print(elem.tag)
    break
# Out:
# <Element 'NORMA' at 0x0000017B4D8FA680>
# TIPOS_NUMEROS
# FECHA_PUBLICACION
# FECHA_PROMULGACION
# TITULO
# ORGANISMOS
# HISTORIASLEY
# TEXTO

# %%
for n in tree:
    for elem in n:
        print(elem.tag, elem.text)
# Out:
# TIPOS_NUMEROS None
# FECHA_PUBLICACION 2023-01-04
# FECHA_PROMULGACION 2022-12-27
# TITULO MODIFICA LA CARTA FUNDAMENTAL PARA RESTABLECER EL VOTO OBLIGATORIO EN LAS ELECCIONES POPULARES
# ORGANISMOS None
# HISTORIASLEY None
# TEXTO LEY NÚM. 21.524
#
# MODIFICA LA CARTA FUNDAMENTAL PARA RESTABLECER EL VOTO OBLIGATORIO EN LAS ELECCIONES POPULARES
#
#      Teniendo presente que el H. Congreso Nacional ha dado su aprobación al siguiente proyecto de ley iniciado en mociones refundidas; la primera, correspondiente al boletín N
# TIPOS_NUMEROS None
# FECHA_PUBLICACION 2022-12-28
# FECHA_PROMULGACION 2022-12-27
# TITULO OTORGA REAJUSTE DE REMUNERACIONES A LAS Y LOS TRABAJADORES DEL SECTOR PÚBLICO, CONCEDE AGUINALDOS QUE SEÑALA, CONCEDE OTROS BENEFICIOS QUE INDICA, Y MODIFICA DIVERSOS CUERPOS LEGALES
# ORGANISMOS None
# HISTORIASLEY None
# TEXTO
# LEY NÚM. 21.526
#
# OTORGA REAJUSTE DE REMUNERACIONES A LAS Y LOS TRABAJADORES DEL SECTOR PÚBLICO, CONCEDE AGUINALDOS QUE SEÑALA, CONCEDE OTROS BENEFICIOS QUE INDICA, Y MODIFICA DIVERSOS CUERPOS LEGALES
#
#      Teniendo presente que el H. Congreso Nacional ha dado su aprobación al siguiente
#
#      Proyec
# TIPOS_NUMEROS None
# FECHA_PUBLICACION 2022-12-31
# FECHA_PROMULGACION 2022-12-27
# TITULO PERMITE LA EXTRACCIÓN DE REMANENTES DE CUOTAS ANUALES DE CAPTURA NO CONSUMIDOS DURANTE 2022 PARA LOS RECURSOS Y REGIONES QUE INDICA
# ORGANISMOS None
# HISTORIASLEY None
# TEXTO
# LEY NÚM. 21.525
#
# PERMITE LA EXTRACCIÓN DE REMANENTES DE CUOTAS ANUALES DE CAPTURA NO CONSUMIDOS DURANTE 2022 PARA LOS RECURSOS Y REGIONES QUE INDICA
#
#      Teniendo presente que el H. Congreso Nacional ha dado su aprobación al siguiente proyecto de ley iniciado en moción del diputado señor Le
# TIPOS_NUMEROS None
# FECHA_PUBLICACION 2023-01-04
# FECHA_PROMULGACION 2022-12-22
# TITULO PROMUEVE LA COMPETENCIA E INCLUSIÓN FINANCIERA A TRAVÉS DE LA INNOVACIÓN Y TECNOLOGÍA EN LA PRESTACIÓN DE SERVICIOS FINANCIEROS, LEY FINTEC
# ORGANISMOS None
# HISTORIASLEY None
# TEXTO
# LEY NÚM. 21.521
#
# PROMUEVE LA COMPETENCIA E INCLUSIÓN FINANCIERA A TRAVÉS DE LA INNOVACIÓN Y TECNOLOGÍA EN LA PRESTACIÓN DE SERVICIOS FINANCIEROS, LEY FINTEC
#
#      Teniendo presente que el H. Congreso Nacional ha dado su aprobación al siguiente
#
#      Proyecto de ley:
# TIPOS_NUMEROS None
# FECHA_PUBLICACION 2022-12-30
# FECHA_PROMULGACION 2022-12-20
# TITULO INTRODUCE UN NUEVO PÁRRAFO EN EL TÍTULO VII DEL LIBRO II DEL CÓDIGO PENAL, RELATIVO A LA EXPLOTACIÓN SEXUAL COMERCIAL Y MATERIAL PORNOGRÁFICO DE NIÑOS, NIÑAS Y ADOLESCENTES
# ORGANISMOS None
# HISTORIASLEY None
# TEXTO
# LEY NÚM. 21.522
#
# INTRODUCE UN NUEVO PÁRRAFO EN EL TÍTULO VII DEL LIBRO II DEL CÓDIGO PENAL, RELATIVO A LA EXPLOTACIÓN SEXUAL COMERCIAL Y MATERIAL PORNOGRÁFICO DE NIÑOS, NIÑAS Y ADOLESCENTES
#
#      Teniendo presente que el H. Congreso Nacional ha dado su aprobación al siguiente
#
#
# TIPOS_NUMEROS None
# FECHA_PUBLICACION 2022-12-31
# FECHA_PROMULGACION 2022-12-19
# TITULO MODIFICA DIVERSOS CUERPOS LEGALES PARA MEJORAR LAS GARANTÍAS PROCESALES, PROTEGER LOS DERECHOS DE LAS VÍCTIMAS DE LOS DELITOS SEXUALES, Y EVITAR SU REVICTIMIZACIÓN
# ORGANISMOS None
# HISTORIASLEY None
# TEXTO
# LEY NÚM. 21.523
#
# MODIFICA DIVERSOS CUERPOS LEGALES PARA MEJORAR LAS GARANTÍAS PROCESALES, PROTEGER LOS DERECHOS DE LAS VÍCTIMAS DE LOS DELITOS SEXUALES, Y EVITAR SU REVICTIMIZACIÓN
#
#      Teniendo presente que el H. Congreso Nacional ha dado su aprobación al siguiente proyecto de ley ini
# TIPOS_NUMEROS None
# FECHA_PUBLICACION 2022-12-28
# FECHA_PROMULGACION 2022-12-16
# TITULO QUE MODIFICA DIVERSOS CUERPOS LEGALES PARA ESTABLECER LA MAYORÍA DE EDAD COMO REQUISITO ESENCIAL PARA LA CELEBRACIÓN DEL MATRIMONIO
# ORGANISMOS None
# HISTORIASLEY None
# TEXTO
# LEY NÚM. 21.515
#
# QUE MODIFICA DIVERSOS CUERPOS LEGALES PARA ESTABLECER LA MAYORÍA DE EDAD COMO REQUISITO ESENCIAL PARA LA CELEBRACIÓN DEL MATRIMONIO
#
#      Teniendo presente que el H. Congreso Nacional ha dado su aprobación al siguiente proyecto de ley iniciado en moción de las diputadas
# TIPOS_NUMEROS None
# FECHA_PUBLICACION 2022-12-29
# FECHA_PROMULGACION 2022-12-16
# TITULO ESTABLECE EL DÍA NACIONAL DE LA DIVERSIDAD
# ORGANISMOS None
# HISTORIASLEY None
# TEXTO
# LEY NÚM. 21.511
#
# ESTABLECE EL DÍA NACIONAL DE LA DIVERSIDAD
#
#      Teniendo presente que el H. Congreso Nacional ha dado su aprobación al siguiente proyecto de ley iniciado en moción de los exdiputados Aldo Cornejo González, Gabriel Ascencio Mansilla, Roberto León Ramírez, Pablo Lorenzini Bas
# TIPOS_NUMEROS None
# FECHA_PUBLICACION 2022-12-20
# FECHA_PROMULGACION 2022-12-07
# TITULO LEY DE PRESUPUESTO DE INGRESOS Y GASTOS DEL SECTOR PÚBLICO PARA EL AÑO 2023
# ORGANISMOS None
# HISTORIASLEY None
# TEXTO
# LEY NÚM. 21.516
#
# LEY DE PRESUPUESTO DE INGRESOS Y GASTOS DEL SECTOR PÚBLICO PARA EL AÑO 2023
#
#      Teniendo presente que el H. Congreso Nacional ha dado su aprobación al siguiente
#
#      Proyecto de ley:
#
# TIPOS_NUMEROS None
# FECHA_PUBLICACION 2022-12-14
# FECHA_PROMULGACION 2022-12-05
# TITULO MODIFICA LEY N° 20.998 QUE REGULA LOS SERVICIOS SANITARIOS RURALES PARA AJUSTAR SUS REQUISITOS Y PLAZOS DE IMPLEMENTACIÓN
# ORGANISMOS None
# HISTORIASLEY None
# TEXTO
# LEY NÚM. 21.520
#
# MODIFICA LEY N° 20.998 QUE REGULA LOS SERVICIOS SANITARIOS RURALES PARA AJUSTAR SUS REQUISITOS Y PLAZOS DE IMPLEMENTACIÓN
#
#      Teniendo presente que el H. Congreso Nacional ha dado su aprobación al siguiente
#
#      Proyecto de ley:

# %%
# !pip install xmljson
# Out:
# Collecting xmljson
#   Using cached xmljson-0.2.1-py2.py3-none-any.whl (10 kB)
# Installing collected packages: xmljson
# Successfully installed xmljson-0.2.1

# %%
import pandas as pd        
import xmljson 

jsontree = xmljson.parker.data(tree)['NORMA']
pd.DataFrame(jsontree)
# Out:
#                                        TIPOS_NUMEROS FECHA_PUBLICACION  \
# 0  {'TIPO_NUMERO': {'TIPO': 'XX1', 'NUMERO': 2152...        2023-01-04
# 1  {'TIPO_NUMERO': {'TIPO': 'XX1', 'NUMERO': 2152...        2022-12-28
# 2  {'TIPO_NUMERO': {'TIPO': 'XX1', 'NUMERO': 2152...        2022-12-31
# 3  {'TIPO_NUMERO': {'TIPO': 'XX1', 'NUMERO': 2152...        2023-01-04
# 4  {'TIPO_NUMERO': {'TIPO': 'XX1', 'NUMERO': 2152...        2022-12-30
# 5  {'TIPO_NUMERO': {'TIPO': 'XX1', 'NUMERO': 2152...        2022-12-31
# 6  {'TIPO_NUMERO': {'TIPO': 'XX1', 'NUMERO': 2151...        2022-12-28
# 7  {'TIPO_NUMERO': {'TIPO': 'XX1', 'NUMERO': 2151...        2022-12-29
# 8  {'TIPO_NUMERO': {'TIPO': 'XX1', 'NUMERO': 2151...        2022-12-20
# 9  {'TIPO_NUMERO': {'TIPO': 'XX1', 'NUMERO': 2152...        2022-12-14
#
#   FECHA_PROMULGACION                                             TITULO  \
# 0         2022-12-27  MODIFICA LA CARTA FUNDAMENTAL PARA RESTABLECER...
# 1         2022-12-27  OTORGA REAJUSTE DE REMUNERACIONES A LAS Y LOS ...
# 2         2022-12-27  PERMITE LA EXTRACCIÓN DE REMANENTES DE CUOTAS ...
# 3         2022-12-22  PROMUEVE LA COMPETENCIA E INCLUSIÓN FINANCIERA...
# 4         2022-12-20  INTRODUCE UN NUEVO PÁRRAFO EN EL TÍTULO VII DE...
# 5         2022-12-19  MODIFICA DIVERSOS CUERPOS LEGALES PARA MEJORAR...
# 6         2022-12-16  QUE MODIFICA DIVERSOS CUERPOS LEGALES PARA EST...
# 7         2022-12-16         ESTABLECE EL DÍA NACIONAL DE LA DIVERSIDAD
# 8         2022-12-07  LEY DE PRESUPUESTO DE INGRESOS Y GASTOS DEL SE...
# 9         2022-12-05  MODIFICA LEY N° 20.998 QUE REGULA LOS SERVICIO...
#
#                                           ORGANISMOS HISTORIASLEY  \
# 0  {'ORGANISMO': 'MINISTERIO SECRETARÍA GENERAL D...         None
# 1            {'ORGANISMO': 'MINISTERIO DE HACIENDA'}         None
# 2  {'ORGANISMO': 'MINISTERIO DE ECONOMÍA, FOMENTO...         None
# 3            {'ORGANISMO': 'MINISTERIO DE HACIENDA'}         None
# 4  {'ORGANISMO': 'MINISTERIO DE JUSTICIA Y DERECH...         None
# 5  {'ORGANISMO': 'MINISTERIO DE JUSTICIA Y DERECH...         None
# 6  {'ORGANISMO': 'MINISTERIO DE DESARROLLO SOCIAL...         None
# 7  {'ORGANISMO': 'MINISTERIO DE DESARROLLO SOCIAL...         None
# 8            {'ORGANISMO': 'MINISTERIO DE HACIENDA'}         None
# 9      {'ORGANISMO': 'MINISTERIO DE OBRAS PÚBLICAS'}         None
#
#                                                TEXTO
# 0  LEY NÚM. 21.524\n      \nMODIFICA LA CARTA FUN...
# 1  \nLEY NÚM. 21.526\n\nOTORGA REAJUSTE DE REMUNE...
# 2  \nLEY NÚM. 21.525\n      \nPERMITE LA EXTRACCI...
# 3  \nLEY NÚM. 21.521\n      \nPROMUEVE LA COMPETE...
# 4  \nLEY NÚM. 21.522\n      \nINTRODUCE UN NUEVO ...
# 5  \nLEY NÚM. 21.523\n      \nMODIFICA DIVERSOS C...
# 6  \nLEY NÚM. 21.515\n      \nQUE MODIFICA DIVERS...
# 7  \nLEY NÚM. 21.511\n \nESTABLECE EL DÍA NACIONA...
# 8  \nLEY NÚM. 21.516\n      \nLEY DE PRESUPUESTO ...
# 9  \nLEY NÚM. 21.520\n\nMODIFICA LEY N° 20.998 QU...

# %% [markdown]
# ### Ejercicio 3

# %% [markdown]
# Listar 2 ordenes de compra (incluyendo el monto de la OC) desde Mercado Público del día 9 de Enero del 2020

# %%
import requests
import time 
import pandas as pd

payload = {
    'fecha':'09012022',
    'ticket': '5C5EBE6A-54AC-4725-A0C3-9CA163F13255'
}

r = requests.get('https://api.mercadopublico.cl/servicios/v1/publico/ordenesdecompra.json', params=payload)

data = r.json()

ocs = []

for oc in data['Listado'][:2]:

    print(oc['Codigo'])
    payload = {
        'codigo':oc['Codigo'],
        'ticket':'F8537A18-8766-4DEF-9E59-426B4FEE2844'
    }
    r = requests.get('https://api.mercadopublico.cl/servicios/v1/publico/ordenesdecompra.json', params=payload)

    ocdata = r.json()
    monto = ocdata['Listado'][0]['Total']
    ocs.append({'codigo':oc['Codigo'], 'moto':monto})
    

df = pd.DataFrame(ocs)
# Out:
# 1057441-7024-SE21
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_7960\4071965326.py in <module>
#      24
#      25     ocdata = r.json()
# ---> 26     monto = ocdata['Listado'][0]['Total']
#      27     ocs.append({'codigo':oc['Codigo'], 'moto':monto})
#      28
#
# KeyError: 'Listado'

# %%
data

# %% [markdown]
# ### Ejercicio 4

# %% [markdown]
# Obtener las estrellas y issues del repositorio scikit-learn/scikit-learn usando la librería PyGithub

# %%
# !pip install PyGithub

# %%
from github import Github
g = Github()
repo = g.get_repo("scikit-learn/scikit-learn")
print('Cantidad de estrellas:', repo.stargazers_count)

open_issues = repo.get_issues(state='open')
for issue in open_issues:
    print(issue)
    break

# %% [markdown]
# ### Ejercicio 5

# %% [markdown]
# Listar los últimos tweets de la cuenta AnidInforma con la librería tweepy

# %%
# !pip install tweepy

# %%
bearer = ""

# %%
import tweepy

# autenticarse
client = tweepy.Client(bearer)

# extraer id de usuario AnidInforma

users = client.get_users(usernames=['AnidInforma'])

user_id = users.data[0].id

# extraer los ultimos tweets de AnidInforma

response = client.get_users_tweets(user_id)

# Por defecto, solo se extrae id y text de los 10 ultimos tweets
for tweet in response.data:
    print(tweet.id)
    print(tweet.text)

# %% [markdown]
# ### Ejercicio 6

# %% [markdown]
# Lista 10 tweets de 10 seguidores de AnidInforma
