# %%
Resumen Doc1 Tarea FInal

# %% [markdown]
# ### 1.- Filtrar y eliminar aquellas que no hayan ofertado por lo menos una vez en el periodo de tiempo definido.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
#  ### 2.- Coeficiente de Jaccard (modelo nulo?)

# %% [markdown]
# El coeficiente de Jaccard centrado mide la similitud entre las ofertas de dos empresas, teniendo en cuenta las probabilidades de ocurrencia de cada empresa. Formalmente, se puede calcular como:

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# donde:
#
# ![image.png](attachment:image.png)
#
# es 1 si la empresa i hizo una oferta para licitar t , siendo 0 en caso contrario;
#
# ![image-2.png](attachment:image-2.png)
#
# es la fracción de licitaciones en las que participó la empresa
#
# ![image-3.png](attachment:image-3.png)
#
# El segundo término de la ecuación proporciona el número esperado de observaciones cuando las ofertas de ambas empresas son independientes y se distribuyen de manera idéntica a través de un proceso de Bernoulli. Por lo tanto, el coeficiente de Jaccard centrado nos permite distinguir entre asociaciones positivas y negativas entre empresas, teniendo en cuenta su nivel de actividad individual.
#
# Finalmente, estimamos la significancia de lo observadoj
#
# ![image-4.png](attachment:image-4.png)
#
# para probar la hipótesis de que
#
# ![image-5.png](attachment:image-5.png)
#
# Con ese fin, iniciamos una distribución nula
#
# ![image-6.png](attachment:image-6.png)
#
# del coeficiente de Jaccard centrado para cada par de empresas generando un conjunto de 1000 aleatorizaciones de la red bipartita inicial. Los datos se aleatorizaron para garantizar que el número de ofertas observadas por empresa y por año se mantuviera constante, al mismo tiempo que se preservaba el número de empresas que presentaban ofertas en cada licitación. Luego, estimamos el
#
# ![image-7.png](attachment:image-7.png)
#
# de una cola asociado con
#
# ![image-8.png](attachment:image-8.png)
#
# calculando la probabilidad de la cola superior de obtener un valor igual o mayor que
#
# ![image-9.png](attachment:image-9.png)
#
# de la frecuencia acumulada de la distribución nula
#
# ![image-10.png](attachment:image-10.png)
#
# Se descartaron los enlaces con un
#
# ![image-11.png](attachment:image-11.png)
#
# superior a 0,05.
#
# La red de co-licitación empresa-empresa resultante contiene 1529 nodos y 12 892 aristas. Las relaciones se tratan como no dirigidas y no ponderadas. La red exhibe un grado promedio de 16,86, con un coeficiente de clúster de 0,52 (Newman et al. 2020 ) y 56 componentes conectados. La Figura  2 muestra que la Distribución de Grados (Fig. 2 a) decae exponencialmente con el grado, lo que sugiere que la mecánica subyacente de la licitación conjunta puede aproximarse mediante un proceso de asociación aleatoria (Albert y Barabási 2002 ). Se ha probado la distribución alternativa (p. ej., ley de potencia), pero se ha mostrado la peor probabilidad según los datos. Sin embargo, el coeficiente de agrupamiento promedio muestra una relación inversa de ley de potencia con el grado (Fig. 2b), sugiriendo la existencia de algún nivel de jerarquía en la estructura de la red. Cabe mencionar que el componente conectado más grande contiene 1141 nodos, 10630 aristas y un coeficiente de agrupamiento de 0,43.

# %% [markdown]
# ### 3.- Representación Gráfica de la Red

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Representación gráfica de la red Firma-Firma, que relaciona firmas con patrones de licitación similares. Para construir la red, solo consideramos las firmas más activas y las aristas con un índice de similitud de Jaccard significativo. Se representa el componente gigante con algunos componentes desconectados relevantes. Los nodos en el componente gigante están coloreados según una de las ocho comunidades principales (de 22) identificadas mediante el algoritmo de Louvain (Blondel et al. 2008). La partición de la red presentada logró una modularidad de 0,61. La categorización Norte y Sur de la ubicación de las empresas se usó aquí en un sentido más amplio y no debe confundirse con las Mesorregiones, que identificamos con sus nombres en portugués. Como referencia, el Norte incluye las Mesorregiones del Norte y Noroeste; mientras que el Sur incluye Sul y Centro Sul.
#
# La Figura  3 presenta el componente gigante de la red de co-licitación empresa-empresa. Utilizando el algoritmo de Louvain (Blondel et al. 2008 ) identificamos 22 comunidades con una modularidad de 0,66. Nos referimos a estas comunidades comoC1,C2, … ,C22, y están indexados en orden descendente con respecto a su tamaño. Para facilitar la lectura, hemos coloreado las ocho comunidades más grandes en la Fig.  3. Sin embargo, la alta modularidad de la red no sorprende y puede explicarse por el hecho de que la red representa principalmente a empresas competidoras que están especializadas en el suministro de diferentes servicios (obras, bienes, servicios, etc.) en diferentes regiones. Así, las comunidades más destacadas dividen la red en dos grandes grupos de empresas que actúan principalmente en las regiones norte (Roja, Azul y Verde) y sur (Morada y Amarilla) del estado de Ceará, pero también en contratos de suministro de Alimentos. servicios (Azul y Morado) u obras de construcción (Rojo y Amarillo). Curiosamente, las comunidades restantes operan a nivel estatal (Rosa y Celeste), y hay una comunidad en particular (Violeta) que opera exclusivamente en la mesorregión de Jaguaribe solo provee servicios de Alimentación.
#
# En algunos casos, las empresas forman subgrafos densamente conectados (p. ej.,C14). Estas estructuras pueden ser un primer indicador para señalar grupos de empresas que presenten un alto riesgo de colusión y manipulación de adquisiciones. Como tal, a continuación, exploramos posibles métricas adicionales para clasificar cada comunidad de firmas a través de su actividad con el fin de delimitar aún más qué grupos de firmas podrían merecer una investigación más profunda por parte de los funcionarios de auditoría.

# %% [markdown]
# ### 4.- Simpson

# %% [markdown]
# Comenzamos observando la diversidad regional en la que las empresas realizan sus actividades (por ejemplo, participar en licitaciones para suministrar servicios) y la diversidad del tipo de contratos por los que licitan. Mientras que una empresa con baja diversidad tanto en alcance regional como en tipo de contrato puede indicar simplemente una empresa que es estrecha tanto en alcance como en dominio; la existencia de grupos de empresas conectadas (es decir, una comunidad de empresas) que comparten una baja diversidad en ambas dimensiones puede resaltar un escenario más problemático. En particular, puede indicar las condiciones para que las empresas se coordinen y cooperen para controlar un mercado específico y un contexto regional, y debe investigarse con mayor discernimiento.
#
# Para ello estimamos el índice de diversidad de Simpson para cada comunidad. El índice de diversidad de Simpson (λ) mide la probabilidad de que dos elementos muestreados aleatoriamente de un conjunto compartan una característica dada en común. En ese sentido,λ = 0 se asocia con la mayor diversidad posible, y λ  = 1 con la diversidad más baja. Formalmente estimamos el índice de Simpson para cada comunidad como:
#
# ![image.png](attachment:image.png)
#
# donde:
#
# ![image-2.png](attachment:image-2.png)
#
# corresponde a la fracción de ofertas realizadas en un tipo de contrato de adquisición γ:{Consumibles Sanidad, Servicios, Construcción, Eventos, Alimentación, Combustibles,…} o mesorregiónγ:{Metropolinana, Norte, Sul, Noroeste,…} por las empresas en comunidadCi,∀ yo ∈ { 1 , 2 , ... , 21 , 22 }. La cantidad
#
# ![image-3.png](attachment:image-3.png)
#
# se normaliza por comunidad, de modo que
#
# ![image-4.png](attachment:image-4.png)
#
# Estimamos
#
# ![image-5.png](attachment:image-5.png)
#
# de forma independiente para cada comunidad (Ci), y para contratos según la región que emite la oferta y el tipo de contrato de licitación (por ejemplo, servicios, alimentos, arrendamiento, construcción, etc.). Nuestra elección del índice de Simpson sobre otras alternativas (p. ej., la entropía) se debe a su sencilla interpretación en nuestro contexto: la probabilidad de que dos ofertas realizadas por empresas dentro de la misma comunidad compartan la misma característica (p. ej., región o tipo de contrato).
#
#
# La Figura  4a ilustra las distribuciones empíricas
#
# ![image-6.png](attachment:image-6.png)
#
# (pagtCi) de la actividad de contratación para las diez comunidades más destacadas. Mostramos los resultados tanto para la distribución Regional de actividades como por Tipo de Contrato. Los colores azules indican una frecuencia relativa baja de ofertas, mientras que el rojo identifica una frecuencia alta. Estos indicadores permitieron inferir el grado de especialización y aglomeración de una comunidad. En particular, encontramos que la Comunidad 8 (C8) las actividades se aglomeran en una sola región (Jaguaribe) y las empresas se especializan en un tipo de contrato (Alimentación). La misma conclusión también se puede inferir de los altos niveles deλC8gato _ _, lo que significa que la Comunidad 8 tiene una baja diversidad de distribución de actividades. La Figura  4b compara las 22 comunidades en términos de los dos indicadores de diversidad definidos anteriormente. Encontramos una agrupación de comunidades en el cuadrante inferior izquierdo, un bajo nivel de aglomeración y especialización, que asociamos con mercados saludables compuestos por empresas que, en promedio, tienen una cartera diversificada de actividades y distribución regional. En contraste, en el cuadrante superior derecho, encontramos comunidades que dependían de contratos de adquisición de un solo tipo y aglomerados en un pequeño número de regiones.
