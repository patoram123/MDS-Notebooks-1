# %% [markdown]
# # Hackaton Ciencias de Redes
# ## Grupo 5
# - #### Patricio Ramirez
# - #### Carlos Bustamante
# - #### Victor Ortiz
# - #### Pablo Elgueta
#
# ## Tarea
#
# #### Objetivo General:
#     Determinar patrones potenciales de corrupción en compras públicas en Chile. Para esto, se disponibilizarán los datos de todos las licitaciones públicas en Chile entre 2014 y 2021. Deben elegir un periodo a estudiar y que los datos son pesados.
#
# #### 1) Análisis Exploratorio:
#     Puede incluir histogramas, relaciones bivariadas, correlaciones (coeficientes y figuras), etc.
# #### 2) Inferencia red:
#     Red bipartita, proyección unimodal de la red bipartita, modelos nulos para filtrar (phi correlation, randomización preservando grado, etc)
# #### 3) Descripción de la red:
#     Distribución de grados (antes y despues de filtrar), gráfico grado de nodo vs coeficiente de clustering, diámetro de la red, número de nodos, número de enlaces, densidad. Detección de comunidades, etc.
# #### 4) Identifiación de patrones de corrupción en la red:
#     El trabajo es abierto en términos de identificación de patrones, sin embargo, pueden usar lo siguiente:
# - 1) Índice de diversidad de simpson por comunidad (ver referencia 1)
# - 2) índice de entropía del buyer (oferente) (ver referncia 2)
# - 3) Licitaciones con solo 1 bider (ofertante) (ver referencia 1 y 2) [esto es uno de los indicadores de potencial
# riesgo de corrupción, ver CRI referencia 2 y 3]
# - 4) Coefcieinte de clustering competitivo (si trabajan con la red bipartita sin proyectar) (ver referencia 2)
# - 5) Datos externos si encuentan y alcanzan son bienvenidos.
# - 6) Otros.

# %% [markdown]
# ### Importación de Librerías

# %%
import pandas as pd
import numpy as np

import networkx as nx
from networkx.algorithms import bipartite

# %% [markdown]
# # Desarrollo de Proyecto

# %% [markdown]
# ## Objetivos e Hipotesis
#
# - ¿Existe una relación que se repita de forma sostenida entre Organismos Públicos y Privados, con los Proveedores para el periodo a analizar?(2020).
# - Desarrollo de una red bipartita para nuestro análisis.
# - Trabajar en base al componente gigante de la red.
# - Identificar patrones de corrupción en la red.

# %% [markdown]
# ### 1) Análisis Exploratorio:

# %%
df = pd.read_csv('lic2020_hackaton.csv', sep=',', encoding='latin_1')

# %%
df.head(3)
# Out:
#     Codigo                              Tipo de Adquisicion      Estado  \
# 0  8468777  Licitación Pública entre a 2000 y 5000 UTM (LQ)  Adjudicada
# 1  8468777  Licitación Pública entre a 2000 y 5000 UTM (LQ)  Adjudicada
# 2  8468777  Licitación Pública entre a 2000 y 5000 UTM (LQ)  Adjudicada
#
#    CodigoOrganismo                                    NombreOrganismo  \
# 0          1375151  HOSPITAL CLINICO METROPOLITANO LA FLORIDA DRA ...
# 1          1375151  HOSPITAL CLINICO METROPOLITANO LA FLORIDA DRA ...
# 2          1375151  HOSPITAL CLINICO METROPOLITANO LA FLORIDA DRA ...
#
#       RutUnidad ComunaUnidad FechaPublicacion  CodigoProductoONU  \
# 0  65.075.485-9          NaN       2020-01-21           51201806
# 1  65.075.485-9          NaN       2020-01-21           51201806
# 2  65.075.485-9          NaN       2020-01-21           51201806
#
#    RutProveedor                       NombreProveedor Moneda de la Oferta  \
# 0  76.432.529-K                 CSL Behring SpA Chile        Peso Chileno
# 1  96.945.670-2  NOVOFARMA SERVICE - LABORATORIO BAGO        Peso Chileno
# 2  96.582.310-7                    Grifols Chile S.A.        Peso Chileno
#
#   MontoLineaAdjudica Oferta seleccionada
# 0                  0     No Seleccionada
# 1                  0     No Seleccionada
# 2            1592000        Seleccionada

# %%
print('Cantidad de Nombres de Organismo:')
print(len(df['NombreOrganismo'].unique()))
print('\nCantidad de Codigos de Organismo:')
print(len(df['CodigoOrganismo'].unique()))
# Out:
# Cantidad de Nombres de Organismo:
# 859
#
# Cantidad de Codigos de Organismo:
# 871

# %% [markdown]
# - ###### Del análisis de datos, fué posible identificar que existen 2 grupos de nodos mediante los cuales es posible generar una Red Bipartita. El primer Grupo contempla las primeras columnas de datos que se encuentras asociadas a los Organismos estatales que generan las Licitaciones. Por otro lado, el conjunto de columnas de la izquierda corresponden a las Empresas participantes de las licitaciones.
#
# - ###### Dentro del análisis exploratiorio de los datos, fue posible identificar que las cantidades de CodigosOrganismos no coincidía con la de NombreOrganismos, lo cual eventualmente significaría que existen Organismos con más de un código asociado, lo que nos inclina por trabajar con los Nombres.
#
# - ###### Otra observación que pudimos identificar, es que algunas de las empresas que participan como oferentes, se en cuentran también dentro del listado de Organismos, estas corresponden a aquellas empresas estatales como universidades, las cuales poseen áreas de proyectos o investigación para el autofinanciamiento.

# %% [markdown]
# ### 2) Inferencia red:

# %% [markdown]
# #### Lista de Nodos de Organismos

# %%
lista_organismos = df['NombreOrganismo'].unique()
lista_organismos[0:5]
len(lista_organismos)
# Out:
# 859

# %% [markdown]
# #### Lista de Nodos de Empresas

# %%
lista_empresas = df['NombreProveedor'].unique()
lista_empresas[0:5]
len(lista_empresas)
# Out:
# 38663

# %% [markdown]
# #### Eliminar Nodos Preentes en Ambos Grupos de Nodos

# %%
del_empresas = []
for organismo in lista_organismos:
    for empresa in lista_empresas:
        if organismo == empresa:
            del_empresas.append(organismo)
del_empresas
# Out:
# ['UNIVERSIDAD DE MAGALLANES',
#  'UNIVERSIDAD DEL BIO BIO',
#  'UNIVERSIDAD DE ATACAMA',
#  'UNIVERSIDAD DE TALCA',
#  'UNIVERSIDAD DE LA FRONTERA',
#  'INSTITUTO FORESTAL',
#  'INSTITUTO DE FOMENTO PESQUERO']

# %%
for universidad in del_empresas:
    df = df[df['NombreProveedor'] != universidad]

# %%
lista_empresas = df['NombreProveedor'].unique()
len(lista_empresas)
# Out:
# 38656

# %% [markdown]
# #### Definición de Enlaces Empresas/Organismos

# %%
#df = df[df['ComunaUnidad'] == 'Santiago']  #'''Este código solo se usa para hacer pruebas por motivos de procesamiento'''
G = nx.Graph()
G.add_nodes_from(lista_empresas, bipartite=0)
G.add_nodes_from(lista_organismos,bipartite=1)

# %%
df.head(3)
# Out:
#     Codigo                              Tipo de Adquisicion      Estado  \
# 0  8468777  Licitación Pública entre a 2000 y 5000 UTM (LQ)  Adjudicada
# 1  8468777  Licitación Pública entre a 2000 y 5000 UTM (LQ)  Adjudicada
# 2  8468777  Licitación Pública entre a 2000 y 5000 UTM (LQ)  Adjudicada
#
#    CodigoOrganismo                                    NombreOrganismo  \
# 0          1375151  HOSPITAL CLINICO METROPOLITANO LA FLORIDA DRA ...
# 1          1375151  HOSPITAL CLINICO METROPOLITANO LA FLORIDA DRA ...
# 2          1375151  HOSPITAL CLINICO METROPOLITANO LA FLORIDA DRA ...
#
#       RutUnidad ComunaUnidad FechaPublicacion  CodigoProductoONU  \
# 0  65.075.485-9          NaN       2020-01-21           51201806
# 1  65.075.485-9          NaN       2020-01-21           51201806
# 2  65.075.485-9          NaN       2020-01-21           51201806
#
#    RutProveedor                       NombreProveedor Moneda de la Oferta  \
# 0  76.432.529-K                 CSL Behring SpA Chile        Peso Chileno
# 1  96.945.670-2  NOVOFARMA SERVICE - LABORATORIO BAGO        Peso Chileno
# 2  96.582.310-7                    Grifols Chile S.A.        Peso Chileno
#
#   MontoLineaAdjudica Oferta seleccionada
# 0                  0     No Seleccionada
# 1                  0     No Seleccionada
# 2            1592000        Seleccionada

# %%
pivot = pd.pivot_table(df, index=['NombreOrganismo','NombreProveedor'],values=['Oferta seleccionada'],aggfunc='count')
pivot = pivot.reset_index()
pivot.head()
# Out:
#                                      NombreOrganismo  \
# 0  AGENCIA CHILENA DE COOPERACION INTERNACIONAL P...
# 1  AGENCIA CHILENA DE COOPERACION INTERNACIONAL P...
# 2  AGENCIA CHILENA DE COOPERACION INTERNACIONAL P...
# 3  AGENCIA CHILENA DE COOPERACION INTERNACIONAL P...
# 4  AGENCIA CHILENA DE COOPERACION INTERNACIONAL P...
#
#                                      NombreProveedor  Oferta seleccionada
# 0                           ARTL CHILE AUDITORES SPA                    1
# 1  AdjudicaChile Consultora en Licitaciones Públicas                    1
# 2                                           Aiguasol                    2
# 3                                    Amelia Virginia                    1
# 4                                        Astral S.A.                    1

# %%
lista_tuplas_pesos = []

for i in pivot.to_numpy():
    lista_tuplas_pesos.append((i[0], i[1], i[2]))

# %%
lista_tuplas_pesos
# Out:
# [('AGENCIA CHILENA DE COOPERACION INTERNACIONAL PARA EL DESARROLLO',
#   'ARTL CHILE AUDITORES SPA',
#   1),
#  ('AGENCIA CHILENA DE COOPERACION INTERNACIONAL PARA EL DESARROLLO',
#   'AdjudicaChile Consultora en Licitaciones Públicas',
#   1),
#  ('AGENCIA CHILENA DE COOPERACION INTERNACIONAL PARA EL DESARROLLO',
#   'Aiguasol',
#   2),
#  ('AGENCIA CHILENA DE COOPERACION INTERNACIONAL PARA EL DESARROLLO',
#   'Amelia Virginia',
#   1),
#  ('AGENCIA CHILENA DE COOPERACION INTERNACIONAL PARA EL DESARROLLO',
#   'Astral S.A.',
#   1),
#  ('AGENCIA CHILENA DE COOPERACION INTERNACIONAL PARA EL DESARROLLO',
#   'Blanco Viajes Ltda.',
#   1),
#  ('AGENCIA CHILENA DE COOPERACION INTERNACIONAL PARA EL DESARROLLO',
#   'CONCORDE EXPRESS',
#   1),
#  ('AGENCIA CHILENA DE COOPERACION INTERNACIONAL PARA EL DESARROLLO',
#   'CVR Consultoría Ltda',
#   1),
#  ('AGENCIA CHILENA DE COOPERACION INTERNACIONAL PARA EL DESARROLLO',
#   'CYSCONSULTING',
#   1),
#  ('AGENCIA CHILENA DE COOPERACION INTERNACIONAL PARA EL DESARROLLO',
#   'Chileconsult',
#   1),
#  ('AGENCIA CHILENA DE COOPERACION INTERNACIONAL PARA EL DESARROLLO',
#   'Citytransfer',
#   1),
#  ('AGENCIA CHILENA DE COOPERACION INTERNACIONAL PARA EL DESARROLLO',
#   'Deuman ',
#   1),
#  ('AGENCIA CHILENA DE COOPERACION INTERNACIONAL PARA EL DESARROLLO',
#   'Docustore SpA',
#   2),
#  ('AGENCIA CHILENA DE COOPERACION INTERNACIONAL PARA EL DESARROLLO',
#   'EBP Chile SpA',
#   1),
#  ('AGENCIA CHILENA DE COOPERACION INTERNACIONAL PARA EL DESARROLLO',
#   'Fortunato y Asociados ',
#   1),
#  ('AGENCIA CHILENA DE COOPERACION INTERNACIONAL PARA EL DESARROLLO',
#   'GTD Teleductos',
#   1),
#  ('AGENCIA CHILENA DE COOPERACION INTERNACIONAL PARA EL DESARROLLO',
#   'Grato Language Solutions',
#   1),
#  ('AGENCIA CHILENA DE COOPERACION INTERNACIONAL PARA EL DESARROLLO',
#   'IC Traducciones',
#   1),
#  ('AGENCIA CHILENA DE COOPERACION INTERNACIONAL PARA EL DESARROLLO',
#   'IFX Networks',
#   1),
#  ('AGENCIA CHILENA DE COOPERACION INTERNACIONAL PARA EL DESARROLLO',
#   'INTERNATIONAL CENTER SPA',
#   1),
#  ('AGENCIA CHILENA DE COOPERACION INTERNACIONAL PARA EL DESARROLLO',
#   'Iron Mountain Chile S.A.',
#   2),
#  ('AGENCIA CHILENA DE COOPERACION INTERNACIONAL PARA EL DESARROLLO',
#   'JUST CONSULTING GROUP SPA',
#   1),
#  ('AGENCIA CHILENA DE COOPERACION INTERNACIONAL PARA EL DESARROLLO', 'KAM', 1),
#  ('AGENCIA CHILENA DE COOPERACION INTERNACIONAL PARA EL DESARROLLO',
#   'Orión 2000 S.A.',
#   1),
#  ('AGENCIA CHILENA DE COOPERACION INTERNACIONAL PARA EL DESARROLLO',
#   'PGA SONIDO E IMAGEN LTDA.',
#   1),
#  ('AGENCIA CHILENA DE COOPERACION INTERNACIONAL PARA EL DESARROLLO',
#   'PROME',
#   1),
#  ('AGENCIA CHILENA DE COOPERACION INTERNACIONAL PARA EL DESARROLLO',
#   'Pontificia Universidad Católica de Valparaíso',
#   1),
#  ('AGENCIA CHILENA DE COOPERACION INTERNACIONAL PARA EL DESARROLLO',
#   'Speech Asesoría en Idiomas',
#   1),
#  ('AGENCIA CHILENA DE COOPERACION INTERNACIONAL PARA EL DESARROLLO',
#   'T&I PROFESSIONALS',
#   1),
#  ('AGENCIA CHILENA DE COOPERACION INTERNACIONAL PARA EL DESARROLLO',
#   'TRANSPORTES QUOVADIS',
#   1),
#  ('AGENCIA CHILENA DE COOPERACION INTERNACIONAL PARA EL DESARROLLO',
#   'TRANSPORTES SANTIAGO S.A.',
#   1),
#  ('AGENCIA CHILENA DE COOPERACION INTERNACIONAL PARA EL DESARROLLO',
#   'Tomate Producciones',
#   1),
#  ('AGENCIA CHILENA DE COOPERACION INTERNACIONAL PARA EL DESARROLLO',
#   'Transportes Exclusive',
#   1),
#  ('AGENCIA CHILENA DE COOPERACION INTERNACIONAL PARA EL DESARROLLO',
#   'Victor',
#   2),
#  ('AGENCIA CHILENA DE COOPERACION INTERNACIONAL PARA EL DESARROLLO',
#   'Zenta Group',
#   1),
#  ('AGENCIA CHILENA DE COOPERACION INTERNACIONAL PARA EL DESARROLLO',
#   'escuela',
#   1),
#  ('AGENCIA CHILENA DE COOPERACION INTERNACIONAL PARA EL DESARROLLO',
#   'yankovic.net',
#   1),
#  ('AGENCIA CHILENA DE EFICIENCIA ENERGETICA',
#   'AHIMCO INGENIERIA Y CONSTRUCCION S.A.',
#   1),
#  ('AGENCIA CHILENA DE EFICIENCIA ENERGETICA', 'ALYLUZ ELECTRICIDAD', 1),
#  ('AGENCIA CHILENA DE EFICIENCIA ENERGETICA', 'ANCARE ENERGY SpA', 8),
#  ('AGENCIA CHILENA DE EFICIENCIA ENERGETICA', 'ANDES EMPRESAS', 1),
#  ('AGENCIA CHILENA DE EFICIENCIA ENERGETICA',
#   'ASGREEN INGENIERIA SUSTENTABLE',
#   1),
#  ('AGENCIA CHILENA DE EFICIENCIA ENERGETICA', 'Adevcom ltda', 1),
#  ('AGENCIA CHILENA DE EFICIENCIA ENERGETICA',
#   'AdjudicaChile Consultora en Licitaciones Públicas',
#   6),
#  ('AGENCIA CHILENA DE EFICIENCIA ENERGETICA', 'Aiguasol', 2),
#  ('AGENCIA CHILENA DE EFICIENCIA ENERGETICA',
#   'Alvarez y Vega Ingeniería Eléctrica Limitada',
#   2),
#  ('AGENCIA CHILENA DE EFICIENCIA ENERGETICA', 'Antü Energía', 1),
#  ('AGENCIA CHILENA DE EFICIENCIA ENERGETICA', 'Aristo Consultores', 2),
#  ('AGENCIA CHILENA DE EFICIENCIA ENERGETICA', 'CHILEMAX', 1),
#  ('AGENCIA CHILENA DE EFICIENCIA ENERGETICA', 'CITYMOVIL S.A.', 2),
#  ('AGENCIA CHILENA DE EFICIENCIA ENERGETICA', 'CLEVER GROUP LTDA', 1),
#  ('AGENCIA CHILENA DE EFICIENCIA ENERGETICA', 'COPEC S.A.', 1),
#  ('AGENCIA CHILENA DE EFICIENCIA ENERGETICA', 'COREAL SPA', 3),
#  ('AGENCIA CHILENA DE EFICIENCIA ENERGETICA', 'Cam Chile S.A.', 2),
#  ('AGENCIA CHILENA DE EFICIENCIA ENERGETICA', 'ChinaLed', 5),
#  ('AGENCIA CHILENA DE EFICIENCIA ENERGETICA', 'Citelum Chile', 4),
#  ('AGENCIA CHILENA DE EFICIENCIA ENERGETICA', 'Corporación Tu Clase', 1),
#  ('AGENCIA CHILENA DE EFICIENCIA ENERGETICA', 'Cristian Mauricio ', 3),
#  ('AGENCIA CHILENA DE EFICIENCIA ENERGETICA', 'Deuman ', 2),
#  ('AGENCIA CHILENA DE EFICIENCIA ENERGETICA', 'Dictuc S.A.', 2),
#  ('AGENCIA CHILENA DE EFICIENCIA ENERGETICA', 'DynamicLab', 1),
#  ('AGENCIA CHILENA DE EFICIENCIA ENERGETICA', 'ECO LIFE SA', 2),
#  ('AGENCIA CHILENA DE EFICIENCIA ENERGETICA',
#   'EDITORIAL PLANETA CHILENA SOCI - Casa Matriz',
#   2),
#  ('AGENCIA CHILENA DE EFICIENCIA ENERGETICA',
#   'ELEC - CHILE COMPAÑIA INDUSTRIAL DE PRODUCTOS ELEC',
#   1),
#  ('AGENCIA CHILENA DE EFICIENCIA ENERGETICA',
#   'ELIOTEC INGENIERÍA ELÉCTRICA',
#   2),
#  ('AGENCIA CHILENA DE EFICIENCIA ENERGETICA', 'ENYMA LTDA', 1),
#  ('AGENCIA CHILENA DE EFICIENCIA ENERGETICA', 'ERNC CHILE', 1),
#  ('AGENCIA CHILENA DE EFICIENCIA ENERGETICA', 'EVOLUSUN', 4),
#  ('AGENCIA CHILENA DE EFICIENCIA ENERGETICA', 'FCFM Centro de Energia', 1),
#  ('AGENCIA CHILENA DE EFICIENCIA ENERGETICA', 'Flux Solar SpA', 1),
#  ('AGENCIA CHILENA DE EFICIENCIA ENERGETICA', 'ImplementaSur', 1),
#  ('AGENCIA CHILENA DE EFICIENCIA ENERGETICA',
#   'Ingenieria Electrica en Potencia SPA',
#   1),
#  ('AGENCIA CHILENA DE EFICIENCIA ENERGETICA', 'Intertek', 4),
#  ('AGENCIA CHILENA DE EFICIENCIA ENERGETICA',
#   'Investigaciones y Datos SPA',
#   3),
#  ('AGENCIA CHILENA DE EFICIENCIA ENERGETICA', 'Itelecom', 3),
#  ('AGENCIA CHILENA DE EFICIENCIA ENERGETICA', 'JCV Ingeniería', 1),
#  ('AGENCIA CHILENA DE EFICIENCIA ENERGETICA', 'Jose', 1),
#  ('AGENCIA CHILENA DE EFICIENCIA ENERGETICA', 'José Luis', 1),
#  ('AGENCIA CHILENA DE EFICIENCIA ENERGETICA', 'José Tomás', 2),
#  ('AGENCIA CHILENA DE EFICIENCIA ENERGETICA', 'Kuantum', 1),
#  ('AGENCIA CHILENA DE EFICIENCIA ENERGETICA', 'MCS', 1),
#  ('AGENCIA CHILENA DE EFICIENCIA ENERGETICA', 'MS CONSTRUCCION Y MONTAJES', 1),
#  ('AGENCIA CHILENA DE EFICIENCIA ENERGETICA', 'Multienergy', 1),
#  ('AGENCIA CHILENA DE EFICIENCIA ENERGETICA',
#   'NEGAWATT Ingeniería & Energía',
#   3),
#  ('AGENCIA CHILENA DE EFICIENCIA ENERGETICA', 'Onduladores de Chile S.A.', 2),
#  ('AGENCIA CHILENA DE EFICIENCIA ENERGETICA', 'PRO 5 LIMITADA', 1),
#  ('AGENCIA CHILENA DE EFICIENCIA ENERGETICA', 'Poch Ambiental S.A.', 2),
#  ('AGENCIA CHILENA DE EFICIENCIA ENERGETICA',
#   'Pontificia Universidad Católica de Valparaíso',
#   2),
#  ('AGENCIA CHILENA DE EFICIENCIA ENERGETICA', 'Proyecta Territorio', 1),
#  ('AGENCIA CHILENA DE EFICIENCIA ENERGETICA', 'Punto Solar EIRL', 1),
#  ('AGENCIA CHILENA DE EFICIENCIA ENERGETICA', 'Quinetic', 1),
#  ('AGENCIA CHILENA DE EFICIENCIA ENERGETICA', 'RODA ENERGIA', 5),
#  ('AGENCIA CHILENA DE EFICIENCIA ENERGETICA', 'SAGESA S.A.', 1),
#  ('AGENCIA CHILENA DE EFICIENCIA ENERGETICA', 'SIMELEC S.A.', 1),
#  ('AGENCIA CHILENA DE EFICIENCIA ENERGETICA', 'Schréder Chile s.a.', 3),
#  ('AGENCIA CHILENA DE EFICIENCIA ENERGETICA', 'Sergio Antonio', 1),
#  ('AGENCIA CHILENA DE EFICIENCIA ENERGETICA', 'Sinec S. A.', 2),
#  ('AGENCIA CHILENA DE EFICIENCIA ENERGETICA', 'Smart-Tec', 1),
#  ('AGENCIA CHILENA DE EFICIENCIA ENERGETICA', 'TESLA ENERGY', 2),
#  ('AGENCIA CHILENA DE EFICIENCIA ENERGETICA', 'TecnoRed S.A.', 1),
#  ('AGENCIA CHILENA DE EFICIENCIA ENERGETICA', 'Tractebel Engineering S.A.', 2),
#  ('AGENCIA CHILENA DE EFICIENCIA ENERGETICA',
#   'UNIVERSIDAD TECNOLOGICA DE CHILE',
#   2),
#  ('AGENCIA CHILENA DE EFICIENCIA ENERGETICA', 'Ucorp S.A.', 1),
#  ('AGENCIA CHILENA DE EFICIENCIA ENERGETICA',
#   'Universidad de Concepción - INSTITUTO DE INVESTIGACIONES TECNOLOGICA',
#   1),
#  ('AGENCIA CHILENA DE EFICIENCIA ENERGETICA', 'Uvax Chile', 2),
#  ('AGENCIA CHILENA DE EFICIENCIA ENERGETICA', 'VIVENDIO IBEROAMERICA', 2),
#  ('AGENCIA CHILENA DE EFICIENCIA ENERGETICA', 'WINDSUN CHILE SPA', 1),
#  ('AGENCIA DE CALIDAD DE LA EDUCACION', 'AIROMA LTDA', 1),
#  ('AGENCIA DE CALIDAD DE LA EDUCACION', 'APORTA', 1),
#  ('AGENCIA DE CALIDAD DE LA EDUCACION', 'ASIDES Ltda.', 1),
#  ('AGENCIA DE CALIDAD DE LA EDUCACION',
#   'AdjudicaChile Consultora en Licitaciones Públicas',
#   1),
#  ('AGENCIA DE CALIDAD DE LA EDUCACION', 'CAROLINA ANDREA ZOMOSA LOBOS', 1),
#  ('AGENCIA DE CALIDAD DE LA EDUCACION',
#   'CEPPE-Centro de Estudios de Pol y Prac en Educ',
#   1),
#  ('AGENCIA DE CALIDAD DE LA EDUCACION',
#   'Centro UC Encuestas y Estudios Longitudinales',
#   1),
#  ('AGENCIA DE CALIDAD DE LA EDUCACION',
#   'Corporación Programa Interdisciplinario de Investi',
#   1),
#  ('AGENCIA DE CALIDAD DE LA EDUCACION', 'EDUCATIC-FUDEA', 2),
#  ('AGENCIA DE CALIDAD DE LA EDUCACION',
#   'ESTUDIOS Y CONSULTORIAS FOCUS SPA',
#   1),
#  ('AGENCIA DE CALIDAD DE LA EDUCACION', 'Easylit', 2),
#  ('AGENCIA DE CALIDAD DE LA EDUCACION', 'Ediciones Fremen', 1),
#  ('AGENCIA DE CALIDAD DE LA EDUCACION', 'Enfoque Social', 1),
#  ('AGENCIA DE CALIDAD DE LA EDUCACION', 'FEN - Departamento de Economía', 1),
#  ('AGENCIA DE CALIDAD DE LA EDUCACION', 'Fidelizador.com', 1),
#  ('AGENCIA DE CALIDAD DE LA EDUCACION', 'Fresh Day SpA.', 1),
#  ('AGENCIA DE CALIDAD DE LA EDUCACION', 'Hdi Seguros S.A. - El Bosque', 1),
#  ('AGENCIA DE CALIDAD DE LA EDUCACION',
#   'Instituto de Informática Educativa',
#   1),
#  ('AGENCIA DE CALIDAD DE LA EDUCACION', 'Juguemos con Nuestros Hijos', 1),
#  ('AGENCIA DE CALIDAD DE LA EDUCACION', 'Julieta Carolina', 1),
#  ('AGENCIA DE CALIDAD DE LA EDUCACION', 'Lunes CineTv', 1),
#  ('AGENCIA DE CALIDAD DE LA EDUCACION', 'Marcelo Ignacio', 1),
#  ('AGENCIA DE CALIDAD DE LA EDUCACION', 'Orión 2000 S.A.', 1),
#  ('AGENCIA DE CALIDAD DE LA EDUCACION',
#   'PUC - ISUC Instituto de Sociologia',
#   1),
#  ('AGENCIA DE CALIDAD DE LA EDUCACION', 'RENTOKIL', 1),
#  ('AGENCIA DE CALIDAD DE LA EDUCACION', 'TELEFONICA EMPRESAS CHILE SA', 1),
#  ('AGENCIA DE CALIDAD DE LA EDUCACION', 'diseño y publicidad', 1),
#  ('Agencia de Promoción de la Inversión Extranjera',
#   'ACADEMIA DE IDIOMAS DEL NORTE',
#   1),
#  ('Agencia de Promoción de la Inversión Extranjera', 'Cristian', 1),
#  ('Agencia de Promoción de la Inversión Extranjera',
#   'ELAINE RUTH BRADLEY BRIDGEMAN',
#   1),
#  ('Agencia de Promoción de la Inversión Extranjera', 'FLOR ELISA', 2),
#  ('Agencia de Promoción de la Inversión Extranjera',
#   'Grato Language Solutions',
#   2),
#  ('Agencia de Promoción de la Inversión Extranjera', 'IC Traducciones', 2),
#  ('Agencia de Promoción de la Inversión Extranjera', 'QINGJUN   WU', 1),
#  ('Agencia de Promoción de la Inversión Extranjera', 'Shamrock', 1),
#  ('Agencia de Promoción de la Inversión Extranjera', 'VESICA PISCIS SPA', 1),
#  ('Biblioteca del Congreso Nacional', 'ARTE CLEAN LTDA.', 1),
#  ('Biblioteca del Congreso Nacional', 'ASCENSORES SCHINDLER (CHILE) S.A.', 1),
#  ('Biblioteca del Congreso Nacional', 'ASIQ S.P.A.', 1),
#  ('Biblioteca del Congreso Nacional', 'Cardi', 1),
#  ('Biblioteca del Congreso Nacional', 'Heavenward Ascensores S.A.', 1),
#  ('Biblioteca del Congreso Nacional', 'INGENIERIA BARRETO Y CIA LTDA', 2),
#  ('Biblioteca del Congreso Nacional', 'Integral del Ascensor', 1),
#  ('Biblioteca del Congreso Nacional', 'LIMCHILE S.A.', 2),
#  ('Biblioteca del Congreso Nacional', 'Luis', 2),
#  ('Biblioteca del Congreso Nacional', 'Maxilimpio', 1),
#  ('Biblioteca del Congreso Nacional', 'Parot y Cía. Ltda.', 2),
#  ('Biblioteca del Congreso Nacional', 'Seing ', 3),
#  ('Biblioteca del Congreso Nacional', 'TK ELEVADORES CHILE SA', 1),
#  ('Biblioteca del Congreso Nacional', 'ecoval limitada', 1),
#  ('CAJA DE PREVISION DE LA DEFENSA NACIONAL', 'A.TORRES Y  CIA. LTDA.', 2),
#  ('CAJA DE PREVISION DE LA DEFENSA NACIONAL', 'AARON SIGFRIDO', 1),
#  ('CAJA DE PREVISION DE LA DEFENSA NACIONAL', 'ABMMEDICAL LIMITADA', 3),
#  ('CAJA DE PREVISION DE LA DEFENSA NACIONAL', 'ACT S.A.', 3),
#  ('CAJA DE PREVISION DE LA DEFENSA NACIONAL', 'AGR SPA', 1),
#  ('CAJA DE PREVISION DE LA DEFENSA NACIONAL', 'ALATHEIA-MEDICAL S.A', 1),
#  ('CAJA DE PREVISION DE LA DEFENSA NACIONAL', 'ALBIA S.A.', 2),
#  ('CAJA DE PREVISION DE LA DEFENSA NACIONAL',
#   'ALCON LABORATORIOS CHILE LTDA',
#   7),
#  ('CAJA DE PREVISION DE LA DEFENSA NACIONAL', 'ALEM Servicios Generales', 2),
#  ('CAJA DE PREVISION DE LA DEFENSA NACIONAL', 'ALJIN CHILE', 1),
#  ('CAJA DE PREVISION DE LA DEFENSA NACIONAL', 'ALLWARE', 1),
#  ('CAJA DE PREVISION DE LA DEFENSA NACIONAL',
#   'AMERICAN EAR - DIST. SALVADOR LTDA.',
#   1),
#  ('CAJA DE PREVISION DE LA DEFENSA NACIONAL', 'ANDY FULL SERVICE', 1),
#  ('CAJA DE PREVISION DE LA DEFENSA NACIONAL',
#   'AQuanta Ingeniería Computacional SPA',
#   2),
#  ('CAJA DE PREVISION DE LA DEFENSA NACIONAL', 'ARCON SPA', 1),
#  ('CAJA DE PREVISION DE LA DEFENSA NACIONAL', 'ASEO UNIVERSO LIMITADA', 1),
#  ('CAJA DE PREVISION DE LA DEFENSA NACIONAL', 'ASIQ S.P.A.', 1),
#  ('CAJA DE PREVISION DE LA DEFENSA NACIONAL', 'AUDITRON CHILE S.A.', 2),
#  ('CAJA DE PREVISION DE LA DEFENSA NACIONAL', 'Abasan C.I.P.', 1),
#  ('CAJA DE PREVISION DE LA DEFENSA NACIONAL',
#   'Abbott Laboratories de Chile Ltda.',
#   1),
#  ('CAJA DE PREVISION DE LA DEFENSA NACIONAL',
#   'AdjudicaChile Consultora en Licitaciones Públicas',
#   4),
#  ('CAJA DE PREVISION DE LA DEFENSA NACIONAL', 'Administración', 1),
#  ('CAJA DE PREVISION DE LA DEFENSA NACIONAL', 'Agroservicios Los Pinos', 1),
#  ('CAJA DE PREVISION DE LA DEFENSA NACIONAL', 'AlfaMed', 1),
#  ('CAJA DE PREVISION DE LA DEFENSA NACIONAL',
#   'Allergan Laboratorios Ltda.',
#   1),
#  ('CAJA DE PREVISION DE LA DEFENSA NACIONAL', 'Allmedica S.A', 2),
#  ('CAJA DE PREVISION DE LA DEFENSA NACIONAL', 'Alvaro Ramiro', 1),
#  ('CAJA DE PREVISION DE LA DEFENSA NACIONAL', 'Andes Clean SpA', 1),
#  ('CAJA DE PREVISION DE LA DEFENSA NACIONAL', 'Andrés Ignacio', 1),
#  ('CAJA DE PREVISION DE LA DEFENSA NACIONAL', 'Arena Tienda Limitada', 1),
#  ('CAJA DE PREVISION DE LA DEFENSA NACIONAL',
#   'Articulos Medicos y Quirurgicos Chile S.A.',
#   2),
#  ('CAJA DE PREVISION DE LA DEFENSA NACIONAL', 'Awad Artículos Médicos', 1),
#  ('CAJA DE PREVISION DE LA DEFENSA NACIONAL', 'Axity Chile SPA', 2),
#  ('CAJA DE PREVISION DE LA DEFENSA NACIONAL', 'B.BRAUN MEDICAL SpA', 2),
#  ('CAJA DE PREVISION DE LA DEFENSA NACIONAL', 'BIOCLIN S.A.', 4),
#  ('CAJA DE PREVISION DE LA DEFENSA NACIONAL', 'BIOMEDICA INGENIERIA', 1),
#  ('CAJA DE PREVISION DE LA DEFENSA NACIONAL', 'BIOTECH LIMITADA', 1),
#  ('CAJA DE PREVISION DE LA DEFENSA NACIONAL', 'BLUNDING S.A.', 1),
#  ('CAJA DE PREVISION DE LA DEFENSA NACIONAL', 'BRILL LIMPIEZA LTDA', 1),
#  ('CAJA DE PREVISION DE LA DEFENSA NACIONAL', 'BUHOS S.C.I. LTDA.', 26),
#  ('CAJA DE PREVISION DE LA DEFENSA NACIONAL', 'Biomedika', 1),
#  ('CAJA DE PREVISION DE LA DEFENSA NACIONAL', 'Bluemedical Insumos', 1),
#  ('CAJA DE PREVISION DE LA DEFENSA NACIONAL', 'CANON CHILE S.A.', 1),
#  ('CAJA DE PREVISION DE LA DEFENSA NACIONAL',
#   'CC CONSTRUCCIONES EIRL CONST Y LIMPIEZA EDIFICIOS',
#   1),
#  ('CAJA DE PREVISION DE LA DEFENSA NACIONAL', 'CEMTECH SPA', 1),
#  ('CAJA DE PREVISION DE LA DEFENSA NACIONAL', 'CESAR VELASQUEZ MANRIQUE', 1),
#  ('CAJA DE PREVISION DE LA DEFENSA NACIONAL',
#   'CG COMERCIALIZADORA Y SANITIZACION LTDA',
#   1),
#  ('CAJA DE PREVISION DE LA DEFENSA NACIONAL', 'CHUBRETOVIC Y CIA. LTDA.', 2),
#  ('CAJA DE PREVISION DE LA DEFENSA NACIONAL', 'CLARO CHILE SA', 2),
#  ('CAJA DE PREVISION DE LA DEFENSA NACIONAL',
#   'CLAUDIO MARTIN VALENZUELA - Casa Matriz',
#   1),
#  ('CAJA DE PREVISION DE LA DEFENSA NACIONAL', 'CLINICA GAETE', 1),
#  ('CAJA DE PREVISION DE LA DEFENSA NACIONAL', 'CLINICA VALPARAISO', 1),
#  ('CAJA DE PREVISION DE LA DEFENSA NACIONAL',
#   'COMERCIALIZADORA ILHABELLA EIRL',
#   45),
#  ('CAJA DE PREVISION DE LA DEFENSA NACIONAL',
#   'COMERCIALIZADORA P&S E.I.R.L.',
#   19),
#  ('CAJA DE PREVISION DE LA DEFENSA NACIONAL', 'CORASA LTDA', 1),
#  ('CAJA DE PREVISION DE LA DEFENSA NACIONAL', 'CRISTIAN ALEJANDRO', 1),
#  ('CAJA DE PREVISION DE LA DEFENSA NACIONAL', 'Call Fire Ltda.', 1),
#  ('CAJA DE PREVISION DE LA DEFENSA NACIONAL', 'Carpedent SpA', 33),
#  ('CAJA DE PREVISION DE LA DEFENSA NACIONAL',
#   'Catalina del Carmen Saavedra Soto',
#   1),
#  ('CAJA DE PREVISION DE LA DEFENSA NACIONAL',
#   'Check Mantencion Industrial Limitada',
#   1),
#  ('CAJA DE PREVISION DE LA DEFENSA NACIONAL', 'Claudio Antonio', 1),
#  ('CAJA DE PREVISION DE LA DEFENSA NACIONAL', 'Cleanmatic', 1),
#  ('CAJA DE PREVISION DE LA DEFENSA NACIONAL', 'Climatizacion', 2),
#  ('CAJA DE PREVISION DE LA DEFENSA NACIONAL', 'Comercial', 1),
#  ('CAJA DE PREVISION DE LA DEFENSA NACIONAL', 'Comercial LBF Limitada', 5),
#  ('CAJA DE PREVISION DE LA DEFENSA NACIONAL',
#   'Comercial Maquinet Limitada',
#   2),
#  ('CAJA DE PREVISION DE LA DEFENSA NACIONAL',
#   'Comercial Plasteca E.I.R.L.',
#   1),
#  ('CAJA DE PREVISION DE LA DEFENSA NACIONAL', 'Comercial San Fernando', 7),
#  ('CAJA DE PREVISION DE LA DEFENSA NACIONAL', 'Conecta Research', 1),
#  ('CAJA DE PREVISION DE LA DEFENSA NACIONAL',
#   'Constructora Electrycom SpA',
#   1),
#  ('CAJA DE PREVISION DE LA DEFENSA NACIONAL',
#   'D&A Servicios Integrales SpA',
#   1),
#  ('CAJA DE PREVISION DE LA DEFENSA NACIONAL',
#   'DCA GROUP empresa ingeniería & servicios limitada',
#   1),
#  ('CAJA DE PREVISION DE LA DEFENSA NACIONAL', 'DCS-Chile S.A.', 1),
#  ('CAJA DE PREVISION DE LA DEFENSA NACIONAL', 'DEIFIRE Y CIA LTDA', 1),
#  ('CAJA DE PREVISION DE LA DEFENSA NACIONAL', 'DELUXE LTDA', 2),
#  ('CAJA DE PREVISION DE LA DEFENSA NACIONAL', 'DENISSE', 3),
#  ('CAJA DE PREVISION DE LA DEFENSA NACIONAL', 'DENTAL ALAMEDA', 9),
#  ('CAJA DE PREVISION DE LA DEFENSA NACIONAL', 'DENTAL LAVAL LTDA.', 18),
#  ('CAJA DE PREVISION DE LA DEFENSA NACIONAL', 'DESAN SPA', 1),
#  ('CAJA DE PREVISION DE LA DEFENSA NACIONAL', 'DIGNIDAD CONCEPCIÓN ', 1),
#  ('CAJA DE PREVISION DE LA DEFENSA NACIONAL', 'DIMACOFI S.A.', 1),
#  ('CAJA DE PREVISION DE LA DEFENSA NACIONAL',
#   'DIST. ARTICULOS MEDICOS PÉREZ SPA',
#   2),
#  ('CAJA DE PREVISION DE LA DEFENSA NACIONAL', 'DPP Group', 3),
#  ('CAJA DE PREVISION DE LA DEFENSA NACIONAL', 'Daniela Blanca', 1),
#  ('CAJA DE PREVISION DE LA DEFENSA NACIONAL', 'Dc Tecno Ltda.', 1),
#  ('CAJA DE PREVISION DE LA DEFENSA NACIONAL', 'Dignidad Ltda.', 1),
#  ('CAJA DE PREVISION DE LA DEFENSA NACIONAL', 'Dipromed S.A.', 22),
#  ('CAJA DE PREVISION DE LA DEFENSA NACIONAL',
#   'Diseño y Soporte para Servicio - Casa Matriz',
#   1),
#  ('CAJA DE PREVISION DE LA DEFENSA NACIONAL',
#   'Distribuciones Juridicas sPA',
#   1),
#  ('CAJA DE PREVISION DE LA DEFENSA NACIONAL',
#   'DyJ Servicios Integrales Spa',
#   1),
#  ('CAJA DE PREVISION DE LA DEFENSA NACIONAL', 'ECOSER S.A.', 1),
#  ('CAJA DE PREVISION DE LA DEFENSA NACIONAL', 'ENTEL CALL CENTER S.A.', 1),
#  ('CAJA DE PREVISION DE LA DEFENSA NACIONAL', 'ENTERPRISE IT SPA', 2),
#  ('CAJA DE PREVISION DE LA DEFENSA NACIONAL', 'ETHON PHARMACEUTICALS SPA.', 2),
#  ('CAJA DE PREVISION DE LA DEFENSA NACIONAL', 'EXXIMMED 2000', 2),
#  ('CAJA DE PREVISION DE LA DEFENSA NACIONAL', 'Easylit', 3),
#  ('CAJA DE PREVISION DE LA DEFENSA NACIONAL', 'Ecohealth', 1),
#  ('CAJA DE PREVISION DE LA DEFENSA NACIONAL', 'Electronica EIRL ', 1),
#  ('CAJA DE PREVISION DE LA DEFENSA NACIONAL', 'Expro Dental (SCL)', 18),
#  ('CAJA DE PREVISION DE LA DEFENSA NACIONAL', 'Exteriliza', 1),
#  ('CAJA DE PREVISION DE LA DEFENSA NACIONAL', 'FRIMED', 3),
#  ('CAJA DE PREVISION DE LA DEFENSA NACIONAL', 'FUMIGACIONESBIOK-2', 1),
#  ('CAJA DE PREVISION DE LA DEFENSA NACIONAL', 'FYM PRODUCCIONES', 1),
#  ('CAJA DE PREVISION DE LA DEFENSA NACIONAL', 'Felipe Ignacio', 1),
#  ('CAJA DE PREVISION DE LA DEFENSA NACIONAL', 'Fernando Alexis', 2),
#  ('CAJA DE PREVISION DE LA DEFENSA NACIONAL', 'Fernando Rene', 1),
#  ('CAJA DE PREVISION DE LA DEFENSA NACIONAL', 'GTD Teleductos', 1),
#  ('CAJA DE PREVISION DE LA DEFENSA NACIONAL', 'Global Plastic', 1),
#  ('CAJA DE PREVISION DE LA DEFENSA NACIONAL', 'Gonzalo', 1),
#  ('CAJA DE PREVISION DE LA DEFENSA NACIONAL', 'H y V Services SPA', 1),
#  ('CAJA DE PREVISION DE LA DEFENSA NACIONAL', 'HDI Seguros de Vida S A', 1),
#  ('CAJA DE PREVISION DE LA DEFENSA NACIONAL', 'HEXIN', 3),
#  ('CAJA DE PREVISION DE LA DEFENSA NACIONAL', 'HIGIECLIN LTDA.', 1),
#  ('CAJA DE PREVISION DE LA DEFENSA NACIONAL', 'HOLISTECK SPA', 1),
#  ('CAJA DE PREVISION DE LA DEFENSA NACIONAL', 'HOSPIRA', 1),
#  ('CAJA DE PREVISION DE LA DEFENSA NACIONAL', 'Haltra Ltda', 2),
#  ('CAJA DE PREVISION DE LA DEFENSA NACIONAL',
#   'Hdi Seguros S.A. - Negocios Masivos',
#   1),
#  ('CAJA DE PREVISION DE LA DEFENSA NACIONAL', 'Help Fire', 1),
#  ('CAJA DE PREVISION DE LA DEFENSA NACIONAL', 'Hugo Alberto', 1),
#  ('CAJA DE PREVISION DE LA DEFENSA NACIONAL', 'Hygienic Place Spa', 1),
#  ('CAJA DE PREVISION DE LA DEFENSA NACIONAL', 'ICSE SPA', 1),
#  ('CAJA DE PREVISION DE LA DEFENSA NACIONAL', 'IFX Networks', 1),
#  ('CAJA DE PREVISION DE LA DEFENSA NACIONAL', 'INDURA MEDICA', 1),
#  ('CAJA DE PREVISION DE LA DEFENSA NACIONAL', 'ING Servicios Integrales', 1),
#  ('CAJA DE PREVISION DE LA DEFENSA NACIONAL', 'INMED DROGUERIA LTDA.', 10),
#  ('CAJA DE PREVISION DE LA DEFENSA NACIONAL', 'INTDATA', 2),
#  ('CAJA DE PREVISION DE LA DEFENSA NACIONAL', 'ISANETTI', 1),
#  ('CAJA DE PREVISION DE LA DEFENSA NACIONAL', 'IVMedical', 1),
#  ('CAJA DE PREVISION DE LA DEFENSA NACIONAL', 'Ignacia Isidora ', 1),
#  ('CAJA DE PREVISION DE LA DEFENSA NACIONAL', 'Ingemec Ltda', 1),
#  ('CAJA DE PREVISION DE LA DEFENSA NACIONAL', 'Ingepumps SpA', 4),
#  ('CAJA DE PREVISION DE LA DEFENSA NACIONAL', 'Insumos Gottlieb', 2),
#  ('CAJA DE PREVISION DE LA DEFENSA NACIONAL',
#   'Insumos y Servicios Medicos S.A.',
#   1),
#  ('CAJA DE PREVISION DE LA DEFENSA NACIONAL', 'International Clinics S.A.', 3),
#  ('CAJA DE PREVISION DE LA DEFENSA NACIONAL', 'JASH', 2),
#  ('CAJA DE PREVISION DE LA DEFENSA NACIONAL', 'JCMEQUIPOSMEDICOS', 1),
#  ('CAJA DE PREVISION DE LA DEFENSA NACIONAL', 'JMO Austral', 1),
#  ('CAJA DE PREVISION DE LA DEFENSA NACIONAL',
#   'JOSE ALEJANDRO SEPULVEDA AGUIL - Casa Matriz',
#   1),
#  ('CAJA DE PREVISION DE LA DEFENSA NACIONAL', 'Jeannette Veronica', 1),
#  ('CAJA DE PREVISION DE LA DEFENSA NACIONAL', 'KONTROL INGENIERIA SPA', 2),
#  ('CAJA DE PREVISION DE LA DEFENSA NACIONAL', 'Kibernum S.A', 1),
#  ('CAJA DE PREVISION DE LA DEFENSA NACIONAL', 'L&D EIRL', 1),
#  ('CAJA DE PREVISION DE LA DEFENSA NACIONAL', 'LA CASA DEL COMPRESOR', 4),
#  ('CAJA DE PREVISION DE LA DEFENSA NACIONAL', 'LABORATORIO E IMAGEN', 1),
#  ('CAJA DE PREVISION DE LA DEFENSA NACIONAL', 'LABORATORIO SANDERSON S.A.', 2),
#  ('CAJA DE PREVISION DE LA DEFENSA NACIONAL',
#   'LABORATORIOS SANFER DE CHILE S.A.',
#   1),
#  ('CAJA DE PREVISION DE LA DEFENSA NACIONAL', 'LAVAQUIM', 1),
#  ('CAJA DE PREVISION DE LA DEFENSA NACIONAL', 'LEAN SERVICE', 1),
#  ('CAJA DE PREVISION DE LA DEFENSA NACIONAL',
#   'LEGAL PUBLISHING CHILE LTDA.',
#   1),
#  ('CAJA DE PREVISION DE LA DEFENSA NACIONAL', 'LIASIN Y CIA. LTDA.', 3),
#  ('CAJA DE PREVISION DE LA DEFENSA NACIONAL', 'LIMCHILE S.A.', 2),
#  ('CAJA DE PREVISION DE LA DEFENSA NACIONAL', 'LOGISTIC WAY SPA', 1),
#  ('CAJA DE PREVISION DE LA DEFENSA NACIONAL',
#   'Laboratorio Clinico Diagnostika Alemana',
#   1),
#  ('CAJA DE PREVISION DE LA DEFENSA NACIONAL',
#   'Lavanderías del Parque S.p.A.',
#   1),
#  ('CAJA DE PREVISION DE LA DEFENSA NACIONAL', 'Leonora ', 1),
#  ('CAJA DE PREVISION DE LA DEFENSA NACIONAL', 'Letras Digitales', 1),
#  ('CAJA DE PREVISION DE LA DEFENSA NACIONAL',
#   'MANTENCION REPARACION ALEJANDRA ZAVALA URZUA EIRL',
#   1),
#  ('CAJA DE PREVISION DE LA DEFENSA NACIONAL', 'MARCELA ANDREA', 1),
#  ('CAJA DE PREVISION DE LA DEFENSA NACIONAL', 'MAXIMO LTDA', 3),
#  ('CAJA DE PREVISION DE LA DEFENSA NACIONAL', 'MAYORDENT LTDA', 31),
#  ('CAJA DE PREVISION DE LA DEFENSA NACIONAL', 'MD INGENIERIA', 2),
#  ('CAJA DE PREVISION DE LA DEFENSA NACIONAL', 'MDS SERVICIOS LIMITADA', 1),
#  ('CAJA DE PREVISION DE LA DEFENSA NACIONAL', 'MEALS & TECHNOLOGIES S.A.', 1),
#  ('CAJA DE PREVISION DE LA DEFENSA NACIONAL', 'MEGAMARKET', 4),
#  ('CAJA DE PREVISION DE LA DEFENSA NACIONAL', 'MERCSOLUCIONES LTDA', 2),
#  ('CAJA DE PREVISION DE LA DEFENSA NACIONAL', 'MERIDA EIRL', 1),
#  ('CAJA DE PREVISION DE LA DEFENSA NACIONAL', 'MICROJURIS COM CHILE S.A.', 1),
#  ('CAJA DE PREVISION DE LA DEFENSA NACIONAL',
#   'MONICA JACQUELINE BERNALES VER - Casa Matriz',
#   1),
#  ('CAJA DE PREVISION DE LA DEFENSA NACIONAL', 'MURUA Y ASOCIADOS LTDA', 36),
#  ('CAJA DE PREVISION DE LA DEFENSA NACIONAL', 'Mantencion', 1),
#  ('CAJA DE PREVISION DE LA DEFENSA NACIONAL', 'Maria Cecilia', 1),
#  ('CAJA DE PREVISION DE LA DEFENSA NACIONAL', 'Medcorp ', 1),
#  ('CAJA DE PREVISION DE LA DEFENSA NACIONAL', 'Medex Ltda', 1),
#  ('CAJA DE PREVISION DE LA DEFENSA NACIONAL',
#   'Metlife Chile Seguros de Vida S.A.',
#   1),
#  ('CAJA DE PREVISION DE LA DEFENSA NACIONAL', 'Microserv Ltda.', 1),
#  ('CAJA DE PREVISION DE LA DEFENSA NACIONAL',
#   'NIPRO MEDICAL CORPORATION (AGENCIA EN CHILE)',
#   8),
#  ('CAJA DE PREVISION DE LA DEFENSA NACIONAL', 'NOVOSALUD', 2),
#  ('CAJA DE PREVISION DE LA DEFENSA NACIONAL', 'NetProvider S.A', 1),
#  ('CAJA DE PREVISION DE LA DEFENSA NACIONAL', 'Netbell Limitada.', 1),
#  ('CAJA DE PREVISION DE LA DEFENSA NACIONAL', 'NexNews', 1),
#  ('CAJA DE PREVISION DE LA DEFENSA NACIONAL',
#   'NinaMapu EIRL: Producción y Servicios en Cultura',
#   1),
#  ('CAJA DE PREVISION DE LA DEFENSA NACIONAL', 'Norstray Nuart SPA', 2),
#  ('CAJA DE PREVISION DE LA DEFENSA NACIONAL', 'Nueva Clinica Cordillera', 1),
#  ('CAJA DE PREVISION DE LA DEFENSA NACIONAL', 'OEL Equipos Medicos Ltda.', 4),
#  ('CAJA DE PREVISION DE LA DEFENSA NACIONAL', 'OFTALMEDICAL LTDA.', 4),
#  ('CAJA DE PREVISION DE LA DEFENSA NACIONAL', 'OFTOMED', 5),
#  ('CAJA DE PREVISION DE LA DEFENSA NACIONAL',
#   'OHL SERVICIOS INGESAN S.A AGENCIA EN CHILE',
#   2),
#  ('CAJA DE PREVISION DE LA DEFENSA NACIONAL', 'ORKIN CHILE', 1),
#  ('CAJA DE PREVISION DE LA DEFENSA NACIONAL', 'ORTOTEK LTDA', 18),
#  ('CAJA DE PREVISION DE LA DEFENSA NACIONAL', 'OSL Control Chile S.A.', 1),
#  ('CAJA DE PREVISION DE LA DEFENSA NACIONAL', 'Oficima SpA', 1),
#  ('CAJA DE PREVISION DE LA DEFENSA NACIONAL', 'Ofimundo', 1),
#  ('CAJA DE PREVISION DE LA DEFENSA NACIONAL', 'Omega Service Limitada', 1),
#  ('CAJA DE PREVISION DE LA DEFENSA NACIONAL', 'Open Wireless Laboratories', 2),
#  ('CAJA DE PREVISION DE LA DEFENSA NACIONAL', 'PARACLINICS', 1),
#  ('CAJA DE PREVISION DE LA DEFENSA NACIONAL',
#   'PATRICIA EMILIA OSORES CORONEO',
#   1),
#  ('CAJA DE PREVISION DE LA DEFENSA NACIONAL',
#   'PAZ DALILA VALENCIA RUSSELL',
#   1),
#  ('CAJA DE PREVISION DE LA DEFENSA NACIONAL', 'PEDRO LUIS', 2),
#  ('CAJA DE PREVISION DE LA DEFENSA NACIONAL', 'PHARMATECH', 1),
#  ('CAJA DE PREVISION DE LA DEFENSA NACIONAL', 'PIRO Multiservicios', 3),
#  ('CAJA DE PREVISION DE LA DEFENSA NACIONAL',
#   'PLASTISERVI LIMITADA - Casa Matriz',
#   1),
#  ('CAJA DE PREVISION DE LA DEFENSA NACIONAL', 'PREGO S.A.', 1),
#  ('CAJA DE PREVISION DE LA DEFENSA NACIONAL', 'PROTEGO S.A.', 2),
#  ('CAJA DE PREVISION DE LA DEFENSA NACIONAL', 'Paracare SpA', 2),
#  ('CAJA DE PREVISION DE LA DEFENSA NACIONAL', 'Pareja Lecaros Chile S.A', 3),
#  ('CAJA DE PREVISION DE LA DEFENSA NACIONAL',
#   'Paulina Clara  Balboa Landabur  ',
#   1),
#  ('CAJA DE PREVISION DE LA DEFENSA NACIONAL',
#   'Plasticos Ecologicos Muñofer',
#   1),
#  ('CAJA DE PREVISION DE LA DEFENSA NACIONAL',
#   'Plaza, servicio y mantencion',
#   1),
#  ('CAJA DE PREVISION DE LA DEFENSA NACIONAL', 'Pro-Ambiental', 1),
#  ('CAJA DE PREVISION DE LA DEFENSA NACIONAL', 'Procesán Casa Matriz', 2),
#  ('CAJA DE PREVISION DE LA DEFENSA NACIONAL',
#   'Productos Médicos Promedon Chile S.A.',
#   4),
#  ('CAJA DE PREVISION DE LA DEFENSA NACIONAL',
#   'Proince Corredores de Seguros.',
#   1),
#  ('CAJA DE PREVISION DE LA DEFENSA NACIONAL', 'Pronomed Ltda', 1),
#  ('CAJA DE PREVISION DE LA DEFENSA NACIONAL', 'Provectis', 1),
#  ('CAJA DE PREVISION DE LA DEFENSA NACIONAL', 'R & L Ingeniería', 2),
#  ('CAJA DE PREVISION DE LA DEFENSA NACIONAL', 'RAFMEDICAL LTDA', 1),
#  ('CAJA DE PREVISION DE LA DEFENSA NACIONAL', 'REDES CLINIC', 2),
#  ('CAJA DE PREVISION DE LA DEFENSA NACIONAL', 'RENHET SPA', 1),
#  ('CAJA DE PREVISION DE LA DEFENSA NACIONAL', 'RESIN SPA', 2),
#  ('CAJA DE PREVISION DE LA DEFENSA NACIONAL', 'RESOLAUD', 1),
#  ('CAJA DE PREVISION DE LA DEFENSA NACIONAL', 'RHOS LTDA CASA MATRIZ', 2),
#  ('CAJA DE PREVISION DE LA DEFENSA NACIONAL',
#   'RICARDO RODRIGUEZ Y CIA. LTDA.',
#   1),
#  ('CAJA DE PREVISION DE LA DEFENSA NACIONAL', 'Re-Med', 2),
#  ('CAJA DE PREVISION DE LA DEFENSA NACIONAL', 'Realtone Limitada', 2),
#  ('CAJA DE PREVISION DE LA DEFENSA NACIONAL', 'Relecom SPA', 2),
#  ('CAJA DE PREVISION DE LA DEFENSA NACIONAL', 'Resmain', 3),
#  ('CAJA DE PREVISION DE LA DEFENSA NACIONAL',
#   'Roche Chile Ltda Roche Diabetes',
#   1),
#  ('CAJA DE PREVISION DE LA DEFENSA NACIONAL', 'Rodrigo Alberto', 1),
#  ('CAJA DE PREVISION DE LA DEFENSA NACIONAL', 'Rosa Erica', 1),
#  ('CAJA DE PREVISION DE LA DEFENSA NACIONAL', 'SAEEIRL', 1),
#  ('CAJA DE PREVISION DE LA DEFENSA NACIONAL', 'SANTA CAROLINA', 1),
#  ('CAJA DE PREVISION DE LA DEFENSA NACIONAL', 'SASF DIVISION MEDICA', 2),
#  ('CAJA DE PREVISION DE LA DEFENSA NACIONAL', 'SAVE Seguros', 1),
#  ('CAJA DE PREVISION DE LA DEFENSA NACIONAL', 'SENIOR´S LIFE AND MOBILITY', 1),
#  ('CAJA DE PREVISION DE LA DEFENSA NACIONAL',
#   'SERVICIOS TECNICOS URBANOS LTDA.',
#   2),
#  ('CAJA DE PREVISION DE LA DEFENSA NACIONAL',
#   'SERVICIOS Y LOGÍSTICA INTEGRALES',
#   1),
#  ('CAJA DE PREVISION DE LA DEFENSA NACIONAL', 'SILI', 1),
#  ('CAJA DE PREVISION DE LA DEFENSA NACIONAL', 'SIMA SPA', 2),
#  ('CAJA DE PREVISION DE LA DEFENSA NACIONAL', 'SIOZONO', 1),
#  ('CAJA DE PREVISION DE LA DEFENSA NACIONAL', 'SIPTEL', 1),
#  ('CAJA DE PREVISION DE LA DEFENSA NACIONAL',
#   'SOCIEDAD DE SERVICIOS NOE LIMITADA',
#   1),
#  ('CAJA DE PREVISION DE LA DEFENSA NACIONAL', 'SOCIEDAD T Y Z LIMITADA', 2),
#  ('CAJA DE PREVISION DE LA DEFENSA NACIONAL', 'SRN', 2),
#  ('CAJA DE PREVISION DE LA DEFENSA NACIONAL', 'ST Computacion S.A.', 1),
#  ('CAJA DE PREVISION DE LA DEFENSA NACIONAL', 'SUPERASEO SPA', 1),
#  ('CAJA DE PREVISION DE LA DEFENSA NACIONAL', 'Sanitización Ambiental HMM', 1),
#  ('CAJA DE PREVISION DE LA DEFENSA NACIONAL', 'Sebastian', 1),
#  ('CAJA DE PREVISION DE LA DEFENSA NACIONAL', 'Serick Max Medica Ltda', 1),
#  ('CAJA DE PREVISION DE LA DEFENSA NACIONAL',
#   'Servicios Integrados de Consultoría en Computación',
#   1),
#  ('CAJA DE PREVISION DE LA DEFENSA NACIONAL',
#   'Servintegral Servicios LTDA.',
#   1),
#  ('CAJA DE PREVISION DE LA DEFENSA NACIONAL',
#   'Smartbricks Technologies SPA',
#   1),
#  ('CAJA DE PREVISION DE LA DEFENSA NACIONAL', 'Socofar Division Munnich', 12),
#  ('CAJA DE PREVISION DE LA DEFENSA NACIONAL', 'Soluziona Ltda', 1),
#  ('CAJA DE PREVISION DE LA DEFENSA NACIONAL', 'Stefanini', 2),
#  ('CAJA DE PREVISION DE LA DEFENSA NACIONAL', 'Sumilab', 1),
#  ('CAJA DE PREVISION DE LA DEFENSA NACIONAL',
#   'TELEFONIA COMUNICACIONES DATOS - Casa Matriz',
#   1),
#  ('CAJA DE PREVISION DE LA DEFENSA NACIONAL',
#   'TELEFONICA EMPRESAS CHILE SA',
#   2),
#  ('CAJA DE PREVISION DE LA DEFENSA NACIONAL', 'TEXAM SPA', 1),
#  ('CAJA DE PREVISION DE LA DEFENSA NACIONAL', 'THE MAGIC', 1),
#  ('CAJA DE PREVISION DE LA DEFENSA NACIONAL', 'TLINE', 1),
#  ('CAJA DE PREVISION DE LA DEFENSA NACIONAL', 'TOPOFFICE', 1),
#  ('CAJA DE PREVISION DE LA DEFENSA NACIONAL', 'TRIGAS CHILE LTDA.', 1),
#  ('CAJA DE PREVISION DE LA DEFENSA NACIONAL', 'Tampigas LTDA.', 1),
#  ('CAJA DE PREVISION DE LA DEFENSA NACIONAL', 'Tivit Chile', 1),
#  ('CAJA DE PREVISION DE LA DEFENSA NACIONAL', 'Trema', 30),
#  ('CAJA DE PREVISION DE LA DEFENSA NACIONAL',
#   'UPCOM BUSINESS & SERVICE CENTER',
#   1),
#  ('CAJA DE PREVISION DE LA DEFENSA NACIONAL', 'UPGRADE CHILE S.A.', 1),
#  ('CAJA DE PREVISION DE LA DEFENSA NACIONAL', 'VEOLIA SI CHILE S.A.', 1),
#  ('CAJA DE PREVISION DE LA DEFENSA NACIONAL', 'Validad', 1),
#  ('CAJA DE PREVISION DE LA DEFENSA NACIONAL', 'Venplagas SpA', 1),
#  ('CAJA DE PREVISION DE LA DEFENSA NACIONAL', 'Viaimport', 4),
#  ('CAJA DE PREVISION DE LA DEFENSA NACIONAL',
#   'WIENECKE CORREDORES DE SEGUROS LIMITADA',
#   2),
#  ('CAJA DE PREVISION DE LA DEFENSA NACIONAL', 'Xinergía Laboral E.S.T.', 1),
#  ('CAJA DE PREVISION DE LA DEFENSA NACIONAL',
#   'Z&L SA Soluciones en Gestion',
#   1),
#  ('CAJA DE PREVISION DE LA DEFENSA NACIONAL', 'agroworld', 1),
#  ('CAJA DE PREVISION DE LA DEFENSA NACIONAL', 'beraudent', 1),
#  ('CAJA DE PREVISION DE LA DEFENSA NACIONAL', 'cediblanc', 1),
#  ('CAJA DE PREVISION DE LA DEFENSA NACIONAL', 'das ohr', 2),
#  ('CAJA DE PREVISION DE LA DEFENSA NACIONAL', 'diego fernandez', 1),
#  ('CAJA DE PREVISION DE LA DEFENSA NACIONAL', 'ecoval limitada', 1),
#  ('CAJA DE PREVISION DE LA DEFENSA NACIONAL', 'efical-segcal', 2),
#  ('CAJA DE PREVISION DE LA DEFENSA NACIONAL', 'globalmed', 1),
#  ('CAJA DE PREVISION DE LA DEFENSA NACIONAL',
#   'importadora gac chile ltda.',
#   7),
#  ('CAJA DE PREVISION DE LA DEFENSA NACIONAL',
#   'ingeniería en equipos médicos limitada',
#   1),
#  ('CAJA DE PREVISION DE LA DEFENSA NACIONAL', 'intermedica ltda', 10),
#  ('CAJA DE PREVISION DE LA DEFENSA NACIONAL', 'jardintiamonica', 1),
#  ('CAJA DE PREVISION DE LA DEFENSA NACIONAL', 'jose ', 2),
#  ('CAJA DE PREVISION DE LA DEFENSA NACIONAL', 'juan luis', 1),
#  ('CAJA DE PREVISION DE LA DEFENSA NACIONAL', 'kAREM ALEJANDRA', 1),
#  ('CAJA DE PREVISION DE LA DEFENSA NACIONAL', 'labocenter', 1),
#  ('CAJA DE PREVISION DE LA DEFENSA NACIONAL', 'p y m ltda', 1),
#  ('CAJA DE PREVISION DE LA DEFENSA NACIONAL', 'persy charly', 1),
#  ('CAJA DE PREVISION DE LA DEFENSA NACIONAL', 'plaresa', 1),
#  ('CAJA DE PREVISION DE LA DEFENSA NACIONAL', 'prodesa', 1),
#  ('CAJA DE PREVISION DE LA DEFENSA NACIONAL', 'raul alberto', 1),
#  ('CAJA DE PREVISION DE LA DEFENSA NACIONAL', 'sasil', 1),
#  ('CAJA DE PREVISION DE LA DEFENSA NACIONAL', 'sebastian alexander', 1),
#  ('CAJA DE PREVISION DE LA DEFENSA NACIONAL', 'socoex chile', 1),
#  ('CAJA DE PREVISION DE LA DEFENSA NACIONAL', 'tecnobus chile ltda', 1),
#  ('CAJA DE PREVISION DE LA DEFENSA NACIONAL',
#   'x-ray proteccion radiologica ltda.',
#   1),
#  ('CENTRAL DE ABASTECIMIENTO DEL SISTEMA NACIONAL DE SERVICIO DE SALUD',
#   '2 Janssen-Cilag Chile',
#   33),
#  ('CENTRAL DE ABASTECIMIENTO DEL SISTEMA NACIONAL DE SERVICIO DE SALUD',
#   '3M Chile S.A.',
#   1),
#  ('CENTRAL DE ABASTECIMIENTO DEL SISTEMA NACIONAL DE SERVICIO DE SALUD',
#   '761442104',
#   2),
#  ('CENTRAL DE ABASTECIMIENTO DEL SISTEMA NACIONAL DE SERVICIO DE SALUD',
#   '762248808',
#   2),
#  ('CENTRAL DE ABASTECIMIENTO DEL SISTEMA NACIONAL DE SERVICIO DE SALUD',
#   '966706406',
#   101),
#  ('CENTRAL DE ABASTECIMIENTO DEL SISTEMA NACIONAL DE SERVICIO DE SALUD',
#   'ABBVIE PRODUCTOS FARMACEUTICOS LIMITADA',
#   7),
#  ('CENTRAL DE ABASTECIMIENTO DEL SISTEMA NACIONAL DE SERVICIO DE SALUD',
#   'ACIMA SOLUCIONES',
#   3),
#  ('CENTRAL DE ABASTECIMIENTO DEL SISTEMA NACIONAL DE SERVICIO DE SALUD',
#   'ACRUX LABS S.A.',
#   32),
#  ('CENTRAL DE ABASTECIMIENTO DEL SISTEMA NACIONAL DE SERVICIO DE SALUD',
#   'ACT S.A.',
#   1),
#  ('CENTRAL DE ABASTECIMIENTO DEL SISTEMA NACIONAL DE SERVICIO DE SALUD',
#   'ADECCO RECURSOS HUMANOS S.A.',
#   1),
#  ('CENTRAL DE ABASTECIMIENTO DEL SISTEMA NACIONAL DE SERVICIO DE SALUD',
#   'ADVANCED STERILIZATION PRODUCTS CHILE SpA',
#   2),
#  ('CENTRAL DE ABASTECIMIENTO DEL SISTEMA NACIONAL DE SERVICIO DE SALUD',
#   'AIROMA LTDA',
#   1),
#  ('CENTRAL DE ABASTECIMIENTO DEL SISTEMA NACIONAL DE SERVICIO DE SALUD',
#   'AISLACION INTEGRAL LIMITADA',
#   2),
#  ('CENTRAL DE ABASTECIMIENTO DEL SISTEMA NACIONAL DE SERVICIO DE SALUD',
#   'ALCON LABORATORIOS CHILE LTDA - Alcon Chile Farmacéutico',
#   5),
#  ('CENTRAL DE ABASTECIMIENTO DEL SISTEMA NACIONAL DE SERVICIO DE SALUD',
#   'ALGODONERA VARAS, CIA LTDA',
#   4),
#  ('CENTRAL DE ABASTECIMIENTO DEL SISTEMA NACIONAL DE SERVICIO DE SALUD',
#   'ALIMPACK SPA',
#   1),
#  ('CENTRAL DE ABASTECIMIENTO DEL SISTEMA NACIONAL DE SERVICIO DE SALUD',
#   'ALPES CHEMIE S.A.',
#   2),
#  ('CENTRAL DE ABASTECIMIENTO DEL SISTEMA NACIONAL DE SERVICIO DE SALUD',
#   'AMF Seguridad S.A.',
#   2),
#  ('CENTRAL DE ABASTECIMIENTO DEL SISTEMA NACIONAL DE SERVICIO DE SALUD',
#   'AMW1',
#   3),
#  ('CENTRAL DE ABASTECIMIENTO DEL SISTEMA NACIONAL DE SERVICIO DE SALUD',
#   'APLICACION DE TECNOLOGIAS AVANZADAS',
#   1),
#  ('CENTRAL DE ABASTECIMIENTO DEL SISTEMA NACIONAL DE SERVICIO DE SALUD',
#   'ARAMA NATURAL PRODUCTS DISTRIBUIDORA LIMITADA',
#   69),
#  ('CENTRAL DE ABASTECIMIENTO DEL SISTEMA NACIONAL DE SERVICIO DE SALUD',
#   'AREA PROYECTOS',
#   1),
#  ('CENTRAL DE ABASTECIMIENTO DEL SISTEMA NACIONAL DE SERVICIO DE SALUD',
#   'ARLAB S.A.',
#   2),
#  ('CENTRAL DE ABASTECIMIENTO DEL SISTEMA NACIONAL DE SERVICIO DE SALUD',
#   'ARTICULOS ESPECIALES SPA',
#   2),
#  ('CENTRAL DE ABASTECIMIENTO DEL SISTEMA NACIONAL DE SERVICIO DE SALUD',
#   'ARTMED LIMITADA',
#   2),
#  ('CENTRAL DE ABASTECIMIENTO DEL SISTEMA NACIONAL DE SERVICIO DE SALUD',
#   'ASPEN CHILE S.A',
#   5),
#  ('CENTRAL DE ABASTECIMIENTO DEL SISTEMA NACIONAL DE SERVICIO DE SALUD',
#   'Abbott Laboratories de Chile Ltda.',
#   35),
#  ('CENTRAL DE ABASTECIMIENTO DEL SISTEMA NACIONAL DE SERVICIO DE SALUD',
#   'Acrilandia',
#   2),
#  ('CENTRAL DE ABASTECIMIENTO DEL SISTEMA NACIONAL DE SERVICIO DE SALUD',
#   'All Test Limitada',
#   2),
#  ('CENTRAL DE ABASTECIMIENTO DEL SISTEMA NACIONAL DE SERVICIO DE SALUD',
#   'Allergan Laboratorios Ltda.',
#   11),
#  ('CENTRAL DE ABASTECIMIENTO DEL SISTEMA NACIONAL DE SERVICIO DE SALUD',
#   'Alpha Pharma Chile',
#   100),
#  ('CENTRAL DE ABASTECIMIENTO DEL SISTEMA NACIONAL DE SERVICIO DE SALUD',
#   'Alvaro Ramiro',
#   3),
#  ('CENTRAL DE ABASTECIMIENTO DEL SISTEMA NACIONAL DE SERVICIO DE SALUD',
#   'Ante',
#   1),
#  ('CENTRAL DE ABASTECIMIENTO DEL SISTEMA NACIONAL DE SERVICIO DE SALUD',
#   'Articulos Medicos y Quirurgicos Chile S.A.',
#   11),
#  ('CENTRAL DE ABASTECIMIENTO DEL SISTEMA NACIONAL DE SERVICIO DE SALUD',
#   'Ascend Laboratories SpA',
#   83),
#  ('CENTRAL DE ABASTECIMIENTO DEL SISTEMA NACIONAL DE SERVICIO DE SALUD',
#   'Asociación Chilena de Protección de la Familia',
#   1),
#  ('CENTRAL DE ABASTECIMIENTO DEL SISTEMA NACIONAL DE SERVICIO DE SALUD',
#   'AstraZeneca',
#   23),
#  ('CENTRAL DE ABASTECIMIENTO DEL SISTEMA NACIONAL DE SERVICIO DE SALUD',
#   'Astral S.A.',
#   1),
#  ('CENTRAL DE ABASTECIMIENTO DEL SISTEMA NACIONAL DE SERVICIO DE SALUD',
#   'Atrim limitada',
#   2),
#  ('CENTRAL DE ABASTECIMIENTO DEL SISTEMA NACIONAL DE SERVICIO DE SALUD',
#   'Avalon Chile',
#   1),
#  ('CENTRAL DE ABASTECIMIENTO DEL SISTEMA NACIONAL DE SERVICIO DE SALUD',
#   'B.BRAUN MEDICAL SpA',
#   53),
#  ('CENTRAL DE ABASTECIMIENTO DEL SISTEMA NACIONAL DE SERVICIO DE SALUD',
#   'B2G Chile (ex Distribuidora Insumos Medicos)',
#   1),
#  ('CENTRAL DE ABASTECIMIENTO DEL SISTEMA NACIONAL DE SERVICIO DE SALUD',
#   'BARBARA PAZ',
#   1),
#  ('CENTRAL DE ABASTECIMIENTO DEL SISTEMA NACIONAL DE SERVICIO DE SALUD',
#   'BAXTER CHILE LTDA.',
#   11),
#  ('CENTRAL DE ABASTECIMIENTO DEL SISTEMA NACIONAL DE SERVICIO DE SALUD',
#   'BEFORE PUBLICIDAD',
#   5),
#  ('CENTRAL DE ABASTECIMIENTO DEL SISTEMA NACIONAL DE SERVICIO DE SALUD',
#   'BIOCLIN S.A.',
#   3),
#  ('CENTRAL DE ABASTECIMIENTO DEL SISTEMA NACIONAL DE SERVICIO DE SALUD',
#   'BIOGEN  CHILE SpA',
#   1),
#  ('CENTRAL DE ABASTECIMIENTO DEL SISTEMA NACIONAL DE SERVICIO DE SALUD',
#   'BIOTEC CHILE S.A.',
#   1),
#  ('CENTRAL DE ABASTECIMIENTO DEL SISTEMA NACIONAL DE SERVICIO DE SALUD',
#   'BLUNDING S.A.',
#   8),
#  ('CENTRAL DE ABASTECIMIENTO DEL SISTEMA NACIONAL DE SERVICIO DE SALUD',
#   'BPH S.A',
#   71),
#  ('CENTRAL DE ABASTECIMIENTO DEL SISTEMA NACIONAL DE SERVICIO DE SALUD',
#   'BRANDING CORPORATIVO',
#   2),
#  ('CENTRAL DE ABASTECIMIENTO DEL SISTEMA NACIONAL DE SERVICIO DE SALUD',
#   'BRISTOL MYERS SQUIBB DE CHILE AGENC DE E R SQUIBB ',
#   7),
#  ('CENTRAL DE ABASTECIMIENTO DEL SISTEMA NACIONAL DE SERVICIO DE SALUD',
#   'BSN Medical',
#   21),
#  ('CENTRAL DE ABASTECIMIENTO DEL SISTEMA NACIONAL DE SERVICIO DE SALUD',
#   'BUHOS S.C.I. LTDA.',
#   13),
#  ('CENTRAL DE ABASTECIMIENTO DEL SISTEMA NACIONAL DE SERVICIO DE SALUD',
#   'BYD CARE',
#   2),
#  ('CENTRAL DE ABASTECIMIENTO DEL SISTEMA NACIONAL DE SERVICIO DE SALUD',
#   'Bayer SA',
#   15),
#  ('CENTRAL DE ABASTECIMIENTO DEL SISTEMA NACIONAL DE SERVICIO DE SALUD',
#   'Biomedika',
#   22),
#  ('CENTRAL DE ABASTECIMIENTO DEL SISTEMA NACIONAL DE SERVICIO DE SALUD',
#   'Biosupplies Group SpA',
#   1),
#  ('CENTRAL DE ABASTECIMIENTO DEL SISTEMA NACIONAL DE SERVICIO DE SALUD',
#   'Blubay',
#   1),
#  ('CENTRAL DE ABASTECIMIENTO DEL SISTEMA NACIONAL DE SERVICIO DE SALUD',
#   'Bluemedical Insumos',
#   8),
#  ('CENTRAL DE ABASTECIMIENTO DEL SISTEMA NACIONAL DE SERVICIO DE SALUD',
#   'Bluemedical SPA',
#   15),
#  ('CENTRAL DE ABASTECIMIENTO DEL SISTEMA NACIONAL DE SERVICIO DE SALUD',
#   'CASA DE MONEDA DE CHILE S.A.',
#   1),
#  ('CENTRAL DE ABASTECIMIENTO DEL SISTEMA NACIONAL DE SERVICIO DE SALUD',
#   'CASA MATRIZ',
#   2),
#  ('CENTRAL DE ABASTECIMIENTO DEL SISTEMA NACIONAL DE SERVICIO DE SALUD',
#   'CEGASURGICAL',
#   6),
#  ('CENTRAL DE ABASTECIMIENTO DEL SISTEMA NACIONAL DE SERVICIO DE SALUD',
#   'CELNOVA CHILE',
#   1),
#  ('CENTRAL DE ABASTECIMIENTO DEL SISTEMA NACIONAL DE SERVICIO DE SALUD',
#   'CHILE SAFETY E INSUMOS INDUSTRIALES SPA',
#   2),
#  ('CENTRAL DE ABASTECIMIENTO DEL SISTEMA NACIONAL DE SERVICIO DE SALUD',
#   'CILEF MEDICAL',
#   27),
#  ('CENTRAL DE ABASTECIMIENTO DEL SISTEMA NACIONAL DE SERVICIO DE SALUD',
#   'CIRUMED LIMITADA -  NEUMANN LIMITADA',
#   14),
#  ('CENTRAL DE ABASTECIMIENTO DEL SISTEMA NACIONAL DE SERVICIO DE SALUD',
#   'CLINICAL MARKET',
#   1),
#  ('CENTRAL DE ABASTECIMIENTO DEL SISTEMA NACIONAL DE SERVICIO DE SALUD',
#   'COHASA',
#   3),
#  ('CENTRAL DE ABASTECIMIENTO DEL SISTEMA NACIONAL DE SERVICIO DE SALUD',
#   'COMERCIAL A Y B S A',
#   15),
#  ('CENTRAL DE ABASTECIMIENTO DEL SISTEMA NACIONAL DE SERVICIO DE SALUD',
#   'COMERCIAL BETA',
#   1),
#  ('CENTRAL DE ABASTECIMIENTO DEL SISTEMA NACIONAL DE SERVICIO DE SALUD',
#   'COMERCIAL CBL LTDA',
#   1),
#  ('CENTRAL DE ABASTECIMIENTO DEL SISTEMA NACIONAL DE SERVICIO DE SALUD',
#   'COMERCIAL E INDUSTRIAL NOVA SEGURIDAD LIMITADA',
#   1),
#  ('CENTRAL DE ABASTECIMIENTO DEL SISTEMA NACIONAL DE SERVICIO DE SALUD',
#   'COMERCIAL OCTAVA LTDA',
#   1),
#  ('CENTRAL DE ABASTECIMIENTO DEL SISTEMA NACIONAL DE SERVICIO DE SALUD',
#   'COMERCIAL PARTNER SPA',
#   1),
#  ('CENTRAL DE ABASTECIMIENTO DEL SISTEMA NACIONAL DE SERVICIO DE SALUD',
#   'COMERCIAL VR LIMITADA',
#   1),
#  ('CENTRAL DE ABASTECIMIENTO DEL SISTEMA NACIONAL DE SERVICIO DE SALUD',
#   'COMERCIAL Y REPRESENTACIONES AUSTRAL LIMITADA',
#   1),
#  ('CENTRAL DE ABASTECIMIENTO DEL SISTEMA NACIONAL DE SERVICIO DE SALUD',
#   'CSL Behring SpA Chile',
#   10),
#  ('CENTRAL DE ABASTECIMIENTO DEL SISTEMA NACIONAL DE SERVICIO DE SALUD',
#   'CYDPHARMA LTDA.',
#   2),
#  ('CENTRAL DE ABASTECIMIENTO DEL SISTEMA NACIONAL DE SERVICIO DE SALUD',
#   'Caribean Pharma Ltda',
#   5),
#  ('CENTRAL DE ABASTECIMIENTO DEL SISTEMA NACIONAL DE SERVICIO DE SALUD',
#   'Carlos Ricardo',
#   1),
#  ('CENTRAL DE ABASTECIMIENTO DEL SISTEMA NACIONAL DE SERVICIO DE SALUD',
#   'Carpedent SpA',
#   1),
#  ('CENTRAL DE ABASTECIMIENTO DEL SISTEMA NACIONAL DE SERVICIO DE SALUD',
#   'Casa Matriz',
#   40),
#  ('CENTRAL DE ABASTECIMIENTO DEL SISTEMA NACIONAL DE SERVICIO DE SALUD',
#   'Casa Matriz FeelSecure',
#   3),
#  ('CENTRAL DE ABASTECIMIENTO DEL SISTEMA NACIONAL DE SERVICIO DE SALUD',
#   'CegaMed',
#   45),
#  ('CENTRAL DE ABASTECIMIENTO DEL SISTEMA NACIONAL DE SERVICIO DE SALUD',
#   'Cell Zion',
#   3),
#  ('CENTRAL DE ABASTECIMIENTO DEL SISTEMA NACIONAL DE SERVICIO DE SALUD',
#   'Cencomex S.A.',
#   13),
#  ('CENTRAL DE ABASTECIMIENTO DEL SISTEMA NACIONAL DE SERVICIO DE SALUD',
#   'Chemopharma S.A.',
#   10),
#  ('CENTRAL DE ABASTECIMIENTO DEL SISTEMA NACIONAL DE SERVICIO DE SALUD',
#   'Click Mall',
#   1),
#  ('CENTRAL DE ABASTECIMIENTO DEL SISTEMA NACIONAL DE SERVICIO DE SALUD',
#   'Comercial LBF Limitada',
#   7),
#  ('CENTRAL DE ABASTECIMIENTO DEL SISTEMA NACIONAL DE SERVICIO DE SALUD',
#   'Comercial Lubeck SPA',
#   2),
#  ('CENTRAL DE ABASTECIMIENTO DEL SISTEMA NACIONAL DE SERVICIO DE SALUD',
#   'Comercial MEVB',
#   1),
#  ('CENTRAL DE ABASTECIMIENTO DEL SISTEMA NACIONAL DE SERVICIO DE SALUD',
#   'Comercial Mar Azul SA.',
#   1),
#  ('CENTRAL DE ABASTECIMIENTO DEL SISTEMA NACIONAL DE SERVICIO DE SALUD',
#   'Comercial Nacional',
#   1),
#  ('CENTRAL DE ABASTECIMIENTO DEL SISTEMA NACIONAL DE SERVICIO DE SALUD',
#   'Comercial OPS',
#   1),
#  ('CENTRAL DE ABASTECIMIENTO DEL SISTEMA NACIONAL DE SERVICIO DE SALUD',
#   'Comercial Perez y Niklitschek Limitada',
#   2),
#  ('CENTRAL DE ABASTECIMIENTO DEL SISTEMA NACIONAL DE SERVICIO DE SALUD',
#   'Comercial San Fernando',
#   2),
#  ('CENTRAL DE ABASTECIMIENTO DEL SISTEMA NACIONAL DE SERVICIO DE SALUD',
#   'Comercializadora Diuana y Bercovich Ltda.',
#   2),
#  ('CENTRAL DE ABASTECIMIENTO DEL SISTEMA NACIONAL DE SERVICIO DE SALUD',
#   'Comercializadora Global Products Ltda.',
#   1),
#  ('CENTRAL DE ABASTECIMIENTO DEL SISTEMA NACIONAL DE SERVICIO DE SALUD',
#   'Comercializadora Pharmacosanté Ltda',
#   1),
#  ('CENTRAL DE ABASTECIMIENTO DEL SISTEMA NACIONAL DE SERVICIO DE SALUD',
#   'Comercializadora e Importadora Redvital.Ltda',
#   2),
#  ('CENTRAL DE ABASTECIMIENTO DEL SISTEMA NACIONAL DE SERVICIO DE SALUD',
#   'Comerciualizdora MTB',
#   1),
#  ('CENTRAL DE ABASTECIMIENTO DEL SISTEMA NACIONAL DE SERVICIO DE SALUD',
#   'Constructora Ferrol Ltda.',
#   2),
#  ('CENTRAL DE ABASTECIMIENTO DEL SISTEMA NACIONAL DE SERVICIO DE SALUD',
#   'Convatec',
#   8),
#  ('CENTRAL DE ABASTECIMIENTO DEL SISTEMA NACIONAL DE SERVICIO DE SALUD',
#   'Corleans',
#   4),
#  ('CENTRAL DE ABASTECIMIENTO DEL SISTEMA NACIONAL DE SERVICIO DE SALUD',
#   'Cramick S.A.',
#   1),
#  ('CENTRAL DE ABASTECIMIENTO DEL SISTEMA NACIONAL DE SERVICIO DE SALUD',
#   'Cristina Daniela',
#   1),
#  ('CENTRAL DE ABASTECIMIENTO DEL SISTEMA NACIONAL DE SERVICIO DE SALUD',
#   'Crisvert Limitada',
#   2),
#  ('CENTRAL DE ABASTECIMIENTO DEL SISTEMA NACIONAL DE SERVICIO DE SALUD',
#   'CyG Multitaller',
#   1),
#  ('CENTRAL DE ABASTECIMIENTO DEL SISTEMA NACIONAL DE SERVICIO DE SALUD',
#   'DELTAMED LIMITADA',
#   1),
#  ('CENTRAL DE ABASTECIMIENTO DEL SISTEMA NACIONAL DE SERVICIO DE SALUD',
#   'DETERCO SpA',
#   33),
#  ('CENTRAL DE ABASTECIMIENTO DEL SISTEMA NACIONAL DE SERVICIO DE SALUD',
#   'DFM PHARMA SPA',
#   13),
#  ('CENTRAL DE ABASTECIMIENTO DEL SISTEMA NACIONAL DE SERVICIO DE SALUD',
#   'DIFEM LABORATORIOS S A',
#   58),
#  ('CENTRAL DE ABASTECIMIENTO DEL SISTEMA NACIONAL DE SERVICIO DE SALUD',
#   'DIMERC S.A.',
#   3),
#  ('CENTRAL DE ABASTECIMIENTO DEL SISTEMA NACIONAL DE SERVICIO DE SALUD',
#   'DISTRIBUIDORA QUALIMED LIMITADA',
#   5),
#  ('CENTRAL DE ABASTECIMIENTO DEL SISTEMA NACIONAL DE SERVICIO DE SALUD',
#   'DISTRIBUIDORA ROYAL CHILE SPA',
#   9),
#  ('CENTRAL DE ABASTECIMIENTO DEL SISTEMA NACIONAL DE SERVICIO DE SALUD',
#   'DISTRIPHAR SPA',
#   3),
#  ('CENTRAL DE ABASTECIMIENTO DEL SISTEMA NACIONAL DE SERVICIO DE SALUD',
#   'DKT Chile SpA',
#   1),
#  ('CENTRAL DE ABASTECIMIENTO DEL SISTEMA NACIONAL DE SERVICIO DE SALUD',
#   "DR REDDY'S LABORATORIES CHILE SpA",
#   19),
#  ('CENTRAL DE ABASTECIMIENTO DEL SISTEMA NACIONAL DE SERVICIO DE SALUD',
#   'DROGUERIA FARMOQUIMICA DEL PACIFICO LTDA',
#   3),
#  ('CENTRAL DE ABASTECIMIENTO DEL SISTEMA NACIONAL DE SERVICIO DE SALUD',
#   'DROGUERIA GLOBAL PHARMA SPA',
#   33),
#  ('CENTRAL DE ABASTECIMIENTO DEL SISTEMA NACIONAL DE SERVICIO DE SALUD',
#   'Dagoway Trade Ltda',
#   1),
#  ('CENTRAL DE ABASTECIMIENTO DEL SISTEMA NACIONAL DE SERVICIO DE SALUD',
#   'Defense & Security',
#   1),
#  ('CENTRAL DE ABASTECIMIENTO DEL SISTEMA NACIONAL DE SERVICIO DE SALUD',
#   'DelPilarLtda',
#   2),
#  ('CENTRAL DE ABASTECIMIENTO DEL SISTEMA NACIONAL DE SERVICIO DE SALUD',
#   'Delex Ltda.',
#   1),
#  ('CENTRAL DE ABASTECIMIENTO DEL SISTEMA NACIONAL DE SERVICIO DE SALUD',
#   'Deutsche Pharma',
#   11),
#  ('CENTRAL DE ABASTECIMIENTO DEL SISTEMA NACIONAL DE SERVICIO DE SALUD',
#   'Diprovet',
#   10),
#  ('CENTRAL DE ABASTECIMIENTO DEL SISTEMA NACIONAL DE SERVICIO DE SALUD',
#   'Dispositivos Médicos',
#   2),
#  ('CENTRAL DE ABASTECIMIENTO DEL SISTEMA NACIONAL DE SERVICIO DE SALUD',
#   'Distribuidora Papeles Industriales SPA',
#   5),
#  ('CENTRAL DE ABASTECIMIENTO DEL SISTEMA NACIONAL DE SERVICIO DE SALUD',
#   'Dolphin Medical',
#   12),
# ...
#   'SOTECNO MEDICAL',
#   6),
#  ('CENTRAL DE ABASTECIMIENTO DEL SISTEMA NACIONAL DE SERVICIO DE SALUD',
#   'SOUTH TRADE MARKETING LTDA',
#   3),
#  ('CENTRAL DE ABASTECIMIENTO DEL SISTEMA NACIONAL DE SERVICIO DE SALUD',
#   'SURMASK',
#   1),
#  ('CENTRAL DE ABASTECIMIENTO DEL SISTEMA NACIONAL DE SERVICIO DE SALUD',
#   'SYH SpA',
#   1),
#  ('CENTRAL DE ABASTECIMIENTO DEL SISTEMA NACIONAL DE SERVICIO DE SALUD',
#   'SYNTHON CHILE LTDA.',
#   6),
#  ('CENTRAL DE ABASTECIMIENTO DEL SISTEMA NACIONAL DE SERVICIO DE SALUD',
#   'Schonfeldt Vidamedica SpA',
#   11),
#  ('CENTRAL DE ABASTECIMIENTO DEL SISTEMA NACIONAL DE SERVICIO DE SALUD',
#   'Servicios industriales',
#   1),
#  ('CENTRAL DE ABASTECIMIENTO DEL SISTEMA NACIONAL DE SERVICIO DE SALUD',
#   'Seven Pharma Chile',
#   1),
#  ('CENTRAL DE ABASTECIMIENTO DEL SISTEMA NACIONAL DE SERVICIO DE SALUD',
#   'Soc. Com. de Productos de Segu - Santiago',
#   1),
#  ('CENTRAL DE ABASTECIMIENTO DEL SISTEMA NACIONAL DE SERVICIO DE SALUD',
#   'Sociedad Comercial Oficinta Ltda.',
#   1),
#  ('CENTRAL DE ABASTECIMIENTO DEL SISTEMA NACIONAL DE SERVICIO DE SALUD',
#   'Sociedad Comercial Seri SpA',
#   2),
#  ('CENTRAL DE ABASTECIMIENTO DEL SISTEMA NACIONAL DE SERVICIO DE SALUD',
#   'Sociedad Comercializadora De Cuadros',
#   1),
#  ('CENTRAL DE ABASTECIMIENTO DEL SISTEMA NACIONAL DE SERVICIO DE SALUD',
#   'Sociedad Procesadora de Leche del Sur S.A.',
#   20),
#  ('CENTRAL DE ABASTECIMIENTO DEL SISTEMA NACIONAL DE SERVICIO DE SALUD',
#   'Socofar Division Munnich',
#   22),
#  ('CENTRAL DE ABASTECIMIENTO DEL SISTEMA NACIONAL DE SERVICIO DE SALUD',
#   'Soluciones Médicas SPA',
#   14),
#  ('CENTRAL DE ABASTECIMIENTO DEL SISTEMA NACIONAL DE SERVICIO DE SALUD',
#   'Spartan de Chile RM',
#   1),
#  ('CENTRAL DE ABASTECIMIENTO DEL SISTEMA NACIONAL DE SERVICIO DE SALUD',
#   'Strenuus Medical Ltd. Drogas Huerfanas',
#   5),
#  ('CENTRAL DE ABASTECIMIENTO DEL SISTEMA NACIONAL DE SERVICIO DE SALUD',
#   'TAUPACK',
#   1),
#  ('CENTRAL DE ABASTECIMIENTO DEL SISTEMA NACIONAL DE SERVICIO DE SALUD',
#   'TECMEDENT LTDA.',
#   1),
#  ('CENTRAL DE ABASTECIMIENTO DEL SISTEMA NACIONAL DE SERVICIO DE SALUD',
#   'TECNOPLANTA',
#   2),
#  ('CENTRAL DE ABASTECIMIENTO DEL SISTEMA NACIONAL DE SERVICIO DE SALUD',
#   'TESLA SPA',
#   1),
#  ('CENTRAL DE ABASTECIMIENTO DEL SISTEMA NACIONAL DE SERVICIO DE SALUD',
#   'TEVEUCI',
#   4),
#  ('CENTRAL DE ABASTECIMIENTO DEL SISTEMA NACIONAL DE SERVICIO DE SALUD',
#   'TEXAL LTDA.',
#   1),
#  ('CENTRAL DE ABASTECIMIENTO DEL SISTEMA NACIONAL DE SERVICIO DE SALUD',
#   'TEXTIL SUPER',
#   6),
#  ('CENTRAL DE ABASTECIMIENTO DEL SISTEMA NACIONAL DE SERVICIO DE SALUD',
#   'TEXTILES BINA LTDA',
#   1),
#  ('CENTRAL DE ABASTECIMIENTO DEL SISTEMA NACIONAL DE SERVICIO DE SALUD',
#   'TOPOFFICE',
#   1),
#  ('CENTRAL DE ABASTECIMIENTO DEL SISTEMA NACIONAL DE SERVICIO DE SALUD',
#   'TRANSPORTES GLOBOBELLO',
#   1),
#  ('CENTRAL DE ABASTECIMIENTO DEL SISTEMA NACIONAL DE SERVICIO DE SALUD',
#   'TRANSPORTES SANTIAGO S.A.',
#   1),
#  ('CENTRAL DE ABASTECIMIENTO DEL SISTEMA NACIONAL DE SERVICIO DE SALUD',
#   'Takeda Chile',
#   4),
#  ('CENTRAL DE ABASTECIMIENTO DEL SISTEMA NACIONAL DE SERVICIO DE SALUD',
#   'Tech-K',
#   2),
#  ('CENTRAL DE ABASTECIMIENTO DEL SISTEMA NACIONAL DE SERVICIO DE SALUD',
#   'Tecnika S.A.',
#   26),
#  ('CENTRAL DE ABASTECIMIENTO DEL SISTEMA NACIONAL DE SERVICIO DE SALUD',
#   'Tecnofarma S.A.',
#   64),
#  ('CENTRAL DE ABASTECIMIENTO DEL SISTEMA NACIONAL DE SERVICIO DE SALUD',
#   'Textiles Zahr S.A.',
#   13),
#  ('CENTRAL DE ABASTECIMIENTO DEL SISTEMA NACIONAL DE SERVICIO DE SALUD',
#   'Therapía iv',
#   8),
#  ('CENTRAL DE ABASTECIMIENTO DEL SISTEMA NACIONAL DE SERVICIO DE SALUD',
#   'Treck S.A.',
#   2),
#  ('CENTRAL DE ABASTECIMIENTO DEL SISTEMA NACIONAL DE SERVICIO DE SALUD',
#   'Trema',
#   8),
#  ('CENTRAL DE ABASTECIMIENTO DEL SISTEMA NACIONAL DE SERVICIO DE SALUD',
#   'UNIFARMA SPA',
#   3),
#  ('CENTRAL DE ABASTECIMIENTO DEL SISTEMA NACIONAL DE SERVICIO DE SALUD',
#   'V Exponencial',
#   1),
#  ('CENTRAL DE ABASTECIMIENTO DEL SISTEMA NACIONAL DE SERVICIO DE SALUD',
#   'VESTCLIN',
#   3),
#  ('CENTRAL DE ABASTECIMIENTO DEL SISTEMA NACIONAL DE SERVICIO DE SALUD',
#   'VITAFARMA S A',
#   19),
#  ('CENTRAL DE ABASTECIMIENTO DEL SISTEMA NACIONAL DE SERVICIO DE SALUD',
#   'VITALSEC SPA',
#   1),
#  ('CENTRAL DE ABASTECIMIENTO DEL SISTEMA NACIONAL DE SERVICIO DE SALUD',
#   'Vesalius Pharma',
#   3),
#  ('CENTRAL DE ABASTECIMIENTO DEL SISTEMA NACIONAL DE SERVICIO DE SALUD',
#   'Viaimport',
#   3),
#  ('CENTRAL DE ABASTECIMIENTO DEL SISTEMA NACIONAL DE SERVICIO DE SALUD',
#   'Vitasystem Ltda',
#   2),
#  ('CENTRAL DE ABASTECIMIENTO DEL SISTEMA NACIONAL DE SERVICIO DE SALUD',
#   'WATT´S S.A.',
#   20),
#  ('CENTRAL DE ABASTECIMIENTO DEL SISTEMA NACIONAL DE SERVICIO DE SALUD',
#   'WESERVE',
#   2),
#  ('CENTRAL DE ABASTECIMIENTO DEL SISTEMA NACIONAL DE SERVICIO DE SALUD',
#   'WINDBELL',
#   2),
#  ('CENTRAL DE ABASTECIMIENTO DEL SISTEMA NACIONAL DE SERVICIO DE SALUD',
#   'WINPHARM',
#   28),
#  ('CENTRAL DE ABASTECIMIENTO DEL SISTEMA NACIONAL DE SERVICIO DE SALUD',
#   'WINTEC',
#   5),
#  ('CENTRAL DE ABASTECIMIENTO DEL SISTEMA NACIONAL DE SERVICIO DE SALUD',
#   'WORKFLOW CHILE LTDA',
#   1),
#  ('CENTRAL DE ABASTECIMIENTO DEL SISTEMA NACIONAL DE SERVICIO DE SALUD',
#   'Winflex Spa',
#   8),
#  ('CENTRAL DE ABASTECIMIENTO DEL SISTEMA NACIONAL DE SERVICIO DE SALUD',
#   'ZERICUM',
#   1),
#  ('CENTRAL DE ABASTECIMIENTO DEL SISTEMA NACIONAL DE SERVICIO DE SALUD',
#   'Zona Eco',
#   3),
#  ('CENTRAL DE ABASTECIMIENTO DEL SISTEMA NACIONAL DE SERVICIO DE SALUD',
#   'apro ltda. - Casa Matriz',
#   11),
#  ('CENTRAL DE ABASTECIMIENTO DEL SISTEMA NACIONAL DE SERVICIO DE SALUD',
#   'ceter',
#   2),
#  ('CENTRAL DE ABASTECIMIENTO DEL SISTEMA NACIONAL DE SERVICIO DE SALUD',
#   'comercial BJ',
#   14),
#  ('CENTRAL DE ABASTECIMIENTO DEL SISTEMA NACIONAL DE SERVICIO DE SALUD',
#   'cooperquim',
#   1),
#  ('CENTRAL DE ABASTECIMIENTO DEL SISTEMA NACIONAL DE SERVICIO DE SALUD',
#   'globalmed',
#   22),
#  ('CENTRAL DE ABASTECIMIENTO DEL SISTEMA NACIONAL DE SERVICIO DE SALUD',
#   'innovative medicines s.a. agencia en chile',
#   8),
#  ('CENTRAL DE ABASTECIMIENTO DEL SISTEMA NACIONAL DE SERVICIO DE SALUD',
#   'juan carlos becerra',
#   1),
#  ('CENTRAL DE ABASTECIMIENTO DEL SISTEMA NACIONAL DE SERVICIO DE SALUD',
#   'juan luis',
#   1),
#  ('CENTRAL DE ABASTECIMIENTO DEL SISTEMA NACIONAL DE SERVICIO DE SALUD',
#   'kAREM ALEJANDRA',
#   1),
#  ('CENTRAL DE ABASTECIMIENTO DEL SISTEMA NACIONAL DE SERVICIO DE SALUD',
#   'kanekalon',
#   1),
#  ('CENTRAL DE ABASTECIMIENTO DEL SISTEMA NACIONAL DE SERVICIO DE SALUD',
#   'mcsa',
#   1),
#  ('CENTRAL DE ABASTECIMIENTO DEL SISTEMA NACIONAL DE SERVICIO DE SALUD',
#   'plasticceron',
#   1),
#  ('CENTRAL DE ABASTECIMIENTO DEL SISTEMA NACIONAL DE SERVICIO DE SALUD',
#   'prodesa',
#   2),
#  ('CENTRAL DE ABASTECIMIENTO DEL SISTEMA NACIONAL DE SERVICIO DE SALUD',
#   'valeska',
#   5),
#  ('CENTRAL DE ABASTECIMIENTO DEL SISTEMA NACIONAL DE SERVICIO DE SALUD',
#   'vento servicios integrales',
#   7),
#  ('CENTRAL DE ABASTECIMIENTO DEL SISTEMA NACIONAL DE SERVICIO DE SALUD',
#   'winkler limitada',
#   4),
#  ('CENTRO DE ESPECIALIDAD  DE ATENCION PREHOSPITALARIA SAMU BIO BIO',
#   'AEROCARDAL LTDA',
#   1),
#  ('CENTRO DE ESPECIALIDAD  DE ATENCION PREHOSPITALARIA SAMU BIO BIO',
#   'AdjudicaChile Consultora en Licitaciones Públicas',
#   1),
#  ('CENTRO DE ESPECIALIDAD  DE ATENCION PREHOSPITALARIA SAMU BIO BIO',
#   'Alejandro Antonio ',
#   2),
#  ('CENTRO DE ESPECIALIDAD  DE ATENCION PREHOSPITALARIA SAMU BIO BIO',
#   'Bioscam SpA',
#   1),
#  ('CENTRO DE ESPECIALIDAD  DE ATENCION PREHOSPITALARIA SAMU BIO BIO',
#   'CASA ÑUBLE',
#   1),
#  ('CENTRO DE ESPECIALIDAD  DE ATENCION PREHOSPITALARIA SAMU BIO BIO',
#   'ELECTRO-CONT',
#   3),
#  ('CENTRO DE ESPECIALIDAD  DE ATENCION PREHOSPITALARIA SAMU BIO BIO',
#   'ELIO',
#   2),
#  ('CENTRO DE ESPECIALIDAD  DE ATENCION PREHOSPITALARIA SAMU BIO BIO',
#   'FT CORREDORES DE SEGUROS SPA',
#   1),
#  ('CENTRO DE ESPECIALIDAD  DE ATENCION PREHOSPITALARIA SAMU BIO BIO',
#   'GOLDEN MEDICAL SOLUTIONS',
#   1),
#  ('CENTRO DE ESPECIALIDAD  DE ATENCION PREHOSPITALARIA SAMU BIO BIO',
#   'Global manejo Integrado de Plagas',
#   1),
#  ('CENTRO DE ESPECIALIDAD  DE ATENCION PREHOSPITALARIA SAMU BIO BIO',
#   'INDURA MEDICA',
#   1),
#  ('CENTRO DE ESPECIALIDAD  DE ATENCION PREHOSPITALARIA SAMU BIO BIO',
#   'LASSA',
#   1),
#  ('CENTRO DE ESPECIALIDAD  DE ATENCION PREHOSPITALARIA SAMU BIO BIO',
#   'MERCSOLUCIONES LTDA',
#   1),
#  ('CENTRO DE ESPECIALIDAD  DE ATENCION PREHOSPITALARIA SAMU BIO BIO',
#   'Medex Ltda',
#   1),
#  ('CENTRO DE ESPECIALIDAD  DE ATENCION PREHOSPITALARIA SAMU BIO BIO',
#   'Plaguigen',
#   1),
#  ('CENTRO DE ESPECIALIDAD  DE ATENCION PREHOSPITALARIA SAMU BIO BIO',
#   'Remodela10',
#   1),
#  ('CENTRO DE ESPECIALIDAD  DE ATENCION PREHOSPITALARIA SAMU BIO BIO',
#   'SEGUROS SURA CASA MATRIZ',
#   1),
#  ('CENTRO DE ESPECIALIDAD  DE ATENCION PREHOSPITALARIA SAMU BIO BIO',
#   'SOCIEDAD TRANSPORTE AEROMEDICO CRITICTO LIMITADA',
#   1),
#  ('CENTRO DE ESPECIALIDAD  DE ATENCION PREHOSPITALARIA SAMU BIO BIO',
#   'Urrutia Henriquez',
#   2),
#  ('CENTRO DE ESPECIALIDAD  DE ATENCION PREHOSPITALARIA SAMU BIO BIO',
#   'controlplagasur spa',
#   1),
#  ('CENTRO DE ESPECIALIDAD  DE ATENCION PREHOSPITALARIA SAMU BIO BIO',
#   'sociedad comercial bernasconi y ruiz ltda.',
#   1),
#  ('CENTRO DE FORMACION TECNICA DE LA REGION DE ATACAMA', 'MIGUEL ANGEL', 1),
#  ('CENTRO DE FORMACION TECNICA DE LA REGION DE COQUIMBO', 'ARQUITECTURA', 1),
#  ('CENTRO DE FORMACION TECNICA DE LA REGION DE COQUIMBO',
#   'AdjudicaChile Consultora en Licitaciones Públicas',
#   1),
#  ('CENTRO DE FORMACION TECNICA DE LA REGION DE COQUIMBO',
#   'BANCO SANTANDER CHILE',
#   1),
#  ('CENTRO DE FORMACION TECNICA DE LA REGION DE COQUIMBO', 'COSUD S.A.', 1),
#  ('CENTRO DE FORMACION TECNICA DE LA REGION DE COQUIMBO', 'EWARE', 2),
#  ('CENTRO DE FORMACION TECNICA DE LA REGION DE COQUIMBO', 'Elvis Franklin', 1),
#  ('CENTRO DE FORMACION TECNICA DE LA REGION DE COQUIMBO',
#   'Empresa Constructora',
#   1),
#  ('CENTRO DE FORMACION TECNICA DE LA REGION DE COQUIMBO',
#   'Gonzalo E Villanueva Rolland',
#   1),
#  ('CENTRO DE FORMACION TECNICA DE LA REGION DE COQUIMBO', 'Ingsernor', 1),
#  ('CENTRO DE FORMACION TECNICA DE LA REGION DE COQUIMBO',
#   'Plataforma Municipalidades',
#   1),
#  ('CENTRO DE FORMACION TECNICA DE LA REGION DE COQUIMBO', 'RODRIGO ANDRES', 1),
#  ('CENTRO DE FORMACION TECNICA DE LA REGION DE COQUIMBO',
#   'SERVICIOS DE INGENIERÍA Y CONSTRUCCIÓN URQUIETA L.',
#   1),
#  ('CENTRO DE FORMACION TECNICA DE LA REGION DE COQUIMBO', 'Samy Chile', 2),
#  ('CENTRO DE FORMACION TECNICA DE LA REGION DE COQUIMBO', 'm+e', 2),
#  ('CENTRO DE FORMACION TECNICA DE LA REGION DE LA ARAUCANIA',
#   'ARTL CHILE AUDITORES SPA',
#   1),
#  ('CENTRO DE FORMACION TECNICA DE LA REGION DE LA ARAUCANIA',
#   'Alba Ambiente S.A',
#   6),
#  ('CENTRO DE FORMACION TECNICA DE LA REGION DE LA ARAUCANIA',
#   'Avanza Bio LTDA',
#   21),
#  ('CENTRO DE FORMACION TECNICA DE LA REGION DE LA ARAUCANIA',
#   'BAKER TILLY CHILE AUDITORES CONSULTORES LIMITADA',
#   1),
#  ('CENTRO DE FORMACION TECNICA DE LA REGION DE LA ARAUCANIA', 'BDO Temuco', 1),
#  ('CENTRO DE FORMACION TECNICA DE LA REGION DE LA ARAUCANIA',
#   'BERGENTEMUCO',
#   26),
#  ('CENTRO DE FORMACION TECNICA DE LA REGION DE LA ARAUCANIA',
#   'CYSCONSULTING',
#   1),
#  ('CENTRO DE FORMACION TECNICA DE LA REGION DE LA ARAUCANIA', 'Camilo', 20),
#  ('CENTRO DE FORMACION TECNICA DE LA REGION DE LA ARAUCANIA',
#   'Consultores y Auditores de Empresas Ltda.',
#   1),
#  ('CENTRO DE FORMACION TECNICA DE LA REGION DE LA ARAUCANIA',
#   'Draeger Medical Limitada',
#   2),
#  ('CENTRO DE FORMACION TECNICA DE LA REGION DE LA ARAUCANIA',
#   'ERF CHILE AUDITORES - CONSULTORES LIMITADA',
#   1),
#  ('CENTRO DE FORMACION TECNICA DE LA REGION DE LA ARAUCANIA', 'Easylit', 2),
#  ('CENTRO DE FORMACION TECNICA DE LA REGION DE LA ARAUCANIA',
#   'Facus Chile SpA',
#   26),
#  ('CENTRO DE FORMACION TECNICA DE LA REGION DE LA ARAUCANIA',
#   'Fortunato y Asociados ',
#   2),
#  ('CENTRO DE FORMACION TECNICA DE LA REGION DE LA ARAUCANIA',
#   'Hdi Seguros S.A. - Temuco',
#   1),
#  ('CENTRO DE FORMACION TECNICA DE LA REGION DE LA ARAUCANIA',
#   'INVERSIONES TI SPA',
#   60),
#  ('CENTRO DE FORMACION TECNICA DE LA REGION DE LA ARAUCANIA',
#   'Ludwig Konrad',
#   23),
#  ('CENTRO DE FORMACION TECNICA DE LA REGION DE LA ARAUCANIA',
#   'Luis Fernando',
#   1),
#  ('CENTRO DE FORMACION TECNICA DE LA REGION DE LA ARAUCANIA',
#   'MANAGER SOFTWARE S A',
#   1),
#  ('CENTRO DE FORMACION TECNICA DE LA REGION DE LA ARAUCANIA',
#   'Manuel Rodolfo',
#   13),
#  ('CENTRO DE FORMACION TECNICA DE LA REGION DE LA ARAUCANIA',
#   'Mapfre Seguros de Chile S.A. ',
#   1),
#  ('CENTRO DE FORMACION TECNICA DE LA REGION DE LA ARAUCANIA',
#   'Maxwell ingeniería eléctrica y automatización',
#   31),
#  ('CENTRO DE FORMACION TECNICA DE LA REGION DE LA ARAUCANIA',
#   'Misael Exequiel Candia Jara',
#   1),
#  ('CENTRO DE FORMACION TECNICA DE LA REGION DE LA ARAUCANIA',
#   'OH-PROTRUST SPA',
#   11),
#  ('CENTRO DE FORMACION TECNICA DE LA REGION DE LA ARAUCANIA',
#   'Promotec Limitada',
#   5),
#  ('CENTRO DE FORMACION TECNICA DE LA REGION DE LA ARAUCANIA',
#   'RUPERTO ESCOBAR VICTORIANO',
#   3),
#  ('CENTRO DE FORMACION TECNICA DE LA REGION DE LA ARAUCANIA',
#   'SOCIEDAD CONSTRUCTORA PELLAHUEN LTDA.',
#   1),
#  ('CENTRO DE FORMACION TECNICA DE LA REGION DE LA ARAUCANIA',
#   'SURLATINA AUDITORES LTDA.',
#   1),
#  ('CENTRO DE FORMACION TECNICA DE LA REGION DE LA ARAUCANIA',
#   'Sivetec Ltda.',
#   8),
#  ('CENTRO DE FORMACION TECNICA DE LA REGION DE LA ARAUCANIA',
#   'TELCOMT LIMITADA',
#   6),
#  ('CENTRO DE FORMACION TECNICA DE LA REGION DE LA ARAUCANIA',
#   'bike red machine spa',
#   3),
#  ('CENTRO DE FORMACION TECNICA DE LA REGION DE LA ARAUCANIA', 'brauer', 26),
#  ('CENTRO DE FORMACION TECNICA DE LA REGION DE LA ARAUCANIA', 'colala', 1),
#  ('CENTRO DE FORMACION TECNICA DE LA REGION DE LA ARAUCANIA', 'mar ltda ', 24),
#  ('CENTRO DE FORMACION TECNICA DE LA REGION DE LA ARAUCANIA',
#   'resein chile',
#   3),
#  ('CENTRO DE FORMACION TECNICA DE LA REGION DE TARAPACA', 'AMW1', 6),
#  ('CENTRO DE FORMACION TECNICA DE LA REGION DE TARAPACA', 'ANA MARLENE', 1),
#  ('CENTRO DE FORMACION TECNICA DE LA REGION DE TARAPACA',
#   'APPLUS CERTIFICATION',
#   1),
#  ('CENTRO DE FORMACION TECNICA DE LA REGION DE TARAPACA',
#   'Alba Ambiente S.A',
#   1),
#  ('CENTRO DE FORMACION TECNICA DE LA REGION DE TARAPACA',
#   'Almaro Operaciones',
#   81),
#  ('CENTRO DE FORMACION TECNICA DE LA REGION DE TARAPACA',
#   'Anker Ingeniería Ltda.',
#   1),
#  ('CENTRO DE FORMACION TECNICA DE LA REGION DE TARAPACA', 'Boris Henry', 1),
#  ('CENTRO DE FORMACION TECNICA DE LA REGION DE TARAPACA',
#   'Bureau Veritas Certification',
#   1),
#  ('CENTRO DE FORMACION TECNICA DE LA REGION DE TARAPACA',
#   'CARLOS ALEJANDRO',
#   23),
#  ('CENTRO DE FORMACION TECNICA DE LA REGION DE TARAPACA',
#   'COMUNICACIONES MIA LIMITADA - Casa Matriz',
#   1),
#  ('CENTRO DE FORMACION TECNICA DE LA REGION DE TARAPACA', 'Camilo', 55),
#  ('CENTRO DE FORMACION TECNICA DE LA REGION DE TARAPACA', 'Certhia SpA', 1),
#  ('CENTRO DE FORMACION TECNICA DE LA REGION DE TARAPACA', 'Chilemat SpA', 53),
#  ('CENTRO DE FORMACION TECNICA DE LA REGION DE TARAPACA', 'Claudio', 1),
#  ('CENTRO DE FORMACION TECNICA DE LA REGION DE TARAPACA',
#   'EKIPOTEL CHILE S.A.',
#   3),
#  ('CENTRO DE FORMACION TECNICA DE LA REGION DE TARAPACA', 'Eshia Ltda.', 29),
#  ('CENTRO DE FORMACION TECNICA DE LA REGION DE TARAPACA',
#   'Fortunato y Asociados ',
#   1),
#  ('CENTRO DE FORMACION TECNICA DE LA REGION DE TARAPACA',
#   'GAA Ingeniería y Proyectos Ltda.',
#   1),
#  ('CENTRO DE FORMACION TECNICA DE LA REGION DE TARAPACA', 'GINNA PAOLA', 1),
#  ('CENTRO DE FORMACION TECNICA DE LA REGION DE TARAPACA', 'GOAR ltda', 1),
#  ('CENTRO DE FORMACION TECNICA DE LA REGION DE TARAPACA',
#   'GSB Servicios Generales',
#   1),
#  ('CENTRO DE FORMACION TECNICA DE LA REGION DE TARAPACA',
#   'Harro Industrial y Energías',
#   23),
#  ('CENTRO DE FORMACION TECNICA DE LA REGION DE TARAPACA',
#   'Imp. Dist. Arquimed Ltda.',
#   6),
#  ('CENTRO DE FORMACION TECNICA DE LA REGION DE TARAPACA', 'Improfor Ltda', 12),
#  ('CENTRO DE FORMACION TECNICA DE LA REGION DE TARAPACA', 'Mainz Medical', 3),
#  ('CENTRO DE FORMACION TECNICA DE LA REGION DE TARAPACA', 'Manuel Rodolfo', 2),
#  ('CENTRO DE FORMACION TECNICA DE LA REGION DE TARAPACA',
#   'Medical Factory SpA',
#   15),
#  ('CENTRO DE FORMACION TECNICA DE LA REGION DE TARAPACA',
#   'OH-PROTRUST SPA',
#   24),
#  ...]

# %%
len(lista_tuplas_pesos)
# Out:
# 213920

# %% [markdown]
# #### Construcción del Grafo

# %%
G = nx.Graph()

# %%
G.add_nodes_from(lista_empresas, bipartite=0)
G.add_nodes_from(lista_organismos,bipartite=1)

# %%
G.add_weighted_edges_from(lista_tuplas_pesos)

# %%
bipartite.is_bipartite(G)
# Out:
# True

# %%
nx.density(G)
# Out:
# 0.00027401125624970494

# %%
import matplotlib.pyplot as plt
from matplotlib import cm
plt.figure(figsize=(25, 15))

# %%
from community import community_louvain

partition = community_louvain.best_partition(G)

size = (len(set(partition.values())))#Numero de comunidades
print('Se detectan %d comunidades' % (size))
# Out:
# Se detectan 14 comunidades

# %%
d = {}
for character, par in partition.items():
    if par in d:
        d[par].append(character)
    else:
        d[par] = [character]

# %%
for i in range(len(d)):
    print(f'Tamaño Comunidad {i}: {len(d[i])}')
# Out:
# Tamaño Comunidad 0: 3033
# Tamaño Comunidad 1: 2067
# Tamaño Comunidad 2: 8800
# Tamaño Comunidad 3: 54
# Tamaño Comunidad 4: 3266
# Tamaño Comunidad 5: 4
# Tamaño Comunidad 6: 5627
# Tamaño Comunidad 7: 3227
# Tamaño Comunidad 8: 5202
# Tamaño Comunidad 9: 7431
# Tamaño Comunidad 10: 7
# Tamaño Comunidad 11: 560
# Tamaño Comunidad 12: 236
# Tamaño Comunidad 13: 1

# %%
pos = nx.spring_layout(G) # Layout para la red (coordenadas de los nodos y enlaces)

# %%
#pos

# %%
len(pos)
# Out:
# 39515

# %%
len(lista_organismos)+len(lista_empresas)
# Out:
# 39515

# %%
count = 0
colors = [np.array(cm.jet(x)).reshape(1,-1) for x in np.linspace(0, 1, size)]#cm.jet es el mapa de colores https://www.programcreek.com/python/example/56498/matplotlib.cm.jet

# %%
for com in set(partition.values()): #para cada comunidad
    list_nodes = [nodes for nodes in partition.keys() if partition[nodes] == com]#guarda los personajes que pertenecen a la comunidad `com`
    nx.draw_networkx_nodes(G, pos, list_nodes, node_size = 2, node_color=colors[count])#plotea nodos con colors por comunidad
    count = count + 1# para iterar sobre los colores
nx.draw_networkx_edges(G, pos, alpha=0.2)#plotea enlaces
plt.show()
