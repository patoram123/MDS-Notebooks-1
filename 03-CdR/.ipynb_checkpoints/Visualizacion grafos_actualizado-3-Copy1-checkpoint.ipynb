# %% [markdown]
# # Hackaton Ciencias de Redes
# ## Grupo 5
# - #### Patricio Ramirez
# - #### Carlos Bustamante
# - #### Victor Ortiz
# - #### Pablo Elgueta
#
# ## Tarea
#
# #### Objetivo General:
#     Determinar patrones potenciales de corrupción en compras públicas en Chile. Para esto, se disponibilizarán los datos de todos las licitaciones públicas en Chile entre 2014 y 2021. Deben elegir un periodo a estudiar y que los datos son pesados.
#
# #### 1) Análisis Exploratorio:
#     Puede incluir histogramas, relaciones bivariadas, correlaciones (coeficientes y figuras), etc.
# #### 2) Inferencia red:
#     Red bipartita, proyección unimodal de la red bipartita, modelos nulos para filtrar (phi correlation, randomización preservando grado, etc)
# #### 3) Descripción de la red:
#     Distribución de grados (antes y despues de filtrar), gráfico grado de nodo vs coeficiente de clustering, diámetro de la red, número de nodos, número de enlaces, densidad. Detección de comunidades, etc.
# #### 4) Identifiación de patrones de corrupción en la red:
#     El trabajo es abierto en términos de identificación de patrones, sin embargo, pueden usar lo siguiente:
# - 1) Índice de diversidad de simpson por comunidad (ver referencia 1)
# - 2) índice de entropía del buyer (oferente) (ver referncia 2)
# - 3) Licitaciones con solo 1 bider (ofertante) (ver referencia 1 y 2) [esto es uno de los indicadores de potencial
# riesgo de corrupción, ver CRI referencia 2 y 3]
# - 4) Coefcieinte de clustering competitivo (si trabajan con la red bipartita sin proyectar) (ver referencia 2)
# - 5) Datos externos si encuentan y alcanzan son bienvenidos.
# - 6) Otros.

# %% [markdown]
# ### Importación de Librerías

# %%
import pandas as pd
import numpy as np

import networkx as nx
from networkx.algorithms import bipartite

# %% [markdown]
# # Desarrollo de Proyecto

# %% [markdown]
# ## Objetivos e Hipotesis
#
# - ¿Existe una relación que se repita de forma sostenida entre Organismos Públicos y Privados, con los Proveedores para el periodo a analizar?(2020).
# - Desarrollo de una red bipartita para nuestro análisis.
# - Trabajar en base al componente gigante de la red.
# - Identificar patrones de corrupción en la red.

# %% [markdown]
# ### 1) Análisis Exploratorio:

# %%
df = pd.read_csv('lic2020_hackaton.csv', sep=',', encoding='latin_1')

# %%
df.head(3)
# Out:
#     Codigo                              Tipo de Adquisicion      Estado  \
# 0  8468777  Licitación Pública entre a 2000 y 5000 UTM (LQ)  Adjudicada
# 1  8468777  Licitación Pública entre a 2000 y 5000 UTM (LQ)  Adjudicada
# 2  8468777  Licitación Pública entre a 2000 y 5000 UTM (LQ)  Adjudicada
#
#    CodigoOrganismo                                    NombreOrganismo  \
# 0          1375151  HOSPITAL CLINICO METROPOLITANO LA FLORIDA DRA ...
# 1          1375151  HOSPITAL CLINICO METROPOLITANO LA FLORIDA DRA ...
# 2          1375151  HOSPITAL CLINICO METROPOLITANO LA FLORIDA DRA ...
#
#       RutUnidad ComunaUnidad FechaPublicacion  CodigoProductoONU  \
# 0  65.075.485-9          NaN       2020-01-21           51201806
# 1  65.075.485-9          NaN       2020-01-21           51201806
# 2  65.075.485-9          NaN       2020-01-21           51201806
#
#    RutProveedor                       NombreProveedor Moneda de la Oferta  \
# 0  76.432.529-K                 CSL Behring SpA Chile        Peso Chileno
# 1  96.945.670-2  NOVOFARMA SERVICE - LABORATORIO BAGO        Peso Chileno
# 2  96.582.310-7                    Grifols Chile S.A.        Peso Chileno
#
#   MontoLineaAdjudica Oferta seleccionada
# 0                  0     No Seleccionada
# 1                  0     No Seleccionada
# 2            1592000        Seleccionada

# %%
df.isnull().sum()
# Out:
# Codigo                      0
# Tipo de Adquisicion         0
# Estado                      0
# CodigoOrganismo             0
# NombreOrganismo             0
# RutUnidad                   0
# ComunaUnidad           111298
# FechaPublicacion            0
# CodigoProductoONU           0
# RutProveedor                0
# NombreProveedor          1860
# Moneda de la Oferta         0
# MontoLineaAdjudica          0
# Oferta seleccionada         0
# dtype: int64

# %%
df[df['NombreProveedor'].isnull()].head(3)
# Out:
#        Codigo                      Tipo de Adquisicion      Estado  \
# 4068  8621395  Licitación Pública Menor a 100 UTM (L1)  Adjudicada
# 4190  8621461  Licitación Pública Menor a 100 UTM (L1)  Adjudicada
# 4192  8621461  Licitación Pública Menor a 100 UTM (L1)  Adjudicada
#
#       CodigoOrganismo          NombreOrganismo     RutUnidad ComunaUnidad  \
# 4068            99860  MUNICIPALIDAD DE OVALLE  69.040.700-0       Ovalle
# 4190            99860  MUNICIPALIDAD DE OVALLE  69.040.700-0       Ovalle
# 4192            99860  MUNICIPALIDAD DE OVALLE  69.040.700-0       Ovalle
#
#      FechaPublicacion  CodigoProductoONU  RutProveedor NombreProveedor  \
# 4068       2020-01-13           25172301  76.690.208-1             NaN
# 4190       2020-01-13           25172901  76.690.208-1             NaN
# 4192       2020-01-13           15121501  76.690.208-1             NaN
#
#      Moneda de la Oferta MontoLineaAdjudica Oferta seleccionada
# 4068        Peso Chileno            1200000        Seleccionada
# 4190        Peso Chileno                  0     No Seleccionada
# 4192        Peso Chileno                  0     No Seleccionada

# %%
df = df.dropna()

# %%
df.isnull().sum()
# Out:
# Codigo                 0
# Tipo de Adquisicion    0
# Estado                 0
# CodigoOrganismo        0
# NombreOrganismo        0
# RutUnidad              0
# ComunaUnidad           0
# FechaPublicacion       0
# CodigoProductoONU      0
# RutProveedor           0
# NombreProveedor        0
# Moneda de la Oferta    0
# MontoLineaAdjudica     0
# Oferta seleccionada    0
# dtype: int64

# %%
print('Cantidad de Nombres de Organismo:')
print(len(df['NombreOrganismo'].unique()))
print('\nCantidad de Codigos de Organismo:')
print(len(df['CodigoOrganismo'].unique()))
# Out:
# Cantidad de Nombres de Organismo:
# 859
#
# Cantidad de Codigos de Organismo:
# 871

# %% [markdown]
# - ###### Del análisis de datos, fué posible identificar que existen 2 grupos de nodos mediante los cuales es posible generar una Red Bipartita. El primer Grupo contempla las primeras columnas de datos que se encuentras asociadas a los Organismos estatales que generan las Licitaciones. Por otro lado, el conjunto de columnas de la izquierda corresponden a las Empresas participantes de las licitaciones.
#
# - ###### Dentro del análisis exploratiorio de los datos, fue posible identificar que las cantidades de CodigosOrganismos no coincidía con la de NombreOrganismos, lo cual eventualmente significaría que existen Organismos con más de un código asociado, lo que nos inclina por trabajar con los Nombres.
#
# - ###### Otra observación que pudimos identificar, es que algunas de las empresas que participan como oferentes, se en cuentran también dentro del listado de Organismos, estas corresponden a aquellas empresas estatales como universidades, las cuales poseen áreas de proyectos o investigación para el autofinanciamiento.

# %% [markdown]
# ### 2) Inferencia red:

# %% [markdown]
# #### Lista de Nodos de Organismos

# %%
lista_organismos = df['NombreOrganismo'].unique()
lista_organismos[0:5]
len(lista_organismos)
# Out:
# 859

# %% [markdown]
# #### Lista de Nodos de Empresas

# %%
lista_empresas = df['NombreProveedor'].unique()
lista_empresas[0:5]
len(lista_empresas)
# Out:
# 37765

# %% [markdown]
# #### Eliminar Nodos Presentes en Ambos Grupos de Nodos

# %%
del_empresas = []
for organismo in lista_organismos:
    for empresa in lista_empresas:
        if organismo == empresa:
            del_empresas.append(organismo)
del_empresas
# Out:
# ['UNIVERSIDAD DE MAGALLANES',
#  'UNIVERSIDAD DEL BIO BIO',
#  'UNIVERSIDAD DE ATACAMA',
#  'UNIVERSIDAD DE TALCA',
#  'UNIVERSIDAD DE LA FRONTERA',
#  'INSTITUTO FORESTAL',
#  'INSTITUTO DE FOMENTO PESQUERO']

# %%
for universidad in del_empresas:
    df = df[df['NombreProveedor'] != universidad]

# %%
lista_empresas = df['NombreProveedor'].unique()
len(lista_empresas)
# Out:
# 37758

# %% [markdown]
# #### Definición de Enlaces Empresas/Organismos

# %%
pivot = pd.pivot_table(df, index=['NombreOrganismo','NombreProveedor'],values=['Oferta seleccionada'],aggfunc='count')
pivot = pivot.reset_index()
pivot.head()
# Out:
#                                      NombreOrganismo  \
# 0  AGENCIA CHILENA DE COOPERACION INTERNACIONAL P...
# 1  AGENCIA CHILENA DE COOPERACION INTERNACIONAL P...
# 2  AGENCIA CHILENA DE COOPERACION INTERNACIONAL P...
# 3  AGENCIA CHILENA DE COOPERACION INTERNACIONAL P...
# 4  AGENCIA CHILENA DE COOPERACION INTERNACIONAL P...
#
#                                      NombreProveedor  Oferta seleccionada
# 0                           ARTL CHILE AUDITORES SPA                    1
# 1  AdjudicaChile Consultora en Licitaciones Públicas                    1
# 2                                           Aiguasol                    2
# 3                                    Amelia Virginia                    1
# 4                                        Astral S.A.                    1

# %%
lista_tuplas_pesos = []

for i in pivot.to_numpy():
    lista_tuplas_pesos.append((i[0], i[1], i[2]))
lista_tuplas_pesos[:4]
# Out:
# [('AGENCIA CHILENA DE COOPERACION INTERNACIONAL PARA EL DESARROLLO',
#   'ARTL CHILE AUDITORES SPA',
#   1),
#  ('AGENCIA CHILENA DE COOPERACION INTERNACIONAL PARA EL DESARROLLO',
#   'AdjudicaChile Consultora en Licitaciones Públicas',
#   1),
#  ('AGENCIA CHILENA DE COOPERACION INTERNACIONAL PARA EL DESARROLLO',
#   'Aiguasol',
#   2),
#  ('AGENCIA CHILENA DE COOPERACION INTERNACIONAL PARA EL DESARROLLO',
#   'Amelia Virginia',
#   1)]

# %%
len(lista_tuplas_pesos)
# Out:
# 205391

# %% [markdown]
# #### Construcción del Grafo

# %%
G = nx.Graph()
G.add_nodes_from(lista_empresas, bipartite=0)
G.add_nodes_from(lista_organismos,bipartite=1)
G.add_weighted_edges_from(lista_tuplas_pesos)
bipartite.is_bipartite(G)
# Out:
# True

# %%
nx.density(G)
# Out:
# 0.00027546446779416127

# %% [markdown]
# #### Identificacion de Comunidades

# %%
import matplotlib.pyplot as plt
from matplotlib import cm

# %%
from community import community_louvain

partition = community_louvain.best_partition(G)

size = (len(set(partition.values())))#Numero de comunidades
print('Se detectan %d comunidades' % (size))
# Out:
# Se detectan 14 comunidades

# %%
d = {}
for character, par in partition.items():
    if par in d:
        d[par].append(character)
    else:
        d[par] = [character]

# %%
for i in range(len(d)):
    print(f'Tamaño Comunidad {i}: {len(d[i])}')
# Out:
# Tamaño Comunidad 0: 3146
# Tamaño Comunidad 1: 3510
# Tamaño Comunidad 2: 1622
# Tamaño Comunidad 3: 8662
# Tamaño Comunidad 4: 69
# Tamaño Comunidad 5: 830
# Tamaño Comunidad 6: 6
# Tamaño Comunidad 7: 32
# Tamaño Comunidad 8: 4532
# Tamaño Comunidad 9: 3714
# Tamaño Comunidad 10: 3300
# Tamaño Comunidad 11: 1750
# Tamaño Comunidad 12: 7440
# Tamaño Comunidad 13: 4

# %%
pos = nx.spring_layout(G) # Layout para la red (coordenadas de los nodos y enlaces)

# %%
#Posiciones definidas para los nodos
len(pos)
# Out:
# 38617

# %%
#Verificacion de cantidad de nodos
len(lista_organismos)+len(lista_empresas)
# Out:
# 38617

# %%
#Corroborar que la suma de cada nodo separado en als comunidades coincidan con la cantidad de nodos

sum = int()
for i in range(len(d)):
    sum = sum + len(d[i])
print (sum)
# Out:
# 38617

# %% [markdown]
# #### Ploteo del Grafo

# %%
plt.figure(figsize=(25, 15))

#colors = [np.array(cm.jet(x)).reshape(1,-1) for x in np.linspace(0, 1, size)]#cm.jet es el mapa de colores https://www.programcreek.com/python/example/56498/matplotlib.cm.jet
colors = ['white', 'white', 'white', 'yellow', 'white', 'white', 'white', 'white', 'white', 'white', 'cyan', 'orange', 'blue', 'white', 'green', 'red', ]

count = 0
for com in set(partition.values()): #para cada comunidad
    list_nodes = [nodes for nodes in partition.keys() if partition[nodes] == com]#guarda los personajes que pertenecen a la comunidad `com`
    nx.draw_networkx_nodes(G, pos, list_nodes, node_size = 20, node_color=colors[count], alpha=0.8)#plotea nodos con colors por comunidad
    count = count + 1# para iterar sobre los colores

nx.draw_networkx_edges(G, pos, alpha=0.5, width=0.15)#plotea enlaces
plt.show()

# %%
def comunidad(df, d):

    df2 = pd.DataFrame()
    j = 0
    for i in range (len(df)):
        if df.NombreOrganismo[i] in d:
            if j == 0:
                df2 = df.loc[i:i]
                j = 1
            else:
                df3 = df.loc[i:i]
                frames = [df2,df3]
                df2 = pd.concat(frames)
    df2 = df2.reset_index()
    
    j = 0
    for i in range (len(df2)):
        if df2.NombreProveedor[i] in d:
            if j == 0:
                df1 = df2.loc[i:i]
                j = 1
            else:
                df3 = df2.loc[i:i]
                frames = [df1,df3]
                df1 = pd.concat(frames)
    df1 = df1.reset_index()                        
    df1 = df1[['NombreOrganismo','NombreProveedor','Oferta seleccionada']]
    
    lista_tuplas_pesos = []
    for i in df1.to_numpy():
        lista_tuplas_pesos.append((i[0], i[1], i[2]))
    lista_tuplas_pesos[:4]

    G = nx.Graph()
    G.add_nodes_from(df1['NombreProveedor'].unique(), bipartite=0)
    G.add_nodes_from(df1['NombreOrganismo'].unique(),bipartite=1)
    G.add_weighted_edges_from(lista_tuplas_pesos)
    
    plt.figure(figsize=(10, 6))
    
    pos = nx.spring_layout(G)
    nx.draw_networkx_nodes(G, pos, d, node_size = 20, node_color=['red'], alpha=0.8)
    nx.draw_networkx_edges(G, pos, alpha=0.8, width=0.25)

    plt.show()
            
    return df1, G

# %%
dd,Gd = comunidad(pivot, d[5])
dd
# Out:
#                              NombreOrganismo  \
# 0     Consultorio Gral. Urbano Violeta Parra
# 1     Consultorio Gral. Urbano Violeta Parra
# 2     Consultorio Gral. Urbano Violeta Parra
# 3     Consultorio Gral. Urbano Violeta Parra
# 4     Consultorio Gral. Urbano Violeta Parra
# ...                                      ...
# 1039                UNIVERSIDAD DE LA SERENA
# 1040                UNIVERSIDAD DE LA SERENA
# 1041                UNIVERSIDAD DE LA SERENA
# 1042                UNIVERSIDAD DE LA SERENA
# 1043                UNIVERSIDAD DE LA SERENA
#
#                                         NombreProveedor  Oferta seleccionada
# 0                                             760988200                    1
# 1                                                   ASS                    1
# 2                                      Copelec Capacita                    1
# 3                              Daniela Manríquez Campos                    6
# 4                                      Filemon Eduardo                     4
# ...                                                 ...                  ...
# 1039                      ROMANE YESSENIA GUZMAN CORTEZ                    1
# 1040                                      SEMANTEC LTDA                    1
# 1041  Sociedad Constructora e inmobiliaria Abadecons...                    1
# 1042                                         Teatro ECO                    1
# 1043                                   francisco javier                    1
#
# [1044 rows x 3 columns]

# %%
dd, Gd = comunidad(pivot, d[13])
dd
# Out:
#                          NombreOrganismo              NombreProveedor  \
# 0  DCCP - Prueba Comprador Area Clientes              Dafned Carrasco
# 1  DCCP - Prueba Comprador Area Clientes              MpOperacionesPU
# 2  DCCP - Prueba Comprador Area Clientes  Victor M. Villarroel Bustos
#
#    Oferta seleccionada
# 0                    1
# 1                    3
# 2                    1

# %%
dd, Gd = comunidad(pivot, d[6])
dd
# Out:
#                   NombreOrganismo  NombreProveedor  Oferta seleccionada
# 0  HOSPITAL PADRE ALBERTO HURTADO  AIR CENTRAL SPA                    1
# 1  HOSPITAL PADRE ALBERTO HURTADO     APO Limitada                    1
# 2  HOSPITAL PADRE ALBERTO HURTADO   PAB Ingeniería                   64
# 3  HOSPITAL PADRE ALBERTO HURTADO  Valeska Solange                   50
# 4  HOSPITAL PADRE ALBERTO HURTADO  barbara michele                    1

# %%
dd, Gd = comunidad(pivot, d[7])
dd
# Out:
#                               NombreOrganismo                NombreProveedor  \
# 0   DELEGACIÓN PRESIDENCIAL REGIONAL DE ÑUBLE             ANDREA DEL CARMEN
# 1   DELEGACIÓN PRESIDENCIAL REGIONAL DE ÑUBLE   CARLOS ALFREDO LAGOS VERGARA
# 2   DELEGACIÓN PRESIDENCIAL REGIONAL DE ÑUBLE                Daniela adriana
# 3   DELEGACIÓN PRESIDENCIAL REGIONAL DE ÑUBLE                   EL ROBLE SPA
# 4   DELEGACIÓN PRESIDENCIAL REGIONAL DE ÑUBLE         EVELIN DE LAS MERCEDES
# 5   DELEGACIÓN PRESIDENCIAL REGIONAL DE ÑUBLE             FRANKLIN FRANCISCO
# 6   DELEGACIÓN PRESIDENCIAL REGIONAL DE ÑUBLE                   HAROLD JOEL
# 7   DELEGACIÓN PRESIDENCIAL REGIONAL DE ÑUBLE  HECTOR HERNAN RAMIREZ HERRERA
# 8   DELEGACIÓN PRESIDENCIAL REGIONAL DE ÑUBLE                           Lemn
# 9   DELEGACIÓN PRESIDENCIAL REGIONAL DE ÑUBLE                         Leonel
# 10  DELEGACIÓN PRESIDENCIAL REGIONAL DE ÑUBLE                  PEDRO ALFONSO
# 11  DELEGACIÓN PRESIDENCIAL REGIONAL DE ÑUBLE               Servicios Aljibe
# 12  DELEGACIÓN PRESIDENCIAL REGIONAL DE ÑUBLE      Sociedad EL Almendro Ltda
# 13  DELEGACIÓN PRESIDENCIAL REGIONAL DE ÑUBLE                 TRANS RENT SPA
# 14  DELEGACIÓN PRESIDENCIAL REGIONAL DE ÑUBLE           TRANSPORTES JSB EIRL
# 15  DELEGACIÓN PRESIDENCIAL REGIONAL DE ÑUBLE              TRANSPORTES ÑUBLE
# 16  DELEGACIÓN PRESIDENCIAL REGIONAL DE ÑUBLE                    Trabun Ltda
# 17  DELEGACIÓN PRESIDENCIAL REGIONAL DE ÑUBLE        Transportes Natalia Roa
# 18  DELEGACIÓN PRESIDENCIAL REGIONAL DE ÑUBLE             Transportes Valcar
# 19  DELEGACIÓN PRESIDENCIAL REGIONAL DE ÑUBLE        Ttnsporte San Sebastian
# 20  DELEGACIÓN PRESIDENCIAL REGIONAL DE ÑUBLE                  YANETH LORENA
# 21  DELEGACIÓN PRESIDENCIAL REGIONAL DE ÑUBLE                   YUNI MARLEN
# 22  DELEGACIÓN PRESIDENCIAL REGIONAL DE ÑUBLE                     ZURBOTRANS
# 23            GOBERNACION PROVINCIAL DE TALCA                Daniel Fernando
# 24            GOBERNACION PROVINCIAL DE TALCA                   LUIS GERARDO
# 25            GOBERNACION PROVINCIAL DE TALCA                       Rotronco
# 26            GOBERNACION PROVINCIAL DE TALCA               SERGIO ROBINSON
# 27            GOBERNACION PROVINCIAL DE TALCA                 TRANS RENT SPA
# 28            GOBERNACION PROVINCIAL DE TALCA            Transporte El Nogal
# 29            GOBERNACION PROVINCIAL DE TALCA            Veronica Valentina
# 30            GOBERNACION PROVINCIAL DE TALCA                      israelroa
#
#     Oferta seleccionada
# 0                     1
# 1                     1
# 2                     2
# 3                     2
# 4                     1
# 5                     2
# 6                     1
# 7                     1
# 8                    10
# 9                     3
# 10                    8
# 11                    5
# 12                    4
# 13                    7
# 14                    1
# 15                    2
# 16                    2
# 17                    1
# 18                    1
# 19                    8
# 20                    1
# 21                    2
# 22                    8
# 23                    1
# 24                    8
# 25                    2
# 26                    5
# 27                   25
# 28                    2
# 29                    4
# 30                   18

# %%
dd, Gd = comunidad(pivot, d[4])
dd
# Out:
#                NombreOrganismo                        NombreProveedor  \
# 0   I MUNICIPALIDAD DE LONGAVI                               62718943
# 1   I MUNICIPALIDAD DE LONGAVI            ALEX ANTONIO YANEZ MARTINEZ
# 2   I MUNICIPALIDAD DE LONGAVI                          ANGEL SEGUNDO
# 3   I MUNICIPALIDAD DE LONGAVI        AURORA DEL CARMEN CAMPOS VALDES
# 4   I MUNICIPALIDAD DE LONGAVI  Agrícola y Comercial Pino Hachado SPA
# ..                         ...                                    ...
# 63  I MUNICIPALIDAD DE LONGAVI                             maquinaria
# 64  I MUNICIPALIDAD DE LONGAVI                                 silvia
# 65  I MUNICIPALIDAD DE LONGAVI                               sociedad
# 66  I MUNICIPALIDAD DE LONGAVI                             transporte
# 67  I MUNICIPALIDAD DE LONGAVI                     transportes parada
#
#     Oferta seleccionada
# 0                     4
# 1                     1
# 2                     2
# 3                     1
# 4                     1
# ..                  ...
# 63                    6
# 64                    2
# 65                    1
# 66                   10
# 67                    8
#
# [68 rows x 3 columns]

# %%
dd, Gd = comunidad(pivot, d[6])
dd
# Out:
#                   NombreOrganismo  NombreProveedor  Oferta seleccionada
# 0  HOSPITAL PADRE ALBERTO HURTADO  AIR CENTRAL SPA                    1
# 1  HOSPITAL PADRE ALBERTO HURTADO     APO Limitada                    1
# 2  HOSPITAL PADRE ALBERTO HURTADO   PAB Ingeniería                   64
# 3  HOSPITAL PADRE ALBERTO HURTADO  Valeska Solange                   50
# 4  HOSPITAL PADRE ALBERTO HURTADO  barbara michele                    1

# %%
lista_nodos_jaccar = dd['NombreProveedor'].unique()
lista_nodos_jaccar
# Out:
# array(['AIR CENTRAL SPA', 'APO Limitada', 'PAB Ingeniería',
#        'Valeska Solange', 'barbara michele'], dtype=object)

# %%
df4 = df[:]
df4 = df4.reset_index()

df2 = pd.DataFrame()

j = 0
for i in range (len(df4)):
    if df4.NombreProveedor[i] in lista_nodos_jaccar:
        print(i)
# Out:
# 1320869
# 1357121
# 1433164
# 1435626
# 1435628
# 1435629
# 1435631
# 1435632
# 1435634
# 1435635
# 1435637
# 1435638
# 1435640
# 1435641
# 1435643
# 1435644
# 1435646
# 1435647
# 1435650
# 1435651
# 1435653
# 1435654
# 1435656
# 1435657
# 1435659
# 1435660
# 1435662
# 1435663
# 1435665
# 1435666
# 1435668
# 1435669
# 1435671
# 1435672
# 1435674
# 1435675
# 1435678
# 1435679
# 1435680
# 1435681
# 1435684
# 1435685
# 1435686
# 1435689
# 1435690
# 1435691
# 1435692
# 1435695
# 1435696
# 1435699
# 1435700
# 1435701
# 1435702
# 1435705
# 1435706
# 1435707
# 1435708
# 1435711
# 1435712
# 1435713
# 1435714
# 1435717
# 1435718
# 1435719
# 1435720
# 1435723
# 1435724
# 1435726
# 1435728
# 1435729
# 1435730
# 1435732
# 1435733
# 1435735
# 1435736
# 1435738
# 1435739
# 1435740
# 1435743
# 1435744
# 1435745
# 1435746
# 1435749
# 1435750
# 1435751
# 1435752
# 1435755
# 1435756
# 1435757
# 1435758
# 1435761
# 1435762
# 1435763
# 1435765
# 1435766
# 1435768
# 1435769
# 1435771
# 1435772
# 1435774
# 1435775
# 1435777
# 1435778
# 1435780
# 1435781
# 1435784
# 1435786
# 1435787
# 1435789
# 1435791
# 1435792
# 1435795
# 1435796
# 1435798
# 1435800
# 1435801
# 1435803
# 1478467
# 1606734
# 1606735

# %%
df4 = df[:]
df4 = df4.reset_index()

df2 = pd.DataFrame()
j = 0
for i in range (len(df)):
    if df4.NombreProveedor[i] in lista_nodos_jaccar:
        if j == 0:
            df2 = df.loc[i:i]
            j = 1
        else:
            df3 = df.loc[i:i]
            frames = [df2,df3]
.            df2 = pd.concat(frames)
df2 = df2.reset_index()
df2.head(3)
# Out:
#      index   Codigo                              Tipo de Adquisicion  \
# 0  1320869  8684080  Licitación Pública entre a 2000 y 5000 UTM (LQ)
# 1  1357121  8693343     Licitación Pública Entre 100 y 1000 UTM (LE)
# 2  1433164  8699021          Licitación Pública Menor a 100 UTM (L1)
#
#        Estado  CodigoOrganismo                                NombreOrganismo  \
# 0  Adjudicada             7260  SERVICIO DE SALUD DEL MAULE HOSPITAL DE TALCA
# 1  Adjudicada           119266                    I MUNICIPALIDAD DE COLTAUCO
# 2  Adjudicada           100648              ILUSTRE MUNICIPALIDAD DE LA LIGUA
#
#       RutUnidad ComunaUnidad FechaPublicacion  CodigoProductoONU  \
# 0  61.606.901-2        Talca       2020-06-02           85111602
# 1  69.080.700-9     Coltauco       2020-06-09           51142103
# 2  69.050.100-7     La Ligua       2020-06-23           42171903
#
#    RutProveedor                     NombreProveedor Moneda de la Oferta  \
# 0  91.537.000-4                            Bayer SA        Peso Chileno
# 1  76.167.536-2                        Medikar Ltda        Peso Chileno
# 2  80.621.200-8  Merck S.A. Productos Farmacéuticos        Peso Chileno
#
#   MontoLineaAdjudica Oferta seleccionada
# 0           23450,89        Seleccionada
# 1                  0     No Seleccionada
# 2              35150        Seleccionada

# %%
for i in range(len(df2)):
    #print(df2.NombreProveedor[i])
    if df2.NombreProveedor[i] in lista_nodos_jaccar:
        print(i)

# %%
def jaccard(grupo1, grupo2):
    interseccion = len(set(grupo1).intersection(set(grupo2)))
    union = len (set(grupo1).union(set(grupo2)))
    return interseccion / union
 
grupo_amigos1 = ["Manuel", "Rodrigo", "Miguel", "Jesus", "Irving"]
grupo_amigos2 = ["Manuel", "Alejandro", "Fernando", "Antonio", "Jesus", "Pablo"]
 
jacard_amigos = jaccard(grupo_amigos1, grupo_amigos2)
print ("Porcentaje de similitud: {:.2f}".format(jacard_amigos))
