# %% [markdown]
# # **Proyecto Final:**
# # **Detección de fraudes potenciales en las licitaciones públicas de Chile en el 2020 usando redes bipartitas y el coeficiente de Jaccard**
#
# ## Ciencias de Redes
# ### Profesor: Cristian Candia Vallejos
# ### Grupo 5:
# - Carlos Bustamante
# - Pablo Elgueta
# - Patricio Ramirez
# - Victor Ortiz
#
# ---

# %% [markdown]
# ## Introducción
#
# Una licitación es un proceso administrativo efectuado por un organismo comprador, el cual invita a diferentes proveedores interesados en proporcionar un bien o servicio a realizar una oferta, adeptándose así la más conveniente según los criterios de evaluación descritos en las bases (Mercado público, s.f.). Este proceso es muy vulnerable a la corrupción, debido a que esta puede darse en diferentes etapas y es difícil detectarla. Los principales indicadores de que una licitación podría ser fraudulenta son:
#
# - Reducido número de licitadores
# - Ofertas incoherentes de un mismo licitador.
# - Similitudes sospechosas entre las ofertas.
# - Ofertas no competitivas.
# - Patrones de comportamiento similar entre las empresas licitadoras.
# - Subcontratación no justificada entre empresas licitadoreas.
# - Ofertas presentadas por las mismas personas físicas.
# - Ofertas económicas de indéntica redacción, formato o errores.
# - Uniones temporales de empresas licitadoras sin justificación aparente.
# (Comisión Nacional de los Mercados y la Competencia, 2019)
#
# Para el desarrollo de este trabajo se utilizaron los datos abiertos del portal Chile Compra (https://datos-abiertos.chilecompra.cl/), específicamente los registros del año 2020. Se busca identificar patrones de posibles fraudes utilizando herramientas de análisis de redes. Para conseguir esto, el trabajo se desarrolló en las siguientes etapas:
#
# * Contexto del proyecto.
# * Objetivos general, específicos e hipótesis formulada.
# * Análisis exploratorio.
# * Inferencia de la red.
# * Descripción de la red.
# * Identificación de patrones de corrupción.
# * Conclusiones, trabajos futuros y limitaciones.
#
# ---

# %% [markdown]
# ## Contexto del proyecto
#
# Se seleccionaron las licitaciones del año 2020 debido a la sensibilidad que estas tenían respecto a la pandemia, el equipo encargado de desarrollar este proyecto supone que al haber sido una contingencia tan grande, quizás las barreras de control fueron más bajas. En el pasado distintas empresas se han visto envueltas en licitaciones polémicas, por ejemplo LG Electronics y el caso de luminarias públicas en el sur de Chile (CIPER, 2015), los casos PagoGate y MilicoGate (El Mostrador, 2019) y un sinfín de otros organismos tanto públicos como privados.
#
# La base de datos contiene las siguientes columnas:
#
# * Codigo: número único de licitación.
# * Tipo de Adquisicion: rango del monto de la licitación.
# * Estado: si la licitación se declaró adjudicada, desierta, revocada, cerrada o suspendida.
# * CodigoOrganismo: número único del organismo público que abre una licitación.
# * NombreOrganismo: nombre del organismo público que abre la licitación.
# * RutUnidad: rol único tributario de la unidad que participa en la licitación.
# * ComunaUnidad: nombre de la comuna en la que la licitación es requerida.
# * FechaPublicacion: fecha en la que la licitación se publicó.
# * CodigoProductoONU: sistema de codificación común de las naciones unidas.
# * RutProveedor: rol único tributario de la empresa que postula a la licitación.
# * NombreProveedor: nombre de la empresa que se postula a la licitación.
# * Moneda de la Oferta: divisa en la que se expresa el monto a pagar de la licitación.
# * MontoLineaAdjudica: monto que se adjudica la empresa en la licitación, puede ser total o parcial.
# * Oferta seleccionada: indicador booleando que expresa si la oferta efectuada por la empresa fue seleccionada o no.

# %% [markdown]
# ## Objetivos general, específicos e hipótesis formulada
#
# **Objetivo General**
#
# Encontrar patrones de fraude y corrupción en las licitaciones públicas de Chile registradas en el año 2020.
#
# **Objetivos Específicos**
#
# - Desarrollo de una red bipartita que integre organismos y empresas.
# - Identificar la componente gigante de la red.
# - Identificar patrones de corrupción usando herramientas de análisis de redes complejas.
#
# **Hipótesis Formulada**
#
# ¿Existe una relación que se repita de forma sostenida entre Organismos Públicos con los Proveedores para el periodo a analizar (2020)?.
#
# - La hipótesis del grupo es que la cantidad de interacciones entre un organismo y un proveedor respecto del global es un indicador de fraude.
#
# - El hecho de que pocos proveedores se postulen a un concurso público, podría sugerir que el organismo no está publicando de manera justa sus licitaciones.

# %% [markdown]
# ## Análisis exploratorio

# %%
# Librerías

#Matemática y datos
import pandas as pd
import numpy as np

#Visualización
import seaborn as sns
import matplotlib.pyplot as plt
from matplotlib import cm
# %matplotlib inline

#Redes
import networkx as nx
from networkx.algorithms import bipartite
import community
from community import community_louvain

# %%
# Leer datos

df = pd.read_csv('lic2020_hackaton.csv', sep=',', encoding='latin_1')
df['FechaPublicacion']=pd.to_datetime(df['FechaPublicacion'])
df.head(3)
# Out:
#     Codigo                              Tipo de Adquisicion      Estado  \
# 0  8468777  Licitación Pública entre a 2000 y 5000 UTM (LQ)  Adjudicada
# 1  8468777  Licitación Pública entre a 2000 y 5000 UTM (LQ)  Adjudicada
# 2  8468777  Licitación Pública entre a 2000 y 5000 UTM (LQ)  Adjudicada
#
#    CodigoOrganismo                                    NombreOrganismo  \
# 0          1375151  HOSPITAL CLINICO METROPOLITANO LA FLORIDA DRA ...
# 1          1375151  HOSPITAL CLINICO METROPOLITANO LA FLORIDA DRA ...
# 2          1375151  HOSPITAL CLINICO METROPOLITANO LA FLORIDA DRA ...
#
#       RutUnidad ComunaUnidad FechaPublicacion  CodigoProductoONU  \
# 0  65.075.485-9          NaN       2020-01-21           51201806
# 1  65.075.485-9          NaN       2020-01-21           51201806
# 2  65.075.485-9          NaN       2020-01-21           51201806
#
#    RutProveedor                       NombreProveedor Moneda de la Oferta  \
# 0  76.432.529-K                 CSL Behring SpA Chile        Peso Chileno
# 1  96.945.670-2  NOVOFARMA SERVICE - LABORATORIO BAGO        Peso Chileno
# 2  96.582.310-7                    Grifols Chile S.A.        Peso Chileno
#
#   MontoLineaAdjudica Oferta seleccionada
# 0                  0     No Seleccionada
# 1                  0     No Seleccionada
# 2            1592000        Seleccionada

# %% [markdown]
# En primer lugar se debe analizar el contenido y eliminar aquellas filas que contuvieran datos nulos. Esto debido a que al momento de querer enlazar nodos o identificar patrones comunes estos datos quedan vinculados.

# %%
df.isnull().sum()
# Out:
# Codigo                      0
# Tipo de Adquisicion         0
# Estado                      0
# CodigoOrganismo             0
# NombreOrganismo             0
# RutUnidad                   0
# ComunaUnidad           111298
# FechaPublicacion            0
# CodigoProductoONU           0
# RutProveedor                0
# NombreProveedor          1860
# Moneda de la Oferta         0
# MontoLineaAdjudica          0
# Oferta seleccionada         0
# dtype: int64

# %%
df[df['NombreProveedor'].isnull()].head(3)
# Out:
#        Codigo                      Tipo de Adquisicion      Estado  \
# 4068  8621395  Licitación Pública Menor a 100 UTM (L1)  Adjudicada
# 4190  8621461  Licitación Pública Menor a 100 UTM (L1)  Adjudicada
# 4192  8621461  Licitación Pública Menor a 100 UTM (L1)  Adjudicada
#
#       CodigoOrganismo          NombreOrganismo     RutUnidad ComunaUnidad  \
# 4068            99860  MUNICIPALIDAD DE OVALLE  69.040.700-0       Ovalle
# 4190            99860  MUNICIPALIDAD DE OVALLE  69.040.700-0       Ovalle
# 4192            99860  MUNICIPALIDAD DE OVALLE  69.040.700-0       Ovalle
#
#      FechaPublicacion  CodigoProductoONU  RutProveedor NombreProveedor  \
# 4068       2020-01-13           25172301  76.690.208-1             NaN
# 4190       2020-01-13           25172901  76.690.208-1             NaN
# 4192       2020-01-13           15121501  76.690.208-1             NaN
#
#      Moneda de la Oferta MontoLineaAdjudica Oferta seleccionada
# 4068        Peso Chileno            1200000        Seleccionada
# 4190        Peso Chileno                  0     No Seleccionada
# 4192        Peso Chileno                  0     No Seleccionada

# %%
df = df.dropna()
df.isnull().sum()
# Out:
# Codigo                 0
# Tipo de Adquisicion    0
# Estado                 0
# CodigoOrganismo        0
# NombreOrganismo        0
# RutUnidad              0
# ComunaUnidad           0
# FechaPublicacion       0
# CodigoProductoONU      0
# RutProveedor           0
# NombreProveedor        0
# Moneda de la Oferta    0
# MontoLineaAdjudica     0
# Oferta seleccionada    0
# dtype: int64

# %% [markdown]
# - De acuerdo a la información contenida en el dataframe, es posible identificar que claramente existen 2 grupos de nodos.
#
# -Los primeros con sus datos agrupados en las columnas de la izquierda, corresponden a los organismos públicos que generan las licitaciones.
#
#
# - En las columnas de la derecha figura lo referente a las empresas proveedoras que participan de las licitaciones asociadas a los organismos públicos, estableciéndose de este modo los enlaces para esta red bipartita.
#
#
# - Identificados los grupos de nodos de la red bipartita, se procede a definir las columnas a utilizar de las que se extraerán estos, si utilizar códigos o nombres. Dado que en los Organismos las cantidades de Nombres son inferiores a las de Códigos, se opta por utilizar los Nombres, ya que eventualmente podría existir más de un Código asociado a los organismos, lo cual generaría una distorsión en el análisis al momento de establecer relaciones.

# %%
print('Cantidad de Nombres de Organismo:')
print(len(df['NombreOrganismo'].unique()))
print('\nCantidad de Codigos de Organismo:')
print(len(df['CodigoOrganismo'].unique()))
# Out:
# Cantidad de Nombres de Organismo:
# 859
#
# Cantidad de Codigos de Organismo:
# 871

# %%
# Cantidad de Licitaciones abiertas por mes

df11 = df[df.Codigo.duplicated(keep=False)]
df11 = df11['FechaPublicacion'].dt.date.value_counts().sort_index().reset_index()
df11.columns=['Fecha Publicacion','Codigo']
df11['Fecha Publicacion']=pd.to_datetime(df11['Fecha Publicacion'])
df11['month'] = df11['Fecha Publicacion'].dt.month
df12 = df11.groupby(df11['Fecha Publicacion'].dt.month)['Codigo'].sum()
df12 = df12.to_frame().reset_index()
df12.columns = ['Mes', 'Cantidad Licitaciones']
ax = df12.plot.bar(x='Mes', y='Cantidad Licitaciones', rot=0)

# %% [markdown]
# Observando la distribución de  la cantidad de licitaciones durante el año, se puede observar una tendencia negativa, la cual no presentó mayores variaciones entre un mes y otro, a excepción de los primeros 3 meses del año. Esta variación no es significativa como para centrar incialmente un análisis en este punto.

# %%
# Cantidad total de veces que algún proveedor aplicó a alguna licitación

df13 = df['NombreProveedor'].value_counts().to_frame().reset_index()
df13['NombreProveedor'].sum()
# Out:
# 1769860

# %%
# Top proveedores que más aplicaron a licitaciones

df13['Porcentaje del total'] = df13['NombreProveedor']/1769860
df13.rename(columns = {'index':'Proveedor','NombreProveedor':'Conteo'}, inplace = True)
df13[:15]
# Out:
#                           Proveedor  Conteo  Porcentaje del total
# 0        ETHON PHARMACEUTICALS SPA.   56023              0.031654
# 1          Socofar Division Munnich   46353              0.026190
# 2              Caribean Pharma Ltda   43473              0.024563
# 3          Distribuidora Salcobrand   36489              0.020617
# 4                          WINPHARM   34765              0.019643
# 5                      Medikar Ltda   30318              0.017130
# 6       DROGUERIA GLOBAL PHARMA SPA   29200              0.016498
# 7                           LABOFAR   22592              0.012765
# 8   COMERCIALIZADORA ILHABELLA EIRL   22505              0.012716
# 9            LABORATORIO CHILE S.A.   20346              0.011496
# 10                   Diprolab Ltda.   20028              0.011316
# 11                 ADN FARMACÉUTICA   19996              0.011298
# 12     INVERSIONES PHARMAVISAN S.A.   17450              0.009860
# 13       LABORATORIOS RECALCINE S.A   13983              0.007901
# 14                 intermedica ltda   13804              0.007799

# %% [markdown]
# Tal como se aprecia en la tabla, ninguno de los proveedores concentra un alto porcentaje de participación en licitaciones como para iniciar un análisis respecto a estos valores.

# %%
# Cantidad total de veces que algún organismo abrió una licitación

df14 = df['NombreOrganismo'].value_counts().to_frame().reset_index()
df14['NombreOrganismo'].sum()
# Out:
# 1769860

# %%
# Top Organismos que más licitaciones abrieron

df14['Porcentaje del total'] = df14['NombreOrganismo']/1769860
df14.rename(columns = {'index':'Organismo','NombreOrganismo':'Conteo'}, inplace = True)
df14[:15]
# Out:
#                                             Organismo  Conteo  \
# 0             FUERZA AEREA DE CHILE COMANDO LOGISTICO   43210
# 1   MINISTERIO DE OBRAS PUBLICAS DIREC CION GRAL D...   35290
# 2                        COMANDO DE APOYO A LA FUERZA   34835
# 3            DIRECCION DE ABASTECIMIENTO DE LA ARMADA   26760
# 4                             I MUNICIPALIDAD DE LOTA   24925
# 5            SERVICIO DE SALUD VALDIVIA HOSPITAL BASE   23619
# 6                 INSTITUTO DE SALUD PUBLICA DE CHILE   22295
# 7            DIRECCION GENERAL DE GENDARMERIA DE CHIL   20607
# 8                       I MUNICIPALIDAD DE LA PINTANA   19980
# 9                            I MUNICIPALIDAD VALDIVIA   17312
# 10             DIRECCION GENERAL DE AERONAUTICA CIVIL   16856
# 11              DIRECCION DE LOGISTICA DE CARABINEROS   16273
# 12     SERVICIO DE SALUD DEL MAULE HOSPITAL DE PARRAL   16195
# 13                                         METRO S.A.   14668
# 14                         I MUNICIPALIDAD DE LINARES   14132
#
#     Porcentaje del total
# 0               0.024414
# 1               0.019939
# 2               0.019682
# 3               0.015120
# 4               0.014083
# 5               0.013345
# 6               0.012597
# 7               0.011643
# 8               0.011289
# 9               0.009782
# 10              0.009524
# 11              0.009195
# 12              0.009150
# 13              0.008288
# 14              0.007985

# %% [markdown]
# En general es posible apreciar que no existe una entidad que concentre un porcentaje de licitaciones significativamente mayor a las demás como para ser objeto de análisis.

# %%
# Conteo de ofertas seleccionadas

df15 = df['Oferta seleccionada'].value_counts().to_frame().reset_index()
df15.rename(columns = {'Oferta seleccionada':'Conteo','index':'Selección ofta'},inplace = True)
df15
# Out:
#     Selección ofta   Conteo
# 0  No Seleccionada  1409938
# 1     Seleccionada   359922

# %%
# Top proveedores que más fueron seleccionados

df15 = df[df['Oferta seleccionada'] == 'Seleccionada']
df15 = df15['NombreProveedor'].value_counts().to_frame().reset_index()
df15['Porcentaje del total'] = df15['NombreProveedor']/359922
df15.rename(columns = {'index':'Proveedor','NombreProveedor':'Conteo'}, inplace = True)
df15[:15]
# Out:
#                       Proveedor  Conteo  Porcentaje del total
# 0    ETHON PHARMACEUTICALS SPA.    8624              0.023961
# 1          Caribean Pharma Ltda    7468              0.020749
# 2      Socofar Division Munnich    6066              0.016854
# 3        LABORATORIO CHILE S.A.    5974              0.016598
# 4    LABORATORIOS RECALCINE S.A    4870              0.013531
# 5   DROGUERIA GLOBAL PHARMA SPA    4756              0.013214
# 6                   VALTEK S.A.    3833              0.010650
# 7   LABORATORIOS ANDROMACO S.A.    3245              0.009016
# 8      Distribuidora Salcobrand    3156              0.008769
# 9                MAYORDENT LTDA    3082              0.008563
# 10              OPKO CHILE S.A.    2660              0.007390
# 11   LABORATORIO SANDERSON S.A.    2542              0.007063
# 12            FARMALATINA LTDA.    2420              0.006724
# 13               MOSIL LIMITADA    2257              0.006271
# 14     Laboratorio Biosano S.A.    2230              0.006196

# %% [markdown]
# Dentro de los proveedores con mayor cantidad de adjudicaciones se aprecia que predominan aquellos vinculados a la industria farmacéutica, sin embargo, individualmente ninguno arroja un porcentaje lo suficientemente grande apra ser objeto de análisis.

# %%
# Conteo del estado de la oferta

df16 = df['Estado'].value_counts().to_frame().reset_index()
df16.rename(columns = {'Estado':'Conteo','index':'Estado'},inplace = True)
df16
# Out:
#                                Estado   Conteo
# 0                          Adjudicada  1633154
# 1  Desierta (o art. 3 ó 9 Ley 19.886)    75018
# 2                            Revocada    32108
# 3                             Cerrada    29503
# 4                          Suspendida       77

# %%
# Top proveedores que más licitaciones se adjudicaron

df16 = df[df['Estado'] == 'Adjudicada']
df16 = df16['NombreProveedor'].value_counts().to_frame().reset_index()
df16['Porcentaje del total'] = df16['NombreProveedor']/1633154
df16.rename(columns = {'index':'Proveedor','NombreProveedor':'Conteo'}, inplace = True)
df16[:15]
# Out:
#                           Proveedor  Conteo  Porcentaje del total
# 0        ETHON PHARMACEUTICALS SPA.   53671              0.032863
# 1          Socofar Division Munnich   43958              0.026916
# 2              Caribean Pharma Ltda   41971              0.025699
# 3          Distribuidora Salcobrand   35137              0.021515
# 4                          WINPHARM   33047              0.020235
# 5                      Medikar Ltda   29319              0.017952
# 6       DROGUERIA GLOBAL PHARMA SPA   28048              0.017174
# 7                           LABOFAR   21815              0.013358
# 8   COMERCIALIZADORA ILHABELLA EIRL   20891              0.012792
# 9            LABORATORIO CHILE S.A.   19765              0.012102
# 10                 ADN FARMACÉUTICA   19237              0.011779
# 11                   Diprolab Ltda.   18692              0.011445
# 12     INVERSIONES PHARMAVISAN S.A.   16811              0.010294
# 13       LABORATORIOS RECALCINE S.A   13407              0.008209
# 14           Awad Artículos Médicos   12799              0.007837

# %%
df_te= df13.merge(df15, how='inner', on='Proveedor')
df_te = df_te[df_te['Conteo_y'] > 1000]
df_te['Tasa éxito'] = df_te['Conteo_y'] / df_te['Conteo_x']
df_te = df_te.reset_index().sort_values(by='Tasa éxito', ascending=False)
df_te.rename(columns = {'Conteo_x':'Conteo Postulaciones','Porcentaje del total_x':'% del total Postulaciones',
                       'Conteo_y':'Conteo Seleccionadas','Porcentaje del total_y':'% del total Seleccionadas'}, inplace = True)
df_te
# Out:
#     index                                      Proveedor  \
# 40     87            Roche Chile Ltda. Roche Diagnostics
# 43    142  STRYKER CORPORATION CHILE Y COMPANIA LIMITADA
# 42    138                                          BADEX
# 23     33                                    VALTEK S.A.
# 31     49                     LABORATORIO SANDERSON S.A.
# 33     56                                 MOSIL LIMITADA
# 37     71                         Laboratorio Pasteur SA
# 39     80                     Fresenius Kabi Chile Ltda.
# 34     58                      Johnson & Johnson Medical
# 38     77                  Merck S.A. Productos Químicos
# 41     90                                  TECNIGEN S.A.
# 19     27                    LABORATORIOS ANDROMACO S.A.
# 27     38                       Laboratorio Biosano S.A.
# 36     66                                Medtronic Chile
# 29     42                        Ascend Laboratories SpA
# 10     13                     LABORATORIOS RECALCINE S.A
# 35     61                           PVequip: Diagnóstica
# 20     28                         MULTICOMERCIAL CHILLAN
# 7       9                         LABORATORIO CHILE S.A.
# 18     24                                OPKO CHILE S.A.
# 22     31                            B.BRAUN MEDICAL SpA
# 32     52                                  Cencomex S.A.
# 30     47                                   Tecnika S.A.
# 26     37   NIPRO MEDICAL CORPORATION (AGENCIA EN CHILE)
# 11     15                                 MAYORDENT LTDA
# 28     40                          INMED DROGUERIA LTDA.
# 15     19                              FARMALATINA LTDA.
# 21     30              DIST. ARTICULOS MEDICOS PÉREZ SPA
# 24     34                                        BPH S.A
# 25     35                                         Camilo
# 16     20                                          Trema
# 2       2                           Caribean Pharma Ltda
# 6       6                    DROGUERIA GLOBAL PHARMA SPA
# 0       0                     ETHON PHARMACEUTICALS SPA.
# 13     17                         Awad Artículos Médicos
# 1       1                       Socofar Division Munnich
# 17     22                             DENTAL LAVAL LTDA.
# 12     16                         MURUA Y ASOCIADOS LTDA
# 14     18                                  Carpedent SpA
# 8      11                               ADN FARMACÉUTICA
# 3       3                       Distribuidora Salcobrand
# 9      12                   INVERSIONES PHARMAVISAN S.A.
# 5       5                                   Medikar Ltda
# 4       4                                       WINPHARM
#
#     Conteo Postulaciones  % del total Postulaciones  Conteo Seleccionadas  \
# 40                  2661                   0.001504                  2206
# 43                  1662                   0.000939                  1055
# 42                  1705                   0.000963                  1015
# 23                  6481                   0.003662                  3833
# 31                  4517                   0.002552                  2542
# 33                  4034                   0.002279                  2257
# 37                  3175                   0.001794                  1668
# 39                  2891                   0.001633                  1412
# 34                  3815                   0.002156                  1810
# 38                  3028                   0.001711                  1413
# 41                  2625                   0.001483                  1184
# 19                  7796                   0.004405                  3245
# 27                  5680                   0.003209                  2230
# 36                  3355                   0.001896                  1215
# 29                  5115                   0.002890                  1810
# 10                 13983                   0.007901                  4870
# 35                  3514                   0.001985                  1051
# 20                  7482                   0.004227                  2228
# 7                  20346                   0.011496                  5974
# 18                  9067                   0.005123                  2660
# 22                  6750                   0.003814                  1978
# 32                  4344                   0.002454                  1077
# 30                  4652                   0.002628                  1113
# 26                  5859                   0.003310                  1333
# 11                 13712                   0.007748                  3082
# 28                  5271                   0.002978                  1091
# 15                 12067                   0.006818                  2420
# 21                  7243                   0.004092                  1413
# 24                  6347                   0.003586                  1210
# 25                  6336                   0.003580                  1162
# 16                 12013                   0.006788                  2130
# 2                  43473                   0.024563                  7468
# 6                  29200                   0.016498                  4756
# 0                  56023                   0.031654                  8624
# 13                 13428                   0.007587                  2045
# 1                  46353                   0.026190                  6066
# 17                  9893                   0.005590                  1166
# 12                 13696                   0.007738                  1421
# 14                 12213                   0.006901                  1252
# 8                  19996                   0.011298                  1829
# 3                  36489                   0.020617                  3156
# 9                  17450                   0.009860                  1420
# 5                  30318                   0.017130                  2091
# 4                  34765                   0.019643                  2061
#
#     % del total Seleccionadas  Tasa éxito
# 40                   0.006129    0.829012
# 43                   0.002931    0.634777
# 42                   0.002820    0.595308
# 23                   0.010650    0.591421
# 31                   0.007063    0.562763
# 33                   0.006271    0.559494
# 37                   0.004634    0.525354
# 39                   0.003923    0.488412
# 34                   0.005029    0.474443
# 38                   0.003926    0.466645
# 41                   0.003290    0.451048
# 19                   0.009016    0.416239
# 27                   0.006196    0.392606
# 36                   0.003376    0.362146
# 29                   0.005029    0.353861
# 10                   0.013531    0.348280
# 35                   0.002920    0.299089
# 20                   0.006190    0.297781
# 7                    0.016598    0.293620
# 18                   0.007390    0.293372
# 22                   0.005496    0.293037
# 32                   0.002992    0.247928
# 30                   0.003092    0.239252
# 26                   0.003704    0.227513
# 11                   0.008563    0.224767
# 28                   0.003031    0.206982
# 15                   0.006724    0.200547
# 21                   0.003926    0.195085
# 24                   0.003362    0.190641
# 25                   0.003228    0.183396
# 16                   0.005918    0.177308
# 2                    0.020749    0.171785
# 6                    0.013214    0.162877
# 0                    0.023961    0.153937
# 13                   0.005682    0.152294
# 1                    0.016854    0.130865
# 17                   0.003240    0.117861
# 12                   0.003948    0.103753
# 14                   0.003479    0.102514
# 8                    0.005082    0.091468
# 3                    0.008769    0.086492
# 9                    0.003945    0.081375
# 5                    0.005810    0.068969
# 4                    0.005726    0.059284

# %% [markdown]
# - Del análisis de datos, fue posible identificar que existen 2 grupos de nodos mediante los cuales es factible generar una Red Bipartita. El primer Grupo contempla las primeras columnas de datos que se encuentras asociadas a los Organismos estatales que generan las Licitaciones. Por otro lado, el conjunto de columnas de la izquierda corresponden a las Empresas participantes de las licitaciones.
#
# - Dentro del análisis exploratiorio de los datos, fue posible identificar que las cantidades de CodigosOrganismos no coincidía con la de NombreOrganismos, lo cual eventualmente significaría que existen Organismos con más de un código asociado, lo que nos inclina por trabajar con los Nombres.
#
# - Otra observación que pudimos identificar, es que algunas de las empresas que participan como oferentes, se
# encuentran también dentro del listado de Organismos, estas corresponden a aquellas empresas estatales como universidades, las cuales poseen áreas de proyectos o investigación para el autofinanciamiento.
#
# - Resulta interesante ver las altas tasas de éxito que tienen algunas empresas respecto de las otras al quedar seleccionados en las licitaciones. El top 7 posee una tasa mayor al 50%, pero con las empresas que vienen después esa tendencia desaparece absolutamente.

# %% [markdown]
# ## Inferencia de la red
# ### Creación de la red:

# %%
# Creación de una lista de nodos con los organismos públicos

lista_organismos = df['NombreOrganismo'].unique()
lista_organismos[0:5]
len(lista_organismos)
# Out:
# 859

# %%
# Lista de nodos de empresas

lista_empresas = df['NombreProveedor'].unique()
lista_empresas[0:5]
len(lista_empresas)
# Out:
# 37765

# %% [markdown]
# Dado que existen empresas que figuran tanto como organismo público y como proveedor, afectando la creación de la red bipartita, se identifican estas instituciones y posteriormentes son eliminadas del dataset. Estas entidades corresponden a empresas estatales como universidades, las cuales poseen áreas de proyectos o investigación para el autofinanciamiento.

# %%
del_empresas = []
for organismo in lista_organismos:
    for empresa in lista_empresas:
        if organismo == empresa:
            del_empresas.append(organismo)
del_empresas

for universidad in del_empresas:
    df = df[df['NombreProveedor'] != universidad]

lista_empresas = df['NombreProveedor'].unique()
len(lista_empresas)
# Out:
# 37758

# %%
del_empresas
# Out:
# ['UNIVERSIDAD DE MAGALLANES',
#  'UNIVERSIDAD DEL BIO BIO',
#  'UNIVERSIDAD DE ATACAMA',
#  'UNIVERSIDAD DE TALCA',
#  'UNIVERSIDAD DE LA FRONTERA',
#  'INSTITUTO FORESTAL',
#  'INSTITUTO DE FOMENTO PESQUERO']

# %%
# Conteo de repeticiones organismo-proveedor

pivot = pd.pivot_table(df, index=['NombreOrganismo','NombreProveedor'],values=['Oferta seleccionada'],aggfunc='count')
pivot = pivot.reset_index().sort_values(by='Oferta seleccionada', ascending=False)
pivot.rename(columns = {'Oferta seleccionada':'Conteo Interacciones'}, inplace = True)
pivot.head(15)
# Out:
#                                 NombreOrganismo  \
# 72006                   I MUNICIPALIDAD DE LOTA
# 72002                   I MUNICIPALIDAD DE LOTA
# 131187      INSTITUTO DE SALUD PUBLICA DE CHILE
# 131119      INSTITUTO DE SALUD PUBLICA DE CHILE
# 131168      INSTITUTO DE SALUD PUBLICA DE CHILE
# 24116   FUERZA AEREA DE CHILE COMANDO LOGISTICO
# 39350                  I MUNICIPALIDAD DE ARICA
# 66510                I MUNICIPALIDAD DE LINARES
# 131172      INSTITUTO DE SALUD PUBLICA DE CHILE
# 124206        ILUSTRE MUNICIPALIDAD DE LA LIGUA
# 66370                I MUNICIPALIDAD DE LINARES
# 66823                I MUNICIPALIDAD DE LINARES
# 66637                I MUNICIPALIDAD DE LINARES
# 131200      INSTITUTO DE SALUD PUBLICA DE CHILE
# 4158               COMANDO DE APOYO A LA FUERZA
#
#                       NombreProveedor  Conteo Interacciones
# 72006          MULTICOMERCIAL CHILLAN                  4679
# 72002                  MOSIL LIMITADA                  3380
# 131187             LIFE SERVICES LTDA                  2569
# 131119             Claudia del Carmen                  2118
# 131168        INMUNODIAGNOSTICO LTDA.                  1608
# 24116                        Alfredo                   1575
# 39350                           ARICA                  1400
# 66510        Distribuidora Salcobrand                  1397
# 131172        Importadora Dilaco S.A.                  1397
# 124206       Distribuidora Salcobrand                  1353
# 66370                ADN FARMACÉUTICA                  1346
# 66823        Socofar Division Munnich                  1306
# 66637                         LABOFAR                  1267
# 131200  Merck S.A. Productos Químicos                  1215
# 4158                          PS Vial                  1151

# %% [markdown]
# Para la creación de la red se buscan los pares de nodos con su respectivo peso, en este caso sería la cantidad de interacciones que tiene un Organismo con un Proveedor de manera individual.
#
# Siguiendo la línea de calcular las coincidencias, se realizó un conteo para el dataset filtrado por empresas seleccionadas, lo cual dió pistas claras para investigar, sin embargo, esa parte del proyecto será abordada más adelante.

# %%
# pivot sólo proveedores seleccionados
df15 = df[df['Oferta seleccionada'] == 'Seleccionada']

pivot15 = pd.pivot_table(df15, index=['NombreOrganismo','NombreProveedor'],values=['Oferta seleccionada'],aggfunc='count')
pivot15 = pivot15.reset_index().sort_values(by='Oferta seleccionada', ascending=False)
pivot15.rename(columns = {'Oferta seleccionada':'Conteo Seleccionados'}, inplace = True)
pivot15.head(15)
# Out:
#                                          NombreOrganismo  \
# 27511                            I MUNICIPALIDAD DE LOTA
# 27512                            I MUNICIPALIDAD DE LOTA
# 24837                            I MUNICIPALIDAD DE LAJA
# 67156           SERVICIO DE SALUD VALDIVIA HOSPITAL BASE
# 46737                INSTITUTO DE SALUD PUBLICA DE CHILE
# 46714                INSTITUTO DE SALUD PUBLICA DE CHILE
# 56516  SERV SALUD METROPOLITANO CENTRAL HOSPITAL CLIN...
# 7515               DIRECCION DE LOGISTICA DE CARABINEROS
# 11138                               HOSPITAL BASE OSORNO
# 27402                            I MUNICIPALIDAD DE LOTA
# 63888           SERVICIO DE SALUD HOSPITAL DE SANTA CRUZ
# 72604                     SUBSECRETARIA DE SALUD PUBLICA
# 69040  SERVICIO NACIONAL DE SALUD HOSPITAL CARLOS VAN...
# 27439                            I MUNICIPALIDAD DE LOTA
# 62158     SERVICIO DE SALUD DEL MAULE HOSPITAL DE PARRAL
#
#                            NombreProveedor  Conteo Seleccionados
# 27511                       MOSIL LIMITADA                  2045
# 27512               MULTICOMERCIAL CHILLAN                  1751
# 24837                      Gabriel Enrique                   776
# 67156   UC CHRISTUS SERVICIOS CLINICOS SpA                   727
# 46737  SERVICIO DE METROLOGIA INTEGRAL SPA                   632
# 46714        Merck S.A. Productos Químicos                   579
# 56516                          Therapía iv                   577
# 7515             SODIMAC SA - LICITACIONES                   554
# 11138  Roche Chile Ltda. Roche Diagnostics                   503
# 27402          Carlos Espejo y Cía. Ltda.-                   498
# 63888  Roche Chile Ltda. Roche Diagnostics                   461
# 72604        Merck S.A. Productos Químicos                   434
# 69040            Johnson & Johnson Medical                   426
# 27439                           ElMINERITO                   421
# 62158                          VALTEK S.A.                   405

# %%
# Se crean tuplas con los pares organismo-proveedor y peso, a modo de encale entre los nodos

lista_tuplas_pesos = []

for i in pivot.to_numpy():
    lista_tuplas_pesos.append((i[0], i[1], i[2]))
lista_tuplas_pesos[:4]
# Out:
# [('I MUNICIPALIDAD DE LOTA', 'MULTICOMERCIAL CHILLAN', 4679),
#  ('I MUNICIPALIDAD DE LOTA', 'MOSIL LIMITADA', 3380),
#  ('INSTITUTO DE SALUD PUBLICA DE CHILE', 'LIFE SERVICES LTDA', 2569),
#  ('INSTITUTO DE SALUD PUBLICA DE CHILE', 'Claudia del Carmen', 2118)]

# %%
len(lista_tuplas_pesos)
# Out:
# 205391

# %%
# Se construye el gráfo de red bipartita

G = nx.Graph()
G.add_nodes_from(lista_empresas, bipartite=0)
G.add_nodes_from(lista_organismos,bipartite=1)
G.add_weighted_edges_from(lista_tuplas_pesos)
bipartite.is_bipartite(G)
# Out:
# True

# %% [markdown]
# ### Análisis de la red:

# %%
N1 = len(G)
L1 = G.size()
degrees1 = list(dict(G.degree()).values())
kmin1 = min(degrees1)
kmax1 = max(degrees1)
densidad = nx.density(G)
print("Número de nodos: ", N1)
print("Número de enlaces: ", L1)
print('-------')
print("Grado promedio: ", 2*L1/N1) #Formula vista en clases (qué sucedía con las redes reales?)
print("Grado promedio (alternativa de calculo)", np.mean(degrees1))
print('-------')
print("Grado mínimo: ", kmin1)
print("Grado máximo: ", kmax1)
print('-------')
print("Densidad de la red: ", densidad)
# Out:
# Número de nodos:  38617
# Número de enlaces:  205391
# -------
# Grado promedio:  10.637335888339333
# Grado promedio (alternativa de calculo) 10.637335888339333
# -------
# Grado mínimo:  1
# Grado máximo:  3165
# -------
# Densidad de la red:  0.00027546446779416127

# %% [markdown]
# Es posible apreciar que la densidad de la red es bastante baja, lo cual también permite inferir que la red poseería varias comunidades entre las cuales se relacionen los nodos.

# %%
# Distribución de grado de la red

degrees = list(dict(G.degree()).values())
plt.hist(list(degrees))
plt.show()

# %%
# Entrega 20 bins linealmente espaceados entre kmin y kmax
bin_edges = np.linspace(kmin1, kmax1, num=30)

# histograma de la data en estos bines 
density, _ = np.histogram(degrees1, bins=bin_edges, density=True)
###Histograma
fig = plt.figure(figsize=(6,4))

# "x" debería ser el punto medido (en escala lineal) de cada bin
log_be = np.log10(bin_edges)
x = 10**((log_be[1:] + log_be[:-1])/2)

plt.plot(x, density, marker='o', linestyle='none')
plt.xlabel(r"degree $k$", fontsize=16)
plt.ylabel(r"$P(k)$", fontsize=16)

# Muestra la gráfica
plt.show()

# %%
bin_edges = np.logspace(np.log10(kmin1), np.log10(kmax1), num=30)
density, _ = np.histogram(degrees1, bins=bin_edges, density=True)
np.histogram(degrees1, bins=bin_edges, density=True)

###Histograma
fig = plt.figure(figsize=(6,4))

# "x" debe ser el punto medio (en escala LOG) de cada bin
log_be = np.log10(bin_edges)
x = 10**((log_be[1:] + log_be[:-1])/2)

plt.loglog(x, density, marker='o', linestyle='none')
plt.xlabel(r"degree $k$", fontsize=16)
plt.ylabel(r"$P(k)$", fontsize=16)

# Muestra la gráfica
plt.show()

# %% [markdown]
# El análisis mediante histogramas permite confirmar nuevamente que existe una gran cantidad de nodos poco conectados y que para grados mayores la distribución de nodos disminuye exponencialmente.

# %% [markdown]
# ### Identificacion de Comunidades:

# %% [markdown]
# - Tal como era posible predecir debido a lo poco densa de la red, existe una cantidad significativa de comunidades.
#
#
# - En este punto se ha optado por definir un random_state para la función de best_partition que arroje una partición con varias comunidades de baja cantidad de nodos, a fin de facilitar el análisis de las comunidades mediante algoritmos.

# %%
partition = community_louvain.best_partition(G, weight='weight', random_state = 6)

size = (len(set(partition.values())))#Numero de comunidades
print('Se detectan %d comunidades' % (size))
print('\n')

d = {}
for character, par in partition.items():
    if par in d:
        d[par].append(character)
    else:
        d[par] = [character]

for i in range(len(d)):
    print(f'Tamaño Comunidad {i}: {len(d[i])}')
# Out:
# Se detectan 15 comunidades
#
#
# Tamaño Comunidad 0: 3014
# Tamaño Comunidad 1: 3273
# Tamaño Comunidad 2: 7983
# Tamaño Comunidad 3: 8138
# Tamaño Comunidad 4: 52
# Tamaño Comunidad 5: 70
# Tamaño Comunidad 6: 4884
# Tamaño Comunidad 7: 701
# Tamaño Comunidad 8: 4515
# Tamaño Comunidad 9: 2314
# Tamaño Comunidad 10: 4
# Tamaño Comunidad 11: 2926
# Tamaño Comunidad 12: 732
# Tamaño Comunidad 13: 5
# Tamaño Comunidad 14: 6

# %% [markdown]
# ### Nota:
#
# ###### Dado que correr el código nx.spring_layout(G) tarda demasiado tiempo, se ha generado un código que permite importar ya la disposición de nodos desde un archivo CSV.
#
# ###### Se recomienda desactivar o eliminar los siguientes códicos si el programa ya ha sido ejecutado previamente y el archivo CSV ha sido generado, a fin de agilizar su ejecución:
#
#
# - pos = nx.spring_layout(G) # Layout para la red (coordenadas de los nodos y enlaces)
# - pos_export = pd.DataFrame(pos)
# - pos_export.to_csv('TareaFinalPos.csv')

# %%
#pos = nx.spring_layout(G) # Layout para la red (coordenadas de los nodos y enlaces)
#pos_export = pd.DataFrame(pos)
#pos_export.to_csv('TareaFinalPos.csv')
pos_import = pd.read_csv('TareaFinalPos.csv', sep=',')
#pos_import = pos_export
pos_import = pos_import.drop(['Unnamed: 0'], axis=1)
cord_dict = {}
for key in pos_import:
    cord = [pos_import[key][0], pos_import[key][1]]
    cord = np.array(cord)
    cord_dict[key] = cord
    
pos_import = cord_dict

# %%
#Posiciones definidas para los nodos
len(pos_import)
# Out:
# 38617

# %%
#Verificacion de cantidad de nodos
len(lista_organismos)+len(lista_empresas)
# Out:
# 38617

# %%
#Corroborar que la suma de cada nodo separado en als comunidades coincidan con la cantidad de nodos

sum = int()
for i in range(len(d)):
    sum = sum + len(d[i])
print (sum)
# Out:
# 38617

# %% [markdown]
# #### Ploteo del Grafo

# %%
plt.figure(figsize=(25, 15))

#colors = [np.array(cm.jet(x)).reshape(1,-1) for x in np.linspace(0, 1, size)]#cm.jet es el mapa de colores https://www.programcreek.com/python/example/56498/matplotlib.cm.jet
colors = ['white', 'white', 'white', 'yellow', 'white', 'white', 'white', 'white', 'white', 'white', 'cyan', 'orange', 'blue', 'white', 'green', 'red', ]

count = 0
for com in set(partition.values()): #para cada comunidad
    list_nodes = [nodes for nodes in partition.keys() if partition[nodes] == com]
    nx.draw_networkx_nodes(G, pos_import, list_nodes, node_size = 20, node_color=colors[count], alpha=0.8)#plotea nodos con colors por comunidad
    count = count + 1# para iterar sobre los colores

nx.draw_networkx_edges(G, pos_import, alpha=0.5, width=0.15)#plotea enlaces
plt.show()

# %% [markdown]
# Mediante el gráfico de red es posible notar que si bien existen comunidades pequeñas que se notan aisladas en la periferia, se denota que las comunidades mas grandes no son facilmente separables entre si, por lo cual se deduce que la partición debe tener baja modularidad.

# %% [markdown]
# ## Identificación de patrones de corrupción

# %%
# Funcion para crear lista de codigos de licitacion entre un par organismo-proveedor

def lista_empresa_licitacion(nombre_organismo, nombre_proveedor):
    
    df_ddn = df[['Codigo','NombreOrganismo','NombreProveedor','Oferta seleccionada']]
    df_ddn = df_ddn[(df_ddn['NombreProveedor'] == nombre_proveedor) ]
    
    lista_codigos = []

    for i in df_ddn['Codigo'].to_numpy():
        lista_codigos.append(i)
       
    return lista_codigos

# Funcion para conseguir el coeficiente de jaccard

def jaccard(grupo1, grupo2):
    interseccion = len(set(grupo1).intersection(set(grupo2)))
    union = len (set(grupo1).union(set(grupo2)))
    
    return interseccion / union , interseccion

# Funcion para conseguir el coeficiente de jaccard para todos los nodos dentro de una comunidad

def jaccard_completo(dd):
    
    lista_nombres_organismos = dd['NombreOrganismo']
    lista_nombres_proveedores = dd['NombreProveedor']
    
    dicc_codigos_dd = {}
    
    df = pd.DataFrame(columns=['NombreProveedor_1', 'NombreProveedor_2', 'Coeficiente de Jaccard', 'CantidadCoincidencias'])
    
    for i in range(len(dd)):
        lista_codigos = lista_empresa_licitacion(lista_nombres_organismos[i], lista_nombres_proveedores[i])
        
        dicc_codigos_dd[lista_nombres_proveedores[i]] = lista_codigos
                
    for key_j, value_j in dicc_codigos_dd.items():
        for key_k, value_k in dicc_codigos_dd.items():
            jacard_empresas, interseccion = jaccard(value_j, value_k)
            #print (f"Porcentaje de similitud Para Empresas {key_j} y {key_k} : {round(jacard_empresas,2)}")
            df_append = pd.DataFrame({'NombreProveedor_1': key_j, 'NombreProveedor_2': key_k,
                                      'Coeficiente de Jaccard': round(jacard_empresas,2), 'CantidadCoincidencias':interseccion }, index=[0])
            frames = [df, df_append]
            df = pd.concat(frames)
            
    df = df.sort_values(by='Coeficiente de Jaccard', ascending=False)
    df = df.reset_index().drop(columns='index')
    
    for index, row in df.iterrows():
        if row['NombreProveedor_1'] == row['NombreProveedor_2']:
            df = df.drop(index)
    df = df.reset_index().drop(columns='index')
    df2 = df
    for i in range(len(df2)):
        for k in range(i+1, len(df2)):
            
            if df2.NombreProveedor_1[i] == df2.NombreProveedor_2[k]: 
                if df2.NombreProveedor_1[k] == df2.NombreProveedor_2[i]:
                    df = df.drop(k)
        
    return df

# %%
def comunidad(df, d):

    df2 = pd.DataFrame()
    j = 0
    for i in range (len(df)):
        if df.NombreOrganismo[i] in d:
            if j == 0:
                df2 = df.loc[i:i]
                j = 1
            else:
                df3 = df.loc[i:i]
                frames = [df2,df3]
                df2 = pd.concat(frames)
    df2 = df2.reset_index()
    
    j = 0
    for i in range (len(df2)):
        if df2.NombreProveedor[i] in d:
            if j == 0:
                df1 = df2.loc[i:i]
                j = 1
            else:
                df3 = df2.loc[i:i]
                frames = [df1,df3]
                df1 = pd.concat(frames)
    df1 = df1.reset_index()                        
    df1 = df1[['NombreOrganismo','NombreProveedor','Conteo Interacciones']]
    
    lista_tuplas_pesos = []
    for i in df1.to_numpy():
        lista_tuplas_pesos.append((i[0], i[1], i[2]))
    lista_tuplas_pesos[:4]

    G = nx.Graph()
    G.add_nodes_from(df1['NombreProveedor'].unique(), bipartite=0)
    G.add_nodes_from(df1['NombreOrganismo'].unique(),bipartite=1)
    G.add_weighted_edges_from(lista_tuplas_pesos)
    
    plt.figure(figsize=(10, 6))
    
    pos = nx.spring_layout(G)
    nx.draw_networkx_nodes(G, pos, d, node_size = 20, node_color=['red'], alpha=0.8)
    nx.draw_networkx_edges(G, pos, alpha=0.8, width=0.25)

    plt.show()
            
    return df1, G

# %% [markdown]
# ### Comunidad de estudio #1: Gobierno Regional de Atacama
#
# Para esta comunidad se realizaron dos análisis: el primero mediante la representación gráfica de la red bipartita y la tabla de enlaces ponderados, para poder definir si existe algún tipo de vinculación entre el organismo licitador y las empresas proveedoras. El segundo es el cálculo del coeficiente de Jaccard, para identificar la razón de coincidencias entre las licitaciones en las que participan los nodos de la comunidad.

# %%
dd0,Gd0 = comunidad(pivot, d[13])
dd0.sort_values(by='Conteo Interacciones', ascending=False)
# Out:
#                 NombreOrganismo       NombreProveedor  Conteo Interacciones
# 1  GOBIERNO REGIONAL DE ATACAMA  Conecta Global Ltda.                    11
# 2  GOBIERNO REGIONAL DE ATACAMA        GYP TECNOLOGIA                    11
# 0  GOBIERNO REGIONAL DE ATACAMA    Aquapress Limitada                     1
# 3  GOBIERNO REGIONAL DE ATACAMA   Zerega Y Cia. Ltda.                     1

# %% [markdown]
# Es posible apreciar que existe una llamativa distribución en las particiones dentro de esta comunidad, donde un total de 25 participaciones en licitaciones corresponden a solo 2 códigos con un total de 12 OC emitidas.

# %%
df0 = df[df['NombreOrganismo'] == 'GOBIERNO REGIONAL DE ATACAMA']
df0 = df0[['Codigo','Tipo de Adquisicion','NombreOrganismo','NombreProveedor','MontoLineaAdjudica','Moneda de la Oferta']]
df0
# Out:
#           Codigo                           Tipo de Adquisicion  \
# 475059   8748588  Licitación Pública Entre 100 y 1000 UTM (LE)
# 475060   8748588  Licitación Pública Entre 100 y 1000 UTM (LE)
# 475061   8748588  Licitación Pública Entre 100 y 1000 UTM (LE)
# 475062   8748588  Licitación Pública Entre 100 y 1000 UTM (LE)
# 475063   8748588  Licitación Pública Entre 100 y 1000 UTM (LE)
# 475064   8748588  Licitación Pública Entre 100 y 1000 UTM (LE)
# 475065   8748588  Licitación Pública Entre 100 y 1000 UTM (LE)
# 475066   8748588  Licitación Pública Entre 100 y 1000 UTM (LE)
# 475067   8748588  Licitación Pública Entre 100 y 1000 UTM (LE)
# 475068   8748588  Licitación Pública Entre 100 y 1000 UTM (LE)
# 475069   8748588  Licitación Pública Entre 100 y 1000 UTM (LE)
# 475070   8748588  Licitación Pública Entre 100 y 1000 UTM (LE)
# 475071   8748588  Licitación Pública Entre 100 y 1000 UTM (LE)
# 475072   8748588  Licitación Pública Entre 100 y 1000 UTM (LE)
# 475073   8748588  Licitación Pública Entre 100 y 1000 UTM (LE)
# 475074   8748588  Licitación Pública Entre 100 y 1000 UTM (LE)
# 475075   8748588  Licitación Pública Entre 100 y 1000 UTM (LE)
# 475076   8748588  Licitación Pública Entre 100 y 1000 UTM (LE)
# 475077   8748588  Licitación Pública Entre 100 y 1000 UTM (LE)
# 475078   8748588  Licitación Pública Entre 100 y 1000 UTM (LE)
# 475079   8748588  Licitación Pública Entre 100 y 1000 UTM (LE)
# 475080   8748588  Licitación Pública Entre 100 y 1000 UTM (LE)
# 1151391  8682225  Licitación Pública Entre 100 y 1000 UTM (LE)
# 1151392  8682225  Licitación Pública Entre 100 y 1000 UTM (LE)
# 1151393  8682225  Licitación Pública Entre 100 y 1000 UTM (LE)
#
#                       NombreOrganismo  \
# 475059   GOBIERNO REGIONAL DE ATACAMA
# 475060   GOBIERNO REGIONAL DE ATACAMA
# 475061   GOBIERNO REGIONAL DE ATACAMA
# 475062   GOBIERNO REGIONAL DE ATACAMA
# 475063   GOBIERNO REGIONAL DE ATACAMA
# 475064   GOBIERNO REGIONAL DE ATACAMA
# 475065   GOBIERNO REGIONAL DE ATACAMA
# 475066   GOBIERNO REGIONAL DE ATACAMA
# 475067   GOBIERNO REGIONAL DE ATACAMA
# 475068   GOBIERNO REGIONAL DE ATACAMA
# 475069   GOBIERNO REGIONAL DE ATACAMA
# 475070   GOBIERNO REGIONAL DE ATACAMA
# 475071   GOBIERNO REGIONAL DE ATACAMA
# 475072   GOBIERNO REGIONAL DE ATACAMA
# 475073   GOBIERNO REGIONAL DE ATACAMA
# 475074   GOBIERNO REGIONAL DE ATACAMA
# 475075   GOBIERNO REGIONAL DE ATACAMA
# 475076   GOBIERNO REGIONAL DE ATACAMA
# 475077   GOBIERNO REGIONAL DE ATACAMA
# 475078   GOBIERNO REGIONAL DE ATACAMA
# 475079   GOBIERNO REGIONAL DE ATACAMA
# 475080   GOBIERNO REGIONAL DE ATACAMA
# 1151391  GOBIERNO REGIONAL DE ATACAMA
# 1151392  GOBIERNO REGIONAL DE ATACAMA
# 1151393  GOBIERNO REGIONAL DE ATACAMA
#
#                                            NombreProveedor MontoLineaAdjudica  \
# 475059                                      GYP TECNOLOGIA              15000
# 475060                                Conecta Global Ltda.                  0
# 475061                                Conecta Global Ltda.                  0
# 475062                                      GYP TECNOLOGIA              18000
# 475063                                      GYP TECNOLOGIA              20000
# 475064                                Conecta Global Ltda.                  0
# 475065                                Conecta Global Ltda.                  0
# 475066                                      GYP TECNOLOGIA              25000
# 475067                                      GYP TECNOLOGIA              18000
# 475068                                Conecta Global Ltda.                  0
# 475069                                Conecta Global Ltda.                  0
# 475070                                      GYP TECNOLOGIA              80000
# 475071                                      GYP TECNOLOGIA              18000
# 475072                                Conecta Global Ltda.                  0
# 475073                                Conecta Global Ltda.                  0
# 475074                                      GYP TECNOLOGIA              15000
# 475075                                      GYP TECNOLOGIA              75000
# 475076                                Conecta Global Ltda.                  0
# 475077                                Conecta Global Ltda.                  0
# 475078                                      GYP TECNOLOGIA                  0
# 475079                                      GYP TECNOLOGIA              71400
# 475080                                Conecta Global Ltda.                  0
# 1151391  MANTENCION REPARACION ALEJANDRA ZAVALA URZUA EIRL                  0
# 1151392                                Zerega Y Cia. Ltda.           19800000
# 1151393                                 Aquapress Limitada                  0
#
#         Moneda de la Oferta
# 475059         Peso Chileno
# 475060         Peso Chileno
# 475061         Peso Chileno
# 475062         Peso Chileno
# 475063         Peso Chileno
# 475064         Peso Chileno
# 475065         Peso Chileno
# 475066         Peso Chileno
# 475067         Peso Chileno
# 475068         Peso Chileno
# 475069         Peso Chileno
# 475070         Peso Chileno
# 475071         Peso Chileno
# 475072         Peso Chileno
# 475073         Peso Chileno
# 475074         Peso Chileno
# 475075         Peso Chileno
# 475076         Peso Chileno
# 475077         Peso Chileno
# 475078         Peso Chileno
# 475079         Peso Chileno
# 475080         Peso Chileno
# 1151391        Peso Chileno
# 1151392        Peso Chileno
# 1151393        Peso Chileno

# %%
df0[df0['Codigo']== 8748588]['MontoLineaAdjudica'].astype('int64', copy=False).sum()
# Out:
# 355400

# %% [markdown]
# - Dentro de las 12 OC emitidas por el Gobierno Regional de Atacama, 11 son a "GYP TECNOLOGIA" con un valor total de $355.400, donde el proceso de licitación contó con solamente un oferente adicional.
#
# - Respecto a la OC restante , en su proceso de licitación sólo participaron 3 oferentes y el proveedor adjudicado fue "Zerega y Cia.Ltda" por un monto de $19.800.000.

# %%
codigos = jaccard_completo(dd0)
codigos[codigos['CantidadCoincidencias']>0.9*codigos['CantidadCoincidencias'].max()]
# Out:
#       NombreProveedor_1    NombreProveedor_2  Coeficiente de Jaccard  \
# 0    Aquapress Limitada  Zerega Y Cia. Ltda.                     1.0
# 2  Conecta Global Ltda.       GYP TECNOLOGIA                     0.5
#
#   CantidadCoincidencias
# 0                     1
# 2                     1

# %% [markdown]
# - Este indicador permite identificar que en el caso de "Aquapress Limitada" y "Zerega Y Cia. Ltda." dentro de los registros solo poseen una única participación en licitaciones y corresponde a la del Gobierno Regional de Atacama.
#
#
# - Si bien ambos procesos de adjudicación parecen llamativos, en el caso de la licitación 8682225 adjudicada a "Zerega Y Cia. Ltda." es mucho más llamativo ya que por un lado la licitación posee muy pocos oferentes y 2 de ellos presentan solo una única participación lo cual podría ser indicio de colusión o de participantes que solo buscaban completar la terna para que la licitación no sea declarada desierta.

# %% [markdown]
# ### Comunidad de estudio #2: Hospital Padre Alberto Hurtado

# %%
dd1,Gd1 = comunidad(pivot, d[14])
dd1.sort_values(by='Conteo Interacciones', ascending=False)
# Out:
#                   NombreOrganismo  NombreProveedor  Conteo Interacciones
# 2  HOSPITAL PADRE ALBERTO HURTADO   PAB Ingeniería                    64
# 3  HOSPITAL PADRE ALBERTO HURTADO  Valeska Solange                    50
# 0  HOSPITAL PADRE ALBERTO HURTADO  AIR CENTRAL SPA                     1
# 1  HOSPITAL PADRE ALBERTO HURTADO     APO Limitada                     1
# 4  HOSPITAL PADRE ALBERTO HURTADO  barbara michele                     1

# %%
codigos1 = jaccard_completo(dd1)
codigos1[codigos1['CantidadCoincidencias']>0.9*codigos1['CantidadCoincidencias'].max()]
# Out:
#   NombreProveedor_1 NombreProveedor_2  Coeficiente de Jaccard  \
# 0   barbara michele      APO Limitada                     0.5
# 2    PAB Ingeniería   Valeska Solange                     0.5
#
#   CantidadCoincidencias
# 0                     1
# 2                     1

# %%
df1[df1['NombreProveedor'] == 'Valeska Solange'].head(2)
# Out:
#           Codigo                           Tipo de Adquisicion  \
# 1529433  8703857  Licitación Pública Entre 100 y 1000 UTM (LE)
# 1529434  8703857  Licitación Pública Entre 100 y 1000 UTM (LE)
#
#                         NombreOrganismo  NombreProveedor MontoLineaAdjudica  \
# 1529433  HOSPITAL PADRE ALBERTO HURTADO  Valeska Solange               3100
# 1529434  HOSPITAL PADRE ALBERTO HURTADO  Valeska Solange               1500
#
#         Moneda de la Oferta
# 1529433        Peso Chileno
# 1529434        Peso Chileno

# %%
df1[df1['NombreProveedor'] == 'PAB Ingeniería'].head(2)
# Out:
#           Codigo                           Tipo de Adquisicion  \
# 1529424  8703857  Licitación Pública Entre 100 y 1000 UTM (LE)
# 1529425  8703857  Licitación Pública Entre 100 y 1000 UTM (LE)
#
#                         NombreOrganismo NombreProveedor MontoLineaAdjudica  \
# 1529424  HOSPITAL PADRE ALBERTO HURTADO  PAB Ingeniería               3890
# 1529425  HOSPITAL PADRE ALBERTO HURTADO  PAB Ingeniería               3890
#
#         Moneda de la Oferta
# 1529424        Peso Chileno
# 1529425        Peso Chileno

# %% [markdown]
# - En este caso, se aprecia una comunidad en torno al "HOSPITAL PADRE ALBERTO HURTADO" en torno a la cual se han detectado 5 nodos con un total de 117 ofertas realizadas.
#
#
# - Dentro de los nodos con mayor coeficiente de Jaccar se encuentran "PAB Ingeniería" y "Valeska Solange" con un indice de 0.5, sin embargo, se descarta algún tipo de colusión ya que ambas empresas coincidieron unicamente en la licitación 8703857 dividida en varias adjudicaciones donde cada uno de los proveedores tuvo adjudicaciones.

# %%
df1 = df[df['NombreOrganismo'] == 'HOSPITAL PADRE ALBERTO HURTADO'][df['Oferta seleccionada']=='Seleccionada']
df1 = df1[['Codigo','Tipo de Adquisicion','NombreOrganismo','NombreProveedor','MontoLineaAdjudica','Moneda de la Oferta']]
df1.head(2)
len(df1)
# Out:
# C:\Users\pablo\AppData\Local\Temp\ipykernel_25932\2207091014.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df1 = df[df['NombreOrganismo'] == 'HOSPITAL PADRE ALBERTO HURTADO'][df['Oferta seleccionada']=='Seleccionada']
# 89

# %%
len(df1[df1['NombreProveedor'] == 'PAB Ingeniería'])
# Out:
# 38

# %% [markdown]
# - Dentro de la comunidad en análisis el nodo con mayor cantidad de adjudicaciones corresponde a "PAB Ingeniería", con 38 de las 89 adjudicaciones realizadas por el hospital.

# %%
df1[df1['NombreProveedor'] == 'PAB Ingeniería']['MontoLineaAdjudica'].astype('int64', copy=False).sum()
# Out:
# 642867

# %% [markdown]
# - De lo anterior, puede ser atribuido a que si bien existe una comunidad de nodos fuertemente relacionados con el Hospital Padre Alberto Hurtado, en realidad estos solo representan una porción menor del total de ofertas presentadas por proveedores a dicho hospital, 117 de 269, por lo cual en realidad existe mayor competencia aparte de la que conforman los nodos de esta comunidad.

# %% [markdown]
# ### Comunidad de estudio #3: Municipalidad Freirina, Municipalidad Hualaihue y SS Hospital Quirihue

# %%
dd2,Gd2 = comunidad(pivot, d[4])
dd2.sort_values(by='Conteo Interacciones', ascending=False)
# Out:
#                                  NombreOrganismo  \
# 15                   I MUNICIPALIDAD DE FREIRINA
# 9                    I MUNICIPALIDAD DE FREIRINA
# 5                    I MUNICIPALIDAD DE FREIRINA
# 2                    I MUNICIPALIDAD DE FREIRINA
# 12                   I MUNICIPALIDAD DE FREIRINA
# 40  SERVICIO DE SALUD NUBLE HOSPITAL DE QUIRIHUE
# 33                  I MUNICIPALIDAD DE HUALAIHUE
# 20                  I MUNICIPALIDAD DE HUALAIHUE
# 43  SERVICIO DE SALUD NUBLE HOSPITAL DE QUIRIHUE
# 34                  I MUNICIPALIDAD DE HUALAIHUE
# 29                  I MUNICIPALIDAD DE HUALAIHUE
# 13                   I MUNICIPALIDAD DE FREIRINA
# 19                  I MUNICIPALIDAD DE HUALAIHUE
# 28                  I MUNICIPALIDAD DE HUALAIHUE
# 50  SERVICIO DE SALUD NUBLE HOSPITAL DE QUIRIHUE
# 35                  I MUNICIPALIDAD DE HUALAIHUE
# 27                  I MUNICIPALIDAD DE HUALAIHUE
# 36                  I MUNICIPALIDAD DE HUALAIHUE
# 22                  I MUNICIPALIDAD DE HUALAIHUE
# 30                  I MUNICIPALIDAD DE HUALAIHUE
# 41  SERVICIO DE SALUD NUBLE HOSPITAL DE QUIRIHUE
# 23                  I MUNICIPALIDAD DE HUALAIHUE
# 1                    I MUNICIPALIDAD DE FREIRINA
# 25                  I MUNICIPALIDAD DE HUALAIHUE
# 24                  I MUNICIPALIDAD DE HUALAIHUE
# 46  SERVICIO DE SALUD NUBLE HOSPITAL DE QUIRIHUE
# 38                  I MUNICIPALIDAD DE HUALAIHUE
# 11                   I MUNICIPALIDAD DE FREIRINA
# 32                  I MUNICIPALIDAD DE HUALAIHUE
# 6                    I MUNICIPALIDAD DE FREIRINA
# 31                  I MUNICIPALIDAD DE HUALAIHUE
# 4                    I MUNICIPALIDAD DE FREIRINA
# 49  SERVICIO DE SALUD NUBLE HOSPITAL DE QUIRIHUE
# 48  SERVICIO DE SALUD NUBLE HOSPITAL DE QUIRIHUE
# 10                   I MUNICIPALIDAD DE FREIRINA
# 45  SERVICIO DE SALUD NUBLE HOSPITAL DE QUIRIHUE
# 44  SERVICIO DE SALUD NUBLE HOSPITAL DE QUIRIHUE
# 26                  I MUNICIPALIDAD DE HUALAIHUE
# 42  SERVICIO DE SALUD NUBLE HOSPITAL DE QUIRIHUE
# 47  SERVICIO DE SALUD NUBLE HOSPITAL DE QUIRIHUE
# 3                    I MUNICIPALIDAD DE FREIRINA
# 37                  I MUNICIPALIDAD DE HUALAIHUE
# 39  SERVICIO DE SALUD NUBLE HOSPITAL DE QUIRIHUE
# 21                  I MUNICIPALIDAD DE HUALAIHUE
# 7                    I MUNICIPALIDAD DE FREIRINA
# 8                    I MUNICIPALIDAD DE FREIRINA
# 14                   I MUNICIPALIDAD DE FREIRINA
# 16                   I MUNICIPALIDAD DE FREIRINA
# 17                   I MUNICIPALIDAD DE FREIRINA
# 18                  I MUNICIPALIDAD DE HUALAIHUE
# 0                    I MUNICIPALIDAD DE FREIRINA
#
#                               NombreProveedor  Conteo Interacciones
# 15                                 ferrohogar                   435
# 9               Ferretería Lonza y Cía. Ltda.                   380
# 5                             Carlos Carrasco                   374
# 2                              BRENDA ARACELY                   229
# 12                                      Multy                    21
# 40                           GUSTAVO GALLEGOS                    18
# 33                                 María José                    16
# 20                            BRAULIO RODRIGO                    16
# 43                              HECTOR HERNAN                    15
# 34                         OLEA SERVICIOS SPA                    15
# 29                              HECTOR HERNAN                    15
# 13                                 PabloSmith                    12
# 19                                  ALVEAL121                    10
# 28                            Geordy Heinrich                    10
# 50                         laboratorio dental                     9
# 35                               RUPERTO RAUL                     8
# 27                         FUNERARIA CASANOVA                     8
# 36                                 Ruth Amada                     8
# 22                            Daniel Leonardo                     8
# 30                                 JOSE JAIME                     6
# 41                             Gabriel Andres                     6
# 23                           ESTEBAN MAURICIO                     5
# 1                           ATACAMA PRO SPORT                     5
# 25                               El navegador                     5
# 24                      El Buen Gourmet Ltda.                     4
# 46                            Jonathan Santos                     4
# 38                           farmacia austral                     4
# 11                    INFORME REMOTO LIMITADA                     4
# 32                                   LMSA SPA                     4
# 6   ENTEL CHILE S.A. - Gerencia Zonal Iquique                     4
# 31                                   KEMELBUS                     3
# 4                                  CONGLO SPA                     3
# 49                            buses via itata                     3
# 48                       TRANSPORTE Y TURISMO                     2
# 10                                       Hugo                     2
# 45                    INFORME REMOTO LIMITADA                     2
# 44                  HUERTA ASOCIADOS LIMITADA                     2
# 26                  FERRETERIA EL CONSTRUCTOR                     2
# 42                            Global Planning                     2
# 47                          MICHAEL ALEJANDRA                     1
# 3                             CA PRODUCCIONES                     1
# 37                                 SALAZAR721                     1
# 39                             Daniel Edgardo                     1
# 21                        Construtecnia Chile                     1
# 7                              Eduardo Osciel                     1
# 8                 Emigdio H. Venegas Cereceda                     1
# 14           WILLIAMS ALIS MADARIAGA VALDIVIA                     1
# 16                             francollaodvet                     1
# 17                     nivaldo olivares lopez                     1
# 18                                AAAGALLARDO                     1
# 0                                   783960508                     1

# %%
codigos2 = jaccard_completo(dd2)
codigos2[codigos2['CantidadCoincidencias']>0.9*codigos2['CantidadCoincidencias'].max()]
# Out:
#    NombreProveedor_1                          NombreProveedor_2  \
# 0    BRAULIO RODRIGO                                 María José
# 6    BRAULIO RODRIGO                                  ALVEAL121
# 7          ALVEAL121                                 María José
# 26              Hugo  ENTEL CHILE S.A. - Gerencia Zonal Iquique
# 48     HECTOR HERNAN                               El navegador
#
#     Coeficiente de Jaccard CantidadCoincidencias
# 0                     1.00                     2
# 6                     0.67                     2
# 7                     0.67                     2
# 26                    0.22                     2
# 48                    0.08                     2

# %% [markdown]
# - Esta comunidad tiene un aspecto sano, si bien la tabla anterior nos muestra que existen proveedores con un alto coeficiente de Jaccard, se observa la cantidad de licitaciones asociadas a cada uno de estos 3 organimos es posible apreciar que la cantidad de licitaciones en que los proveedores "BRAULIO RODRIGO", "María José" o "ALVEAL121" sus coincidencias son muy pocas en relacion al total de licitaciones.
#
#
# - En general, el hecho de que nodos correspondientes a Proveedores conecten nodos correspondientes a Organismos, proporciona un sintoma de sanidad en la comunidad a diferencia de lo ocurrido en el caso del Gobierno Regional de Atacama.

# %% [markdown]
# ### Comunidad de estudio #4: Caso MOSIL LIMITADA

# %%
df101 = df[df['NombreProveedor'] == 'MOSIL LIMITADA'][df['Oferta seleccionada']=='Seleccionada']
df101 = pd.pivot_table(df101, index=['NombreOrganismo','NombreProveedor'],values=['Oferta seleccionada'],aggfunc='count')
df101 = df101.reset_index().sort_values(by='Oferta seleccionada', ascending=False)
df101.rename(columns = {'Oferta seleccionada':'Conteo Seleccionados'}, inplace = True)
df101.head(15)
# Out:
# C:\Users\pablo\AppData\Local\Temp\ipykernel_25932\424500896.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df101 = df[df['NombreProveedor'] == 'MOSIL LIMITADA'][df['Oferta seleccionada']=='Seleccionada']
#                            NombreOrganismo NombreProveedor  \
# 8                  I MUNICIPALIDAD DE LOTA  MOSIL LIMITADA
# 11  I MUNICIPALIDAD DE SAN PEDRO DE LA PAZ  MOSIL LIMITADA
# 18           Ilustre Municipalidad de Lebu  MOSIL LIMITADA
# 21                MUNICIPALIDAD DE HUALPEN  MOSIL LIMITADA
# 5               I MUNICIPALIDAD DE CORONEL  MOSIL LIMITADA
# 12        I MUNICIPALIDAD DE SANTA BARBARA  MOSIL LIMITADA
# 17    Ilustre Municipalidad de Curanilahue  MOSIL LIMITADA
# 14                 I MUNICIPALIDAD DE TOME  MOSIL LIMITADA
# 13          I MUNICIPALIDAD DE SANTA JUANA  MOSIL LIMITADA
# 15               I MUNICIPALIDAD DE YUMBEL  MOSIL LIMITADA
# 7           I MUNICIPALIDAD DE LOS ANGELES  MOSIL LIMITADA
# 20    Ilustre Municipalidad de San Rosendo  MOSIL LIMITADA
# 16        Ilustre Municipalidad de Calbuco  MOSIL LIMITADA
# 4           I MUNICIPALIDAD DE CHIGUAYANTE  MOSIL LIMITADA
# 10           I MUNICIPALIDAD DE NACIMIENTO  MOSIL LIMITADA
#
#     Conteo Seleccionados
# 8                   2045
# 11                    66
# 18                    36
# 21                    34
# 5                     12
# 12                    11
# 17                    10
# 14                    10
# 13                     5
# 15                     5
# 7                      4
# 20                     3
# 16                     3
# 4                      2
# 10                     2

# %%
df102 = df[df['NombreOrganismo'] == 'I MUNICIPALIDAD DE LOTA']
lota = []

for i in df102['NombreProveedor'].unique():
    lota.append(i)
    
lota.append('I MUNICIPALIDAD DE LOTA')

# %%
lota
# Out:
# ['Xavier Andres Lauriani Molina',
#  'Global Construcciones Spa',
#  'RAGLIANTI Y COMPAÑIA LIMITADA',
#  'roddan soluciones integrales spa',
#  'TERESA GARRIDO ROJAS E HIJOS LTDA',
#  'FRANCISCO MANUEL',
#  'Repuestos Hualqui',
#  'GENIALCOM SPA',
#  'SERVICIO TECNICO GILDEMEISTER',
#  'Jose Luis Pavez y Cía Ltda - BOSCH Car Service',
#  'FELIX OLEA',
#  'Universal Diesel',
#  'OLIMPO REPUESTOS',
#  'RICARDO ENRIQUE',
#  'DIARIO LA TRIBUNA',
#  'SOCIEDAD RADIODIFUSORA FM 102 LIMITADA',
#  'MULTICOMERCIAL CHILLAN LTDA CHILECOMPRAS',
#  'marcelo',
#  'MIG',
#  'SERVICIOS HIMCE LIMITADA',
#  'DK INGENIERIA Y CONSTRUCCION SPA',
#  'eco sweep',
#  'TOCONAO LTDA SOC. CORREDORA DE SEGUROS',
#  'Hdi Seguros S.A. - Temuco',
#  'Juan José González González',
#  'Comercial Antuco',
#  'Roanel',
#  'Rehuce Ltda',
#  'ORIETA ',
#  'MULTICOMERCIAL CHILLAN',
#  'XIMENA AYALA',
#  'Distribuidora Seguel Limitada',
#  'Roian Store',
#  'Ana Valentina ',
#  'Vanessa Hugo Osorio',
#  'ORKIN CHILE',
#  '79733881',
#  'Sanidec Plagas Cía Ltda',
#  'COMERCIALIZACIÓN',
#  'JORGE ANDRÉS ',
#  'Carlos Espejo y Cía. Ltda.-',
#  'MOSIL LIMITADA',
#  'Comercial Atila Trade',
#  'Importadora y Distribuidora Neumax S.A.',
#  'CRUZ Y CIA LTDA - Serviteca Talcahuano',
#  'NEUMACHILE',
#  'WAY SPA',
#  'SIEPL LTDA',
#  'PS Vial',
#  'PROVINTEC.SPA',
#  'Komatsu Chile S.A. - Concepción',
#  'SOCIEDAD LYJ',
#  'JOSE OLEA CORNEJO',
#  'Office Pro',
#  'Vilcar Ltda.',
#  'Distribuidora Dalver Ltda',
#  'J.H.Salazar  Limitada.',
#  'Const. Verver Ltda.',
#  'Sociedad Tecnológica y Servicios Express Ltda',
#  'ISOGRAPHIC',
#  'Servicios Médicos del Bío Bío Ltda.',
#  'Mainz Medical',
#  'JUANJH ALBERTO ',
#  'Diprolab Ltda.',
#  'resein chile',
#  'Mariana Issa Casanova',
#  'intermedica ltda',
#  'COMERCIALIZADORA ILHABELLA EIRL',
#  '4 Molles',
#  'Awad Artículos Médicos',
#  'Paramed  Ltda',
#  'Nestor Kother',
#  'ANGELO  IVAN',
#  'Textil las Américas',
#  'SEKAY LTDA',
#  'ESE&GE LTDA.',
#  'Hernan Antonio',
#  'Malalcura SPA',
#  'COMERCIAL CLS',
#  'VALERIA ESTER',
#  'Harro Industrial y Energías',
#  'Comercial Pradenas',
#  'ARGELEC Y CIA. LTDA.',
#  'MEGAFERCO',
#  'OH-PROTRUST SPA',
#  'Jaime Bahamondes Cavieres',
#  'servicios integrales Abril Spa',
#  'Yerko Enrique',
#  'Data Cool SPA',
#  'Ana María',
#  'Marjorie Elizabeth',
#  'HHERNANDEZ',
#  'itg ltda.',
#  'PRISUR',
#  'Impresion Digital,Offset,Agendas,Empaste y Merchan',
#  'Sumacomp Spa.',
#  'CRECIC S.A.',
#  'LABOFAR',
#  'ETHON PHARMACEUTICALS SPA.',
#  'DROGUERIA GLOBAL PHARMA SPA',
#  'Medikar Ltda',
#  'GDM',
#  'Distribuidora Salcobrand',
#  'LABORATORIOS ANDROMACO S.A.',
#  'LABORATORIOS RECALCINE S.A',
#  'Instituto Sanitas S.A.',
#  'BPH S.A',
#  'Novofarma Service SA - Axon-Pharma',
#  'CYDPHARMA LTDA.',
#  'INVERSIONES PHARMAVISAN S.A.',
#  'WINPHARM',
#  'Libreria Atlantik Ltda.',
#  'F y F Ltda.',
#  'Jaime Andres',
#  'CONSTRUCTORA DAVJO LIMITADA',
#  'comercial river',
#  'Patricio Alejandro',
#  'PROMANING EIRL',
#  'Caribean Pharma Ltda',
#  'ADN FARMACÉUTICA',
#  'Droguería Concepción Ltda',
#  'SOCOSEP SA',
#  'Socofar Division Munnich',
#  'Ascend Laboratories SpA',
#  'DIFEM LABORATORIOS S A',
#  'FARMACEUTICA SCHUBERT',
#  'LABORATORIO CHILE S.A.',
#  'OPKO CHILE S.A.',
#  'REUTTER DIVISION MEDICA',
#  'SOC.COM.DISTRIMED LTDA.',
#  'DISTRIBUIDORA QUALIMED LIMITADA',
#  'Multinsumos L&L',
#  'ByB Farmaceutica Ltda.',
#  'Chemopharma S.A.',
#  'INSUVAL S.A.',
#  'B.BRAUN MEDICAL SpA',
#  'marco antonio',
#  'COMERCIALIZADORA TICMA',
#  'EYE CONSTRUCCIONES ',
#  'Menssage',
#  'Carlos Ricardo',
#  'ELSA MARCELA',
#  'MATICES PUBLICIDAD SPA',
#  'Sociedad Comercial Oficinta Ltda.',
#  'JOSE SANTOS',
#  'MAITERR',
#  'RICARDO RODRIGUEZ Y CIA. LTDA.',
#  'LUIS ALBERTO',
#  'María',
#  'Liberman Ltda',
#  'FUENTES',
#  'Servicom SpA',
#  'L&L SPA',
#  'Comercializadora Garcia Olivares SPA',
#  'SAN SEBASTIAN',
#  'QUIMICA PASSOL S.A.',
#  'Pinturas Tricolor S.A.',
#  'LOTHUS',
#  'Geo logística',
#  'Carlos Alberto',
#  'JUAN ',
#  'COMERCIALIZADORA DE PRODUCTOS VIALES LTDA.',
#  'Almaro Operaciones',
#  'ferreteria t y t limitada',
#  'Renato Dario',
#  'Hector Enrique',
#  'Comercial Palihue',
#  'PANTONLIMITADA',
#  'Plagbío Servicios',
#  'DESAN',
#  'Eduardo Arturo',
#  'DIST. ARTICULOS MEDICOS PÉREZ SPA',
#  'Drogueria Hofmann',
#  'IMPORTADORA SURDENT LIMITADA',
#  'Carpedent SpA',
#  'Eksa Dental',
#  'TURBINACHILE',
#  'DENTAL LAVAL LTDA.',
#  'MURUA Y ASOCIADOS LTDA',
#  'TELCOMT LIMITADA',
#  'DentiMovil',
#  'Trema',
#  'Inmunodent Coronel',
#  'SYNTHON CHILE LTDA.',
#  'Pharmaxpress Spa',
#  'Laboratorio Pasteur SA',
#  'HOSPIFARMA',
#  '2 Janssen-Cilag Chile',
#  'INSUMOS/EQUIPOS MEDICOS',
#  'CEEL INGENIERIA SPA',
#  'B&R Ltda',
#  'Maria Bello Rivera',
#  'Sebastian matias',
#  'LAVIN Y COMPANIA LIMITADA',
#  'Comercial Centella',
#  'SL MULTISPORT',
#  'AGR SPA',
#  'Eduardo Ricardo',
#  'agroworld',
#  'FEILON',
#  'FULL SAFETY COMPANY LIMITADA',
#  'Dipromed S.A.',
#  'OPEN STOCK SPA',
#  'FERNANDO VELOSO OLIVA',
#  'Arena Tienda Limitada',
#  'DyJ Servicios Integrales Spa',
#  'Redeyes',
#  'Comercial San Fernando',
#  'FYM PRODUCCIONES',
#  'IMPORTADORA VIVE MAS SPA',
#  'Viaimport',
#  'OPENLINE CHILE',
#  'Nuovo SpA',
#  'Deborat Susana',
#  'BIOTECH LIMITADA',
#  'PUBLICIDAD ARTICULOS DECOLOR SPA',
#  'INVERSOL LTDA',
#  'MAXIMO LTDA',
#  'WINTEC',
#  'ALJIN CHILE',
#  'BE TRADE',
#  'SEBASTIAN EMETERIO MARTINEZ MONTECINO',
#  'IMEX CLEAN SPA',
#  'valeska',
#  'Oficima SpA',
#  'NIPRO MEDICAL CORPORATION (AGENCIA EN CHILE)',
#  'DEL VALLE',
#  'Productos Médicos Promedon Chile S.A.',
#  'MedicalTek CHILE S.A.',
#  'Pronomed Ltda',
#  'Articulos Medicos y Quirurgicos Chile S.A.',
#  'Bluemedical Insumos',
#  'MEGAMARKET',
#  'NEMO CHILE',
#  'IGRO IMPEX',
#  'Kluffer',
#  'Espol S.A.',
#  'Mola Importaciones',
#  'MCI Spa',
#  'SASF DIVISION MEDICA',
#  'Cencomex S.A.',
#  'Emuchile S.A.',
#  'Comercial Maquinet Limitada',
#  'Ecohealth',
#  'MERIDA EIRL',
#  'BLUNDING S.A.',
#  'AlfaMed',
#  'Plasticos Ecologicos Muñofer',
#  'TALIOMED',
#  'FIREGROUND EQUIPAMIENTO SPA',
#  'comercial alto peumayen',
#  'AMARO PUBLICIDAD GROUP',
#  'Insumos Gottlieb',
#  'IBH',
#  'Winflex Spa',
#  'COOLTEC',
#  'MEGALABS CHILE SA MEDICAL DEVICE',
#  'K. y P. Servicios Ltda.',
#  'SECUR LIMITADA',
#  'AdjudicaChile Consultora en Licitaciones Públicas',
#  'COMERCIAL E INDUSTRIAL NOVA SEGURIDAD LIMITADA',
#  'ELEHEN',
#  'GCP Insumos',
#  'Comercializadora',
#  'Extintores  Victoria',
#  'carlos edgardo',
#  'EasyService',
#  'COMERCIAL INDIMEX LTDA',
#  'Grandes Tiendas La Covadonga',
#  'PRISA S A. - sucursal',
#  'Enlazar',
#  'Modaktuall S.A.',
#  'TEXAM SPA',
#  'Sumilab',
#  'Juan Carlos ',
#  'Extintores y Seguridad Industrial Superseg',
#  'apro ltda. - Casa Matriz',
#  'Sociedad Comercial Vercon SPA',
#  'TLR SPA',
#  'BIOSLABCHILE LTDA.',
#  'Primetex',
#  'Fabrica de detergentes industriales Marvelkleen Ch',
#  'CRISTIAN ANDRÉS',
#  'COMERCIAL INVADE',
#  'Comercial Don Talo ',
#  'el lolo',
#  'Maria Cecilia',
#  'ERICK ROBERTO',
#  'Constructora GRH',
#  'PATRICIA  PAOLA',
#  'MOTORSHOP',
#  'Tremiq Ltda',
#  'INVERSIONES Y SERVICIOS BALDER S A',
#  'COMERCIAL VR LIMITADA',
#  'INDURA MEDICA',
#  'Plusmedical SpA',
#  'Germed Ltda.',
#  'Amilab ltda.',
#  'HELPI MEDICAL SpA',
#  'NOVOFARMA-SOPHIA',
#  'Unidad de venta de productos oftalmológicos',
#  'Allergan Laboratorios Ltda.',
#  'ALCON LABORATORIOS CHILE LTDA - Alcon Chile Farmacéutico',
#  'Pisa Farmaceutica de Chile SpA',
#  'COMERCIAL DOÑA BLANCA ESTER EIRL',
#  'Coffebreak',
#  'la union',
#  'INSTEC Ingenieria y Construccion Ltda.',
#  'Alba Ambiente S.A',
#  'EMach',
#  'Laboratorio Biosano S.A.',
#  'FARMACIA IBERIA',
#  'Yenia Estefanía',
#  'ALEX SEBASTIAN FERNANDEZ ACUNA',
#  'DANIELA BELEN DIAZ SEPULVEDA',
#  'Francisca Marihuan Espejo',
#  'Manuel Rodolfo',
#  'CUPON ELECTRONICO Zona Sur',
#  'LA MADRILEÑA LTDA',
#  'Kanri - Consultoria',
#  'Advance Capacitaciones Limitada',
#  'UNIVERSIDAD DE LAS AMERICAS',
#  'Sociedad Educacional del Maule S.A.',
#  'Dynamic Consultores',
#  'Centro de Capacitación INNOVA',
#  'CAPACITACIONES CAEM LTDA',
#  'IC 2 CAPACITACIONES SPA',
#  'Andrea Soledad',
#  'ARTE VISUAL',
#  'FERRETERIA INDUSTRIAL EL MAESTRO AR LIMITADA',
#  'estampadojya',
#  'ESTAMPADOS Y SUBLIMACIÓN',
#  'Esteban Mauricio ',
#  'LYL SOLUCIONES LTDA',
#  'Fabrita',
#  'ricardo mauricio',
#  'RICMAR LTDA',
#  'DIMERC S.A.',
#  'Distribuidora Papeles Industriales SPA',
#  'ignacio alejandro',
#  'Carolina Paz',
#  'NUEVO HORIZONTE LIMITADA',
#  'Globo Marketing',
#  'ECOVERDE',
#  'fac',
#  'SOLOVERDE',
#  'JM Mantenimiento e importaciones',
#  'COMERCIAL EXPRESS DENT LIMITADA',
#  'QUIMVAL MEDICA LTDA.',
#  'BIO-PHARMAMED LIMITADA',
#  'LABORATORIO SANDERSON S.A.',
#  'zucar',
#  'Abbott Laboratories de Chile Ltda.',
#  'Sociedad Distribuidora Las Pataguas Ltda.',
#  'Vivirsalud',
#  'Renova Functionals S.A.',
#  'Miguel Edgardo Manuel',
#  'TOPOFFICE',
#  'HELMUTH GERARDO',
#  'Promedical Clinic',
#  'DISTRIBUIDORA Y COMERCIAL DIMAK LIMITADA',
#  'Merck S.A. Productos Farmacéuticos',
#  'ANTONIO',
#  'Comercializadora Mercadopublico SpA',
#  'Farmacia 18',
#  'Sociedad Comercial Seri SpA',
#  'XtremoSur SCL',
#  'DURBAN LTDA',
#  'RENHET SPA',
#  'FASTENAL',
#  'Moltex',
#  'Victoria',
#  'ABMMEDICAL LIMITADA',
#  'Datainnova',
#  'Comercializadora Raiper Chile SPA',
#  'winkler limitada',
#  'Importaciones y Servicios Advances Computing Techn',
#  'Comercial Sedille',
#  'Mecano Ltda',
#  'CONSTRUCTORA CONATUS LTDA',
#  'MANTO GRANDE SPA',
#  'SEGURIDAD PRIVADA',
#  'Procesán Casa Matriz',
#  'REDES CLINIC',
#  'ZUBIMED LTDA.',
#  'Los Hualles SpA',
#  'Imagenologa HCS',
#  'Centro de Especialidades Médicas Hospital del Trab',
#  'HECTOR IVAN',
#  'ILUMINA LIMITADA',
#  'Daniel Leonardo',
#  'KMALEON LTDA',
#  'Jose',
#  'CONFEMAC',
#  'Textil Matex',
#  'TRANSUIZA',
#  'miltelec',
#  'Juan ',
#  'Juan Alfredo',
#  'FERRECAM MAQUINARIAS',
#  'PATRICIO',
#  'Grupo MR8',
#  'ESENERGY SPA',
#  'EQUIPOS INDUSTRIALES PUERTO MONTT LTDA',
#  'Pulve Agri E.I.R.L.',
#  'Electronet Ltda',
#  'Comercial GP',
#  'bbr',
#  'MIRANDA SPA',
#  'IC RODFEL',
#  'COMERCIAL MUÑOZ Y CIA LTDA',
#  'dimalum',
#  'MAXIMILIANO',
#  'Novofarma Service S.A. - Boehringer',
#  'sandra Angelica ',
#  'OSCAR ',
#  'RAUL EMILIO GUTIERREZ OLIVARES',
#  'SERVICIOS DE IMPRESION Y PUBLICIDAD',
#  'OFFICECOM SPA',
#  'IMPROSOLUCIONES',
#  'digitalgraphicmatriz',
#  'JORGE YON SANDOVAL - Casa Matriz',
#  'CASA DE MONEDA DE CHILE S.A.',
#  'COPEC S.A.',
#  'SIGDOTEK S.A..',
#  'COMERCIALIZADORA RGSPA',
#  'Mavisa',
#  'Mantencion T y T SPA',
#  'NACER PUBLICIDAD',
#  'Hdi Seguros S.A. - Talca',
#  'LUIS ANDRES ',
#  'Carlos',
#  'GRAS',
#  'VIVIENDAS SANTA MARTA ',
#  'EVENTOS Y PUBLICIDAD.',
#  'ALLTRACK LTDA.',
#  'ElMINERITO',
#  'Danisa Isabel',
#  'Patricio Alberto',
#  'Distribuidora Vergio SA',
#  'cindy ',
#  'MyGroup',
#  'ZENAIDA OFELIA ',
#  'Decoraciones Viña',
#  'COMERCIAL 1',
#  'BlackHome',
#  'Hugo Hernan Cifuentes Diaz',
#  'Importadora & Comercializadora Unidad de Proyectos',
#  'DECOESTILO',
#  'LA ROSA',
#  'Construmad Hormigones',
#  'Rodrigo Jose Romero Soto',
#  'LA OTRA VERDAD DEL BIO BIO S A',
#  'Imp. Dist. Arquimed Ltda.',
#  'TCL LTDA.',
#  'ENERGON SPA',
#  'Electroproductos s.a. - Casa Matriz',
#  '"FACAVA" Electricidad',
#  'CLAUDIO ULLOA STEFFENS',
#  'Chilemat SpA',
#  'PCA',
#  'OLLER Y CÍA LIMITADA',
#  'OSM Ltda.',
#  'Maribel Cristina',
#  'MEGAMED CHILE LIMITADA',
#  'Re-Med',
#  'HUALPEN',
#  'ANTONIO SEBASTIAN',
#  'brauer',
#  'Zarzartex',
#  'CONCOREX',
#  'Desarrollo Integral Chile SpA',
#  'sasil',
#  'José Manuel ',
#  'ProviPaint EIRL ',
#  'ACCION SOLAR CHILE',
#  'INVERSIONES APS SPA',
#  'Eileen Elizabeth',
#  'Camilo',
#  'efical-segcal',
#  'Sociedad Altair Spa',
#  'Sebastian Ariel',
#  'AGENCIA CÓDIGOS',
#  'felipe andres',
#  'casonademirla',
#  'rene omar',
#  'SIIP LTDA',
#  'Rosa Chamorro',
#  'gatofelix',
#  'El Conejo Blanco SpA',
#  'GEM',
#  'Gilda Isabel Giovanetti Fuenzalida',
#  'Gaspar Eduardo',
#  'FRANCO DIEGO LEIVA PARDO',
#  'Cristobal Ignacio',
#  'FXCOM',
#  'ilumina ltda',
#  'Inversiones SAI',
#  'City Technology Spa',
#  'Deutsche Pharma',
#  'Mario',
#  'Oscar Andres',
#  'FOCOTRAB',
#  'MANGO SPA',
#  'SOUTH LIGHT CHILE LTDA',
#  'luis ',
#  'ELEC - CHILE COMPAÑIA INDUSTRIAL DE PRODUCTOS ELEC',
#  'Sociedad Tecnología en ilumina - Casa Matriz',
#  'VyR ingenieria y montaje',
#  'Victor Rene',
#  'Fullmedical',
#  'DISTRIBUIDORA CURANILAHUE',
#  'SIURON casa matriz',
#  'Shekina Ltda.',
#  'luis alberto',
#  'RECICLADOS LEONARDO PRIETO EIRL',
#  'Daniela Carolina',
#  'tecnidiesel ltda',
#  'SERVICIOS DE INGENIERIA Y MANTENCION TRAFO LTDA.',
#  'MEDIPHARM S.A.',
#  'ITF Labomed Farmaceutica Limitada',
#  'DMU ENERGY LIMITADA',
#  'Fullneumaticos',
#  'Tecnoworld',
#  'Papeles Andalién Concepción',
#  'PABLO MARCELO',
#  'ENOKS SPA',
#  'RUC Promociones',
#  'EDUCCIÓN SPA',
#  'Acrilandia',
#  'FARMALATINA LTDA.',
#  'SALAZAR Y SALAZAR LTDA.',
#  'FERRETERIA CORONEL SPA',
#  'canalzonal',
#  'PHARMATECH',
#  'REUTTER S.A',
#  'LABORATORIOS SANFER DE CHILE S.A.',
#  'PHARMAMERICA LTDA.',
#  'AndesLux',
#  'Vimarsa SpA',
#  'Jaime Ramirez e Hijo Ltda',
#  'B&B.S Edificaciones Servicios y Comercio SpA',
#  'Max Servicios SPA',
#  'BENJAMÍN ANDRES',
#  'etha distribuidora medica ltda.',
#  'PHARMAVISION SPA',
#  'LOGIMED LTDA.',
#  'Constructora Beltrán Ltda',
#  'DIAN CORDAL',
#  'VICENTE ENRIQUE',
#  'SOCIEDAD COMERCIAL SERVIOCTAVA S. A.',
#  'EMPRESAS R&A',
#  'Rafael Enrique ',
#  'COMERCIALIZADORA ENGINE PARTS S.A',
#  'RICARDO RUBEN',
#  'Cecor S.A.',
#  'Ramon Antonio',
#  'Christopher Damian',
#  'PUNTO HIDRAULICO BUIN SPA',
#  'Easy Retail',
#  'centro de diagnostico por imagenes y cia ltda',
#  'CITSALUD',
#  'RADIODIAGNSOTICO CORONEL',
#  'inmunomedica',
#  'Centro Médico Concepción',
#  'AMERICAN EAR - DIST. SALVADOR LTDA.',
#  'OTOMEDICAL - WIDEX',
#  'Audiophon Ltda',
#  'ICAEE SpA',
#  'CONSTREET',
#  'AC&WS - ANIMAL CARE & WELLNESS SOLUTIONS S.A.',
#  'AGROMAIPO',
#  'COMERCIAL ALIAGRO LTDA.',
#  'Schonfeldt Vidamedica SpA',
#  'MEGAMEDICAL SpA',
#  'Norstray Nuart SPA',
#  'Comercial LBF Limitada',
#  'globalmed',
#  'Medical Supplies Chile E.I.R.L.',
#  'LKM Chile',
#  'MEDBIOTEC',
#  'Librería La Oficina Ltda.',
#  'CRISTIAN SAMUEL',
#  'JONATHAN EDGARDO',
#  'VALING',
#  'ELIOTEC INGENIERÍA ELÉCTRICA',
#  'MANUEL ALEJANDRO',
#  'GIOVANNI SEBASTIAN',
#  'FARMACIA BULFOR',
#  'Exeltis SpA',
#  'Indopharma S.A.',
#  'FPC',
#  'IFICAM',
#  'HERNAN EDGARDO',
#  'Laboratorio Boston s.a. - Casa Matriz',
#  'M y P  Ltda.',
#  'Ingesmart S.A.',
#  'Constructora GF Chile Limitada',
#  'CONSTRUCTORA VALMON SPA',
#  'EMPRESA NACIONAL DE ENERGIA ENEX SA',
#  'YPF CHILE',
#  'COMERCIAL A T M LTDA',
#  'RIOSAN 21 DE MAYO 3033',
#  'Inversiones y Comercialización San Luis SPA',
#  'Jan',
#  'Tecnolub Ltda. ',
#  'BIOLINE LIMITADA',
#  'TopRoller',
#  'IMV INGENIERIA SPA',
#  'Delex Ltda.',
#  'Equipos Médicos Zepeda y Compañia Ltda.',
#  'Comercial Pro-Clinic Ltda.',
#  'ALIMPACK SPA',
#  'HealthPlus equipos medicos',
#  'Medcorp ',
#  'KNOP LABORATORIOS S.A.- Casa Matriz',
#  'Redoffice Region Metropolitana',
#  'PABLO CESAR',
#  'Katherine Pamela',
#  'VICRACK',
#  'NEUMACLICK',
#  'Acoplas',
#  'Avalco SpA',
#  'Alexis Alejandro',
#  'YERKO ENRIQUE',
#  'JUAN CARLOS',
#  'Genset Energy Solutions Ltda.',
#  'MAYORDENT LTDA',
#  'LABORATORIOS DENTAID S A',
#  'BUHOS S.C.I. LTDA.',
#  'Clan Dent ',
#  'GRYLY SABINA',
#  'MedicalTek (División Dental)',
#  'ANDRES ESTEBAN',
#  'Salinas y Fabres S.A. - Sucursal Concepción',
#  'CAMILO IGNACIO HERNANDEZ HERNANDEZ',
#  'TAMARA CONSTANZA HUERTA SANTANDER',
#  'Madelein Andrea',
#  'IVAN MARCELO QUEZADA ARRIAGADA',
#  'WIENECKE CORREDORES DE SEGUROS LIMITADA',
#  'StoneMusic',
#  'Angela Rodríguez ',
#  'RENAYCO LTDA',
#  'Sherwin Zonal Sur',
#  'PROMAC',
#  'Ultracolor',
#  'Sergio Cartes',
#  'INNOCON S.A.',
#  'MSM',
#  'Chilemat Toso',
#  'supersa',
#  'TERMINACIONES EN PINTURAS SPA',
#  'Terrano',
#  'Antus Industrial',
#  'Edgard Ignacio ',
#  'CimmaSeg',
#  'CFMedica',
#  'Comercial Lubeck SPA',
#  'christian',
#  'SERVICIO DE METROLOGIA INTEGRAL SPA',
#  'IMPORTADORA EXCELLENT',
#  'COMERCIAL MAHUEL SPA',
#  'Küpfer Hnos. S.A. N 1',
#  'ARSYSTEM SPA',
#  'LBF Limitada',
#  'Safety Med',
#  'Demmis hernaldo',
#  'Comercial Kuppel SPA',
#  'VLADIMIR HERTE SALAZAR',
#  'Skyway Corporation',
#  'MAURICIO',
#  'BRANDING CORPORATIVO',
#  'Interfilm S.A.',
#  'ANA LUISA ',
#  'Sanitzhile',
#  'Silvia Ester',
#  '7 PLAGAS LTDA.',
#  'CHILE SERVICIOS SPA',
#  'ROBERT ANTONIO ',
#  'Distribuidora Abtao',
#  'GMA SPA',
#  'BMK SPA',
#  'PEDRO ALEJANDRO',
#  'Inversiones América Spa',
#  'Mauricio Alfonso ',
#  'KRF LTDA',
#  'Fernando Ariel',
#  'Luis Orlando',
#  'DINASEG LTDA',
#  'DIMAR',
#  'Limpieza Industrial Chile SpA',
#  'JORGE ANTONIO',
#  'Indubal',
#  'Angelo Eduardo',
#  'DELTAMED LIMITADA',
#  'Equimed Electronica Ltda.',
#  'QUALITOM PHARMA MEDICAL',
#  'INNOVAMEDICA',
#  'IVMedical',
#  'TEXTIL KIMMY SPA',
#  'OLTRA  SpA',
#  'BIOFISICS',
#  'DMC3',
#  'FERNANDO MORATINOS POHL - ARQUITECTO',
#  'Roberto Guillermo',
#  'Victor Alfredo',
#  'ARIEL ALBERTO CARRILLO CAVIERES',
#  'NATALIA PAOLA CORRAL HOPPE',
#  'Ariel Damián',
#  'PAULO IGNACIO CUEVAS SAN MARTIN',
#  'servicios de arquitectura',
#  'Rodrigo ariel',
#  'Pablo Rubén',
#  'Edison Gerardo',
#  'rodrigo alonso',
#  'Gustavo Adolfo',
#  'Arquitecto y Revisor Independiente de Arquitectura',
#  'Constanza Solá Pardo',
#  'Sermecoop Ltda',
#  'Magaly Susana',
#  'FERNANDO  ',
#  'FUAD',
#  'Gamma Comunicaciones',
#  'william cornelio',
#  'CODESUR LTDA',
#  'GALENICUM CHILE',
#  'Cipriano Eduardo',
#  'Matias Alejandro',
#  'stefani carolina',
#  'Futuro',
#  'Impresos El Gráfico Ltda',
#  'MOLINO FUENTES S.A.',
#  'Terkofilms E.I.R.L.',
#  'Cristian',
#  'Elías Joaquín',
#  'Claudia Maricel ',
#  'RICARDO FIERRO AYALA',
#  'distribuidora pec',
#  'SOCIEDAD DE INVERSIONES MAXIMO SPA',
#  'SOLUCIONES',
#  'trasporte Aravena',
#  'Ricardo Ignacio',
#  'ESPECIALIDADES OFTALMOLÓGICAS SUCURSAL CHILE SPA',
#  'GLAXOSMITHKLINE CHILE FARMACEUTICA LIMITADA',
#  'KSLTDA',
#  'Importaciones Medicas S.A.',
#  'SOLARFILM',
#  'CMP servicios clinicos ltda',
#  'MYC SPA',
#  'Ban Producciones',
#  'Exom Chile Spa',
#  'Cramick S.A.',
#  'DIEGO FRANCISCO',
#  'softwareLife',
#  'DAVID AND JOSEPH CHILE',
#  'KOLFF SpA',
#  'SIMELCO',
#  'COMERCIALIZADORA GRÁFICA',
#  'IMPRESOS AMAR',
#  'Impresos Gama',
#  'ALVARO MIZGIER  HOCHSCHILD',
#  'CMEDICAL SpA',
#  'Christian Eugenio',
#  'Convatec',
#  'Tecnika S.A.',
#  'MADEGOM S.A.',
#  'Limax Salud',
#  'SOC.IMPORTADORA OPTIVISION LTD 2',
#  'AD Salud',
#  'Global Healthcare Chile L.P.',
#  'MOLNLYCKE',
#  'VITALSEC SPA',
#  'PALNIC',
#  'BIOCLIN S.A.',
#  'INMED DROGUERIA LTDA.',
#  'NOVOSALUD',
#  'Comercial Plasteca E.I.R.L.',
#  'Mapam',
#  'Alvaro Ramiro',
#  'Mincotec',
#  'greentak',
#  'ETIBRAS LTDA.',
#  'Resolutions SpA',
#  'AndesCampers NuevaVida',
#  'Renta Nacional - Concepción',
#  'CRISTHIAN ALVARO RIQUELME FLORES',
#  'K y D Consultores',
#  'ethos',
#  'MR GRUPOINTEGRAL',
#  'NEDDY CARMEN RIVAS ZENTENO',
#  'LUIS ARCENIO',
#  'Biomedika',
#  'RAC SEGURIDAD INDUSTRIAL',
#  'Andover Alianza Médica S. A.',
#  'Patricio Alejandro Flores Parra',
#  'MGM Productos Médicos Ltda.',
#  'AMICpap',
#  'EDUARDO',
#  'HCmedical',
#  'LINDE GAS CHILE S.A.',
#  'LIFECORP S.A.',
#  'ESPEX INGENIERIA',
#  'CBP INGENIERÍA Y CONSTRUCCIÓN EIRL',
#  'Opciones S.A. Sistemas de Información',
#  'PCHOME LIMITADA',
#  'SSP',
#  'automotriz jc ltda',
#  'Eurofarma Chile S. A.',
#  'Raul Armando',
#  'carlos',
#  'Fernando',
#  'COMERCIAL AYC SPA',
#  'Comercial Agustin Limitada',
#  'Nubecita Diapers',
#  'EM HUALLE SpA',
#  'INVERSIONES PILUM SpA',
#  'Juanreca',
#  'RODRIGO ALEXIS FLORES PAREDES',
#  'RELIEVE comunicación, contenidos, investigación',
#  'Juan Carlos Riffo Chávez',
#  'MARIO ALEX',
#  'Espacio Clima SpA',
#  'Paulina Ximena',
#  'Servimaule Control y Manejo de Plagas Limitada',
#  'PATRICIA EMILIA OSORES CORONEO',
#  'Laboratorios Pint Pharma Chile SPA',
#  'AV-EME PUBLICIDAD',
#  'Eco Digital spa',
#  'Asociados Undurraga Impresores Ltda.',
#  'ESTUDIO 203',
#  'Punto Grafix E.I.R.L.',
#  'TITUS DISEÑO Y PRODUCCION',
#  'DW PUBLICIDAD SPA',
#  'InfoView Profesionales',
#  'International Clinics S.A.',
#  'I MUNICIPALIDAD DE LOTA']

# %%
ddlota,G_lota = comunidad(pivot, lota)
ddlota = ddlota.sort_values(by='Conteo Interacciones', ascending=False)

# %%
ddlota.reset_index().drop(columns='index')
# Out:
#              NombreOrganismo                    NombreProveedor  \
# 0    I MUNICIPALIDAD DE LOTA             MULTICOMERCIAL CHILLAN
# 1    I MUNICIPALIDAD DE LOTA                     MOSIL LIMITADA
# 2    I MUNICIPALIDAD DE LOTA        Carlos Espejo y Cía. Ltda.-
# 3    I MUNICIPALIDAD DE LOTA                         ElMINERITO
# 4    I MUNICIPALIDAD DE LOTA                            HUALPEN
# ..                       ...                                ...
# 830  I MUNICIPALIDAD DE LOTA           Rodrigo Jose Romero Soto
# 831  I MUNICIPALIDAD DE LOTA                      Rodrigo ariel
# 832  I MUNICIPALIDAD DE LOTA               Constanza Solá Pardo
# 833  I MUNICIPALIDAD DE LOTA  Comercializadora Raiper Chile SPA
# 834  I MUNICIPALIDAD DE LOTA      Centro de Capacitación INNOVA
#
#      Conteo Interacciones
# 0                    4679
# 1                    3380
# 2                     919
# 3                     736
# 4                     538
# ..                    ...
# 830                     1
# 831                     1
# 832                     1
# 833                     1
# 834                     1
#
# [835 rows x 3 columns]

# %%
dflota = df[df['NombreProveedor'] == 'MOSIL LIMITADA'][df['Oferta seleccionada']=='Seleccionada']
dflota
# Out:
# C:\Users\pablo\AppData\Local\Temp\ipykernel_25932\1517818614.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   dflota = df[df['NombreProveedor'] == 'MOSIL LIMITADA'][df['Oferta seleccionada']=='Seleccionada']
#           Codigo                           Tipo de Adquisicion      Estado  \
# 64671    8636708       Licitación Pública Menor a 100 UTM (L1)  Adjudicada
# 64750    8636708       Licitación Pública Menor a 100 UTM (L1)  Adjudicada
# 144707   8643081       Licitación Pública Menor a 100 UTM (L1)  Adjudicada
# 175629   8645554       Licitación Pública Menor a 100 UTM (L1)  Adjudicada
# 184016   8646299       Licitación Pública Menor a 100 UTM (L1)  Adjudicada
# ...          ...                                           ...         ...
# 1868145  8729648       Licitación Pública Menor a 100 UTM (L1)  Adjudicada
# 1868147  8729648       Licitación Pública Menor a 100 UTM (L1)  Adjudicada
# 1868150  8729648       Licitación Pública Menor a 100 UTM (L1)  Adjudicada
# 1868574  8729695  Licitación Pública Entre 100 y 1000 UTM (LE)  Adjudicada
# 1876682  8730986       Licitación Pública Menor a 100 UTM (L1)  Adjudicada
#
#          CodigoOrganismo                           NombreOrganismo  \
# 64671             111875  DIRECCION DE ABASTECIMIENTO DE LA ARMADA
# 64750             111875  DIRECCION DE ABASTECIMIENTO DE LA ARMADA
# 144707             98443                   I MUNICIPALIDAD DE TOME
# 175629            120004                 I MUNICIPALIDAD DE YUMBEL
# 184016            123786                  MUNICIPALIDAD DE HUALPEN
# ...                  ...                                       ...
# 1868145           113259                   I MUNICIPALIDAD DE LOTA
# 1868147           113259                   I MUNICIPALIDAD DE LOTA
# 1868150           113259                   I MUNICIPALIDAD DE LOTA
# 1868574           100049                  I MUNICIPALIDAD DE AYSEN
# 1876682            98443                   I MUNICIPALIDAD DE TOME
#
#             RutUnidad ComunaUnidad FechaPublicacion  CodigoProductoONU  \
# 64671    61.102.023-6   Talcahuano       2020-01-08           31211904
# 64750    61.102.023-6   Talcahuano       2020-01-08           14111609
# 144707   69.150.100-0         Tomé       2020-01-18           11111611
# 175629   69.150.901-K       Yumbel       2020-01-23           31161504
# 184016   69.264.400-k      Hualpén       2020-01-24           11111701
# ...               ...          ...              ...                ...
# 1868145  69.151.300-9         Lota       2020-09-30           22101505
# 1868147  69.151.300-9         Lota       2020-09-30           26111601
# 1868150  69.151.300-9         Lota       2020-09-30           30111601
# 1868574  69.240.100-K        Aysén       2020-09-28           30111501
# 1876682  69.150.100-0         Tomé       2020-09-30           11111611
#
#          RutProveedor NombreProveedor Moneda de la Oferta MontoLineaAdjudica  \
# 64671    76.722.635-7  MOSIL LIMITADA        Peso Chileno              29970
# 64750    76.722.635-7  MOSIL LIMITADA        Peso Chileno             109035
# 144707   76.722.635-7  MOSIL LIMITADA        Peso Chileno            2945824
# 175629   76.722.635-7  MOSIL LIMITADA        Peso Chileno             798258
# 184016   76.722.635-7  MOSIL LIMITADA        Peso Chileno              54750
# ...               ...             ...                 ...                ...
# 1868145  76.722.635-7  MOSIL LIMITADA        Peso Chileno              29080
# 1868147  76.722.635-7  MOSIL LIMITADA        Peso Chileno              40712
# 1868150  76.722.635-7  MOSIL LIMITADA        Peso Chileno              48150
# 1868574  76.722.635-7  MOSIL LIMITADA        Peso Chileno           15500800
# 1876682  76.722.635-7  MOSIL LIMITADA        Peso Chileno             797643
#
#         Oferta seleccionada
# 64671          Seleccionada
# 64750          Seleccionada
# 144707         Seleccionada
# 175629         Seleccionada
# 184016         Seleccionada
# ...                     ...
# 1868145        Seleccionada
# 1868147        Seleccionada
# 1868150        Seleccionada
# 1868574        Seleccionada
# 1876682        Seleccionada
#
# [2257 rows x 14 columns]

# %%
ddlota_aux = ddlota.iloc[:10]
ddlota_aux = ddlota_aux.reset_index().drop(columns='index')
codigos123 = jaccard_completo(ddlota_aux)
codigos123[codigos123['CantidadCoincidencias']>0.001*codigos123['CantidadCoincidencias'].max()]
# Out:
#               NombreProveedor_1            NombreProveedor_2  \
# 0                      WINPHARM   ETHON PHARMACEUTICALS SPA.
# 2    ETHON PHARMACEUTICALS SPA.         Caribean Pharma Ltda
# 4    ETHON PHARMACEUTICALS SPA.  DROGUERIA GLOBAL PHARMA SPA
# 6   DROGUERIA GLOBAL PHARMA SPA         Caribean Pharma Ltda
# 8   DROGUERIA GLOBAL PHARMA SPA                     WINPHARM
# 10         Caribean Pharma Ltda     Distribuidora Salcobrand
# 12                     WINPHARM         Caribean Pharma Ltda
# 14     Distribuidora Salcobrand   ETHON PHARMACEUTICALS SPA.
# 16  DROGUERIA GLOBAL PHARMA SPA     Distribuidora Salcobrand
# 18                     WINPHARM     Distribuidora Salcobrand
# 20  Carlos Espejo y Cía. Ltda.-               MOSIL LIMITADA
# 21                      HUALPEN                   ElMINERITO
# 24       MULTICOMERCIAL CHILLAN               MOSIL LIMITADA
# 26       MULTICOMERCIAL CHILLAN  Carlos Espejo y Cía. Ltda.-
# 28               MOSIL LIMITADA                   ElMINERITO
# 29                      HUALPEN  Carlos Espejo y Cía. Ltda.-
# 32               MOSIL LIMITADA                      HUALPEN
# 34                   ElMINERITO  Carlos Espejo y Cía. Ltda.-
# 36                   ElMINERITO       MULTICOMERCIAL CHILLAN
# 38       MULTICOMERCIAL CHILLAN                      HUALPEN
# 39       MULTICOMERCIAL CHILLAN     Distribuidora Salcobrand
# 41               MOSIL LIMITADA     Distribuidora Salcobrand
# 48                     WINPHARM       MULTICOMERCIAL CHILLAN
# 49  DROGUERIA GLOBAL PHARMA SPA       MULTICOMERCIAL CHILLAN
# 57       MULTICOMERCIAL CHILLAN         Caribean Pharma Ltda
# 75       MULTICOMERCIAL CHILLAN   ETHON PHARMACEUTICALS SPA.
#
#     Coeficiente de Jaccard CantidadCoincidencias
# 0                     0.59                  3271
# 2                     0.56                  3442
# 4                     0.54                  3162
# 6                     0.52                  2884
# 8                     0.50                  2579
# 10                    0.49                  2586
# 12                    0.48                  2691
# 14                    0.46                  2661
# 16                    0.43                  2214
# 18                    0.41                  2085
# 20                    0.16                    75
# 21                    0.16                    12
# 24                    0.11                   123
# 26                    0.10                   102
# 28                    0.05                    18
# 29                    0.05                    14
# 32                    0.04                    14
# 34                    0.03                     9
# 36                    0.02                    20
# 38                    0.01                    12
# 39                    0.01                    29
# 41                    0.01                    26
# 48                    0.00                    12
# 49                    0.00                    13
# 57                    0.00                    16
# 75                    0.00                     5

# %% [markdown]
# La empresa MOSIL LIMITADA no tiene un coeficiente de Jaccard alto, por lo que dentro de la Municipalidad de Lota está bien distribuida, sin embargo, es llamativo que la tasa de éxito en esta empresa sea tan alto.

# %% [markdown]
# ## Conclusiones, trabajos futuros y limitaciones

# %% [markdown]
# ### Conclusiones
#
# - Las empresas farmaceuticas son el giro el cual concentra la mayor cantidad de licitaciones en el año 2020.
#
#
# - Se esperaba que hubieran mas instituciones de salud en los organismos que abrieron licitaciones, pero este top lo lideran instituciones de fuerzas armadas.
#
#
# - Se analizó la tasa de éxito de los proveedores, encontrando una distribución sospechosa entre el top 7 y que la empresa MOSIL es potencialmente fraudulenta.
#
#
# - Se construyó una red bipartita con 38.617 nodos y 205.391 enlaces.
#
#
# - Observando la distribución de grado, se ve que gran cantidad de nodos bajamente conectados y que para grados mayores la distribución de nodos disminuye exponencialmente.
#
#
# - El cálculo de comunidades mediante el algoritmo de Louvain es una excelente herramienta para detectar posibles casos de corrupción. Se estudiaron las comunidades más pequeñas encontrando anomalías importantes en cuanto a los criterios de selección de proveedores por parte los organismos.
#
#
# - El coeficiente de Jaccard es también un buen indicador el cual muestra cuantas veces coincidieron los mismos proveedores en las licitaciones. Si el coeficiente es bajo, significa que un proveedor está postulando de manera aislada a las licitaciones sin competir.
#
#
# - En el caso de estudio de Atacama, todos los participantes tienen un alto coef Jaccard entre sí. Los ganadores tienen un coef Jaccard bajo sugiriendo que estas empresas no competían.
#
#
# - En el caso de MOSIL LIMITADA, quien destaca por su gran cantidad de licitaciones aceptadas (comparables con empresas farmacéuticas de renombre) y una de las tasas de éxito postulación/aceptación mas altas de todos los proveedores, concentra en la Municipalidad de Lota 2.000 licitaciones aceptadas, siendo esto una anomalía importante comparándolo con el general del dataset. Al calcular su Coeficiente de Jaccard, el grupo se percató de que coincide en licitaciones con la empresa Salcobrand, siendo MOSIL una empresa de construcción.
#
#
# - La comunidad del Hospital Padre Hurtado era pequeña pero al analizarse no identificamos patrones de fraude.
#
#
# - Se concluye que el desafío fue correctamente superado al haber finalizado cada una de las etapas solicitadas con éxito.
#
#
# - Resulta muy positivo que la actividad final de esta asignatura contemple el desarrollo de un proyecto real, poniendo en práctica las herramientas adquiridas en esta esta asignatura y también en el magister.
#
#
# ### Trabajos futuros
#
# - Existe una oportunidad al automatizar las tareas de análisis manual efectuadas durante este desafío.
#
#
# - Una actividad para profundizar esta investigación, sería repetir el análisis desarrollado tomando en cuenta las comunidades mas grandes y descomponiendolas en sub-comunidades mas pequeñas, para así poder ir identificando patrones de corrupción de manera cíclica.
#
#
# ### Limitaciones
#
# - La capacidad computacional enletece los análisis y lo hace en algunos casos imposible debido a la gran cantidad de ram necesaria para procesar esta red
#
#
# - La cantidad de tiempo óptima para realziar un análisis realmente profundo de la base de datos es mayor a la que el grupo tuvo para finalizar el desafío.

# %% [markdown]
# ### Bibliografía y Webgrafía

# %% [markdown]
# - https://www.mercadopublico.cl/Home/Contenidos/QueEsLicitacion
# - https://www.cnmc.es/guias
# - https://www.ciperchile.cl/2015/08/11/el-fraude-que-oscurece-las-licitaciones-que-gano-lg-para-iluminar-seis-comunas-con-led/
# - https://www.elmostrador.cl/noticias/pais/2023/01/14/a-7-anos-del-milicogate-las-agencias-de-viajes-involucradas-se-adjudican-millonarias-licitaciones-con-el-estado/
